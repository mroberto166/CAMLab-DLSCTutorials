# %% [markdown]
# ## Physics Informed Neural Networks to Approximate Solution of PDEs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch.optim as optim
import torch
from torch.utils.data import DataLoader

# Adapt this import to your specific directory tree.
from drive.MyDrive.DLSC.Common import NeuralNet, MultiVariatePoly
import time
torch.autograd.set_detect_anomaly(True)
torch.manual_seed(128)

# %% [markdown]
# Consider the one-dimensional parametric heat equation:
#
# $$
# u_t(t, x, \mu) = u_{xx}(t, x, \mu), \quad t\in[0,T], ~x\in [-1,1], ~\mu\in [-1,1]^d
# $$
#
# where the parametric nature of the PDE stems from the initial condition
#
# $$
# u(0, x, \mu) = u_0(x, \mu) = \sum_{m}^d u_0^m(x, \mu_m) = - \frac{1}{d}\sum_{m=1}^d \mu_m\sin(\pi m x )/m^{0.5}
# $$
#
# with
#
# $$
# u_0^m(x, \mu_m) = - \mu_m\sin(\pi m x )/m^{0.5}
# $$
#
# Similarly to the previous tutorials, consider zero Dirichlet BC:
# $$
# u_b(t, -1, \mu)=u_b(t,1, \mu)=0,
# $$
#
# We want to obtain an approximate solution of the heat equation $u : [0,T]\times[-1,1]\times[-1,1]^d  \mapsto R$ with physics informed neural networks (PINNs).
#
# To do so, we consider the following ansatz for the solution of the PDE:
#
# $$
# \bar{u}_\theta(t,x,\mu) =  \frac{1}{d}\sum_{m=1}^d u_0^m(x, \mu_m)(1 - t u^m_{\theta}(t,x,\mu)) \approx u(t,x, \mu)
# $$
# with $u_\theta(t,x,\mu):\mathbb{R}^{2+d}\mapsto \mathbb{R}^{d}$, $u_\theta(t,x,\mu) =(u^1_\theta(t,x,\mu), ..., u^d_\theta(t,x,\mu))$ being a feedforward dense neural network with tunable parameters $\theta$.
#
# This ansatz is a natural choice for this type of problem, given the nature of the initial condition, which is the superposition of different functions $u_0^m(x, \mu_m)$ and the linearity of the PDE. As a consequence, the PDE solution is the superposition of the solutions of the PDE with initial conditions given by $u_0^m(x, \mu_m)$.
#
# Define the following residuals:
#
# - Interior residual given by,
#
# \begin{equation}
#          r_{int,\theta}(t, x, \mu):=  \bar{u}_\theta(t, x, \mu) - \bar{u}_{\theta, xx}(t, x, \mu), \quad \forall ~t \in [0,T],~ x \in [-1,1], ~\mu \in [-1,1]^d.
# \end{equation}
#
# - Spatial boundary residual given by,
#
# \begin{equation}
#     r_{sb,\theta}(t,-1,\mu):= \bar{u}_{\theta}(t,-1, \mu)- u_b(t,-1, \mu), \quad r_{sb,\theta}(t,1, \mu):= \bar{u}_{\theta}(t,1, \mu)- u_b(t,1, \mu), \quad \forall t \in (0,T], ~\mu \in [-1,1]^d .
# \end{equation}
#
#
#    - Temporal boundary residual given by,
#
#         $$r_{tb,\theta}(x,\mu):= \bar{u}_{\theta}(x,0,\mu) - u_0(x,\mu), \quad \forall x \in [-1,1], ~\mu \in [-1,1]^d.$$
#
# Observe that given the definition of $\bar{u}$, the boundaries residuals are identically zero.
#
#
# Therefore, we only need to compute the interior loss given the training data
#
# $$
# S_{int} =\{y_n\}, \quad 1 \leq n \leq N_{int},\quad y_n = (x,t, \mu)_n \in [0,T]\times[-1,1]\times[-1,1]^d,
# $$
#
# $$
# L_{int}(\theta) = \frac{1}{N_{int}}\sum_{i=1}^{N_{int}}r_{int,\theta}^2(y_n)
# $$
#
# and solve the minimization problem
#
# $$
# \theta^\ast = argmin_{\theta} \Big(L_{int}(\theta)\Big)
# $$

# %%
class HardBCPinns(torch.nn.Module):

    def __init__(self, ic, u_tilde):
        super().__init__()
        self.ic = ic
        self.u_tilde = u_tilde

    def forward(self, x):
        time_coord = x[:, 0].reshape(-1, )

        u0 = self.ic(x[:, 1:])
        u_tilde = self.u_tilde(x)
        sol = torch.sum((1 - time_coord[:, None] * u_tilde) * u0, -1)

        return sol.reshape(-1, 1)

class Pinns:
    def __init__(self, n_int_, n_sb_, n_tb_):
        self.n_int = n_int_
        self.n_sb = n_sb_
        self.n_tb = n_tb_

        # Extrema of the solution domain (t,x) in [0,0.1]x[-1,1]
        self.domain_extrema = torch.tensor([[0, 0.1],  # Time dimension
                                            [-1, 1]])  # Space dimension

        self.p = 5
        self.parameters_extrema = torch.ones((self.p, 2))
        self.parameters_extrema[:, 0] = -1

        self.domain_extrema = torch.cat(
            (self.domain_extrema, self.parameters_extrema), 0)

        # Number of space dimensions
        self.space_dimensions = 1

        # FF Dense NN to approximate the solution of the underlying heat equation
        self.nn = NeuralNet(input_dimension=2 + self.p,
                            output_dimension=self.p,
                            n_hidden_layers=4,
                            neurons=20,
                            regularization_param=0.,
                            regularization_exp=2.,
                            retrain_seed=42)

        self.approximate_solution = HardBCPinns(
            self.get_initial_condition_modes, self.nn)

        # Generator of Sobol sequences
        self.soboleng = torch.quasirandom.SobolEngine(
            dimension=self.domain_extrema.shape[0])

        # Training sets S_sb, S_tb, S_int as torch dataloader
        self.training_set_sb, self.training_set_tb, self.training_set_int = self.assemble_datasets()

    ################################################################################################
    # Function to linearly transform a tensor whose value are between 0 and 1
    # to a tensor whose values are between the domain extrema
    def convert(self, tens):
        assert (tens.shape[1] == self.domain_extrema.shape[0])
        return tens * (self.domain_extrema[:, 1] - self.domain_extrema[:, 0]) + self.domain_extrema[:, 0]

    # Initial condition to solve the heat equation u0(x)=-sin(pi x)
    def initial_condition(self, inputs):
        t0 = torch.full((inputs.shape[0], 1), self.domain_extrema[0, 0])
        inputs = torch.cat((t0, inputs), 1)
        return self.exact_solution(inputs)

    def get_initial_condition_modes(self, inputs):
        x = inputs[:, 0]
        mu = inputs[:, 1:]
        u = torch.zeros((inputs.shape[0], self.p))
        for i in range(1, self.p + 1):
            u[:, i-1] = -mu[:, i - 1]/self.p * torch.sin(np.pi * x * i) / i ** 0.5
        return u

    # Exact solution for the heat equation ut = u_xx with the IC above
    def exact_solution(self, inputs):
        t = inputs[:, 0]
        x = inputs[:, 1]
        mu = inputs[:, 2:]
        u = 0
        for i in range(1, self.p + 1):
            u = u - torch.exp(-(np.pi * i) ** 2 * t) * mu[:, i - 1]/self.p * torch.sin(np.pi * x * i) / i ** 0.5

        return u

    ################################################################################################
    # Function returning the input-output tensor required to assemble the training set S_tb corresponding to the temporal boundary
    def add_temporal_boundary_points(self):
        t0 = self.domain_extrema[0, 0]
        input_tb = self.convert(self.soboleng.draw(self.n_tb))
        input_tb[:, 0] = torch.full(input_tb[:, 0].shape, t0)
        output_tb = self.initial_condition(input_tb[:, 1:]).reshape(-1, 1)

        return input_tb, output_tb

    # Function returning the input-output tensor required to assemble the training set S_sb corresponding to the spatial boundary
    def add_spatial_boundary_points(self):
        x0 = self.domain_extrema[1, 0]
        xL = self.domain_extrema[1, 1]

        input_sb = self.convert(self.soboleng.draw(self.n_sb))

        input_sb_0 = torch.clone(input_sb)
        input_sb_0[:, 1] = torch.full(input_sb_0[:, 1].shape, x0)

        input_sb_L = torch.clone(input_sb)
        input_sb_L[:, 1] = torch.full(input_sb_L[:, 1].shape, xL)

        output_sb_0 = torch.zeros((input_sb.shape[0], 1))
        output_sb_L = torch.zeros((input_sb.shape[0], 1))

        return torch.cat([input_sb_0, input_sb_L], 0), torch.cat([output_sb_0, output_sb_L], 0)

    #  Function returning the input-output tensor required to assemble the training set S_int corresponding to the interior domain where the PDE is enforced
    def add_interior_points(self):
        input_int = self.convert(self.soboleng.draw(self.n_int))
        output_int = torch.zeros((input_int.shape[0], 1))
        return input_int, output_int

    # Function returning the training sets S_sb, S_tb, S_int as dataloader
    def assemble_datasets(self):
        input_sb, output_sb = self.add_spatial_boundary_points()  # S_sb
        input_tb, output_tb = self.add_temporal_boundary_points()  # S_tb
        input_int, output_int = self.add_interior_points()  # S_int

        training_set_sb = DataLoader(torch.utils.data.TensorDataset(input_sb, output_sb), batch_size=2 * self.space_dimensions * self.n_sb, shuffle=False)
        training_set_tb = DataLoader(torch.utils.data.TensorDataset(input_tb, output_tb), batch_size=self.n_tb, shuffle=False)
        training_set_int = DataLoader(torch.utils.data.TensorDataset(input_int, output_int), batch_size=self.n_int, shuffle=False)

        return training_set_sb, training_set_tb, training_set_int

    ################################################################################################
    # Function to compute the terms required in the definition of the TEMPORAL boundary residual
    def apply_initial_condition(self, input_tb):
        u_pred_tb = self.approximate_solution(input_tb)
        return u_pred_tb

    # Function to compute the terms required in the definition of the SPATIAL boundary residual
    def apply_boundary_conditions(self, input_sb):
        u_pred_sb = self.approximate_solution(input_sb)

        return u_pred_sb

    # Function to compute the PDE residuals
    def compute_pde_residual(self, input_int):
        input_int.requires_grad = True
        u = self.approximate_solution(input_int)

        # grad compute the gradient of a "SCALAR" function L with respect to some input nxm TENSOR Z=[[x1, y1],[x2,y2],[x3,y3],...,[xn,yn]], m=2
        # it returns grad_L = [[dL/dx1, dL/dy1],[dL/dx2, dL/dy2],[dL/dx3, dL/dy3],...,[dL/dxn, dL/dyn]]
        # Note: pytorch considers a tensor [u1, u2,u3, ... ,un] a vectorial function
        # whereas sum_u = u1 + u2 u3 + u4 + ... + un as a "scalar" one

        # In our case ui = u(xi), therefore the line below returns:
        # grad_u = [[dsum_u/dx1, dsum_u/dy1],[dsum_u/dx2, dsum_u/dy2],[dsum_u/dx3, dL/dy3],...,[dsum_u/dxm, dsum_u/dyn]]
        # and dsum_u/dxi = d(u1 + u2 u3 + u4 + ... + un)/dxi = d(u(x1) + u(x2) u3(x3) + u4(x4) + ... + u(xn))/dxi = dui/dxi
        grad_u = torch.autograd.grad(u.sum(), input_int, create_graph=True)[0]
        grad_u_t = grad_u[:, 0]
        grad_u_x = grad_u[:, 1]
        grad_u_xx = torch.autograd.grad(grad_u_x.sum(), input_int, create_graph=True)[0][:, 1]

        residual = grad_u_t - grad_u_xx
        return residual.reshape(-1, )

    # Function to compute the total loss (weighted sum of spatial boundary loss, temporal boundary loss and interior loss)
    def compute_loss(self, inp_train_sb, u_train_sb, inp_train_tb, u_train_tb, inp_train_int, verbose=True):
        u_pred_sb = self.apply_boundary_conditions(inp_train_sb)
        u_pred_tb = self.apply_initial_condition(inp_train_tb)

        assert (u_pred_sb.shape[1] == u_train_sb.shape[1])
        assert (u_pred_tb.shape[1] == u_train_tb.shape[1])

        r_int = self.compute_pde_residual(inp_train_int)
        r_sb = u_train_sb - u_pred_sb
        r_tb = u_train_tb - u_pred_tb

        loss_sb = torch.mean(abs(r_sb) ** 2)
        loss_tb = torch.mean(abs(r_tb) ** 2)
        loss_int = torch.mean(abs(r_int) ** 2)

        loss_u = loss_sb + loss_tb

        # Loss is given only by the interior one since the boundary and initial conditions are automatically satisfied.
        loss = torch.log10(loss_int)
        if verbose:
           print(
               "Total loss: ", round(loss.item(), 4),
                "| PDE Loss: ", round(torch.log10(loss_int).item(), 4), "| Function Loss: ", round(torch.log10(loss_u).item(), 4))

        return loss

    ################################################################################################
    def fit(self, num_epochs, optimizer, verbose=True):
        history = list()

        # Loop over epochs
        for epoch in range(num_epochs):
            if verbose: print("################################ ", epoch, " ################################")

            for j, ((inp_train_sb, u_train_sb), (inp_train_tb, u_train_tb), (inp_train_int, u_train_int)) in enumerate(zip(self.training_set_sb, self.training_set_tb, self.training_set_int)):
                def closure():
                    optimizer.zero_grad()
                    loss = self.compute_loss(inp_train_sb, u_train_sb, inp_train_tb, u_train_tb, inp_train_int, verbose=verbose)
                    loss.backward()

                    history.append(loss.item())
                    return loss

                optimizer.step(closure=closure)

        print('Final Loss: ', history[-1])

        return history

    ################################################################################################
    def plotting(self):
        t = torch.linspace(0, 1, 50)
        x = torch.linspace(0, 1, 50)
        input_tx = torch.cartesian_prod(t, x)

        for i in range(5):
            mu = torch.rand((1, self.p))
            mu = mu.repeat(input_tx.shape[0], 1)

            inputs = torch.cat((input_tx, mu), -1)
            inputs = self.convert(inputs)

            output = self.approximate_solution(inputs).reshape(50, 50)
            exact_output = self.exact_solution(inputs).reshape(50, 50)

            fig, axs = plt.subplots(1, 2, figsize=(16, 8), dpi=150)
            im1 = axs[0].contourf(x, t, exact_output.detach(), cmap="jet", levels=200)
            axs[0].set_xlabel("x")
            axs[0].set_ylabel("t")
            plt.colorbar(im1, ax=axs[0])
            axs[0].grid(True, which="both", ls=":")
            im2 = axs[1].contourf(x, t, output.detach(), cmap="jet", levels=200)
            axs[1].set_xlabel("x")
            axs[1].set_ylabel("t")
            plt.colorbar(im2, ax=axs[1])
            axs[1].grid(True, which="both", ls=":")
            axs[0].set_title("Exact Solution")
            axs[1].set_title("Approximate Solution")

            plt.show()

            err = (torch.mean((output - exact_output) ** 2) / torch.mean(exact_output ** 2)) ** 0.5 * 100
            print("L2 Relative Error Norm: ", err.item(), "%")

# %%
# Solve the heat equation:
# u_t = u_xx, (t,x) in [0, 0.1]x[-1,1]
# with zero dirichlet BC and
# u(x,0)= -sin(pi x)

n_int = 8192
n_sb = 4
n_tb = 4

pinn = Pinns(n_int, n_sb, n_tb)

# %%
# Plot the input training points
input_sb_, output_sb_ = pinn.add_spatial_boundary_points()
input_tb_, output_tb_ = pinn.add_temporal_boundary_points()
input_int_, output_int_ = pinn.add_interior_points()

plt.figure(figsize=(16, 8), dpi=150)
plt.scatter(input_sb_[:, 1].detach().numpy(), input_sb_[:, 0].detach().numpy(), label="Boundary Points")
plt.scatter(input_int_[:, 1].detach().numpy(), input_int_[:, 0].detach().numpy(), label="Interior Points")
plt.scatter(input_tb_[:, 1].detach().numpy(), input_tb_[:, 0].detach().numpy(), label="Initial Points")
plt.xlabel("x")
plt.ylabel("t")
plt.legend()
plt.show()

# %%
n_epochs = 1
optimizer_LBFGS = optim.LBFGS(pinn.approximate_solution.parameters(),
                              lr=float(0.5),
                              max_iter=10000,
                              max_eval=50000,
                              history_size=150,
                              line_search_fn="strong_wolfe",
                              tolerance_change=1.0 * np.finfo(float).eps)
optimizer_ADAM = optim.Adam(pinn.approximate_solution.parameters(),
                            lr=float(0.005))

# %%
hist = pinn.fit(num_epochs=n_epochs,
                optimizer=optimizer_LBFGS,
                verbose=True)

plt.figure(dpi=150)
plt.grid(True, which="both", ls=":")
plt.plot(np.arange(1, len(hist) + 1), hist, label="Train Loss")
plt.xscale("log")
plt.legend()
# Out:
# ################################  0  ################################
# Total loss:  2.1666 | PDE Loss:  2.1666 | Function Loss:  -14.9748
# Total loss:  2.162 | PDE Loss:  2.162 | Function Loss:  -14.9809
# Total loss:  2.122 | PDE Loss:  2.122 | Function Loss:  -15.0347
# Total loss:  2.0512 | PDE Loss:  2.0512 | Function Loss:  -15.1177
# Total loss:  1.929 | PDE Loss:  1.929 | Function Loss:  -15.238
# Total loss:  1.6435 | PDE Loss:  1.6435 | Function Loss:  -15.5016
# Total loss:  1.5395 | PDE Loss:  1.5395 | Function Loss:  -15.535
# Total loss:  1.5118 | PDE Loss:  1.5118 | Function Loss:  -15.5227
# Total loss:  1.5054 | PDE Loss:  1.5054 | Function Loss:  -15.518
# Total loss:  1.4931 | PDE Loss:  1.4931 | Function Loss:  -15.5122
# Total loss:  1.4887 | PDE Loss:  1.4887 | Function Loss:  -15.5038
# Total loss:  1.4868 | PDE Loss:  1.4868 | Function Loss:  -15.5017
# Total loss:  1.4858 | PDE Loss:  1.4858 | Function Loss:  -15.5005
# Total loss:  1.4854 | PDE Loss:  1.4854 | Function Loss:  -15.5033
# Total loss:  1.4852 | PDE Loss:  1.4852 | Function Loss:  -15.5046
# Total loss:  1.4852 | PDE Loss:  1.4852 | Function Loss:  -15.5064
# Total loss:  1.4851 | PDE Loss:  1.4851 | Function Loss:  -15.5073
# Total loss:  1.4851 | PDE Loss:  1.4851 | Function Loss:  -15.5079
# Total loss:  1.4851 | PDE Loss:  1.4851 | Function Loss:  -15.5084
# Total loss:  1.4851 | PDE Loss:  1.4851 | Function Loss:  -15.5087
# Total loss:  1.4851 | PDE Loss:  1.4851 | Function Loss:  -15.5092
# Total loss:  1.4851 | PDE Loss:  1.4851 | Function Loss:  -15.5097
# Total loss:  1.4851 | PDE Loss:  1.4851 | Function Loss:  -15.5103
# Total loss:  1.485 | PDE Loss:  1.485 | Function Loss:  -15.5107
# Total loss:  1.485 | PDE Loss:  1.485 | Function Loss:  -15.5116
# Total loss:  1.4849 | PDE Loss:  1.4849 | Function Loss:  -15.5123
# Total loss:  1.4848 | PDE Loss:  1.4848 | Function Loss:  -15.5131
# Total loss:  1.4847 | PDE Loss:  1.4847 | Function Loss:  -15.5123
# Total loss:  1.4845 | PDE Loss:  1.4845 | Function Loss:  -15.5031
# Total loss:  1.4844 | PDE Loss:  1.4844 | Function Loss:  -15.5066
# Total loss:  1.4843 | PDE Loss:  1.4843 | Function Loss:  -15.5052
# Total loss:  1.484 | PDE Loss:  1.484 | Function Loss:  -15.5052
# Total loss:  1.4836 | PDE Loss:  1.4836 | Function Loss:  -15.5063
# Total loss:  1.4825 | PDE Loss:  1.4825 | Function Loss:  -15.5171
# Total loss:  1.4819 | PDE Loss:  1.4819 | Function Loss:  -15.5238
# Total loss:  1.4817 | PDE Loss:  1.4817 | Function Loss:  -15.5357
# Total loss:  1.4814 | PDE Loss:  1.4814 | Function Loss:  -15.531
# Total loss:  1.48 | PDE Loss:  1.48 | Function Loss:  -15.5333
# Total loss:  1.4875 | PDE Loss:  1.4875 | Function Loss:  -15.5444
# Total loss:  1.4775 | PDE Loss:  1.4775 | Function Loss:  -15.538
# Total loss:  1.476 | PDE Loss:  1.476 | Function Loss:  -15.5326
# Total loss:  1.4754 | PDE Loss:  1.4754 | Function Loss:  -15.5309
# Total loss:  1.4739 | PDE Loss:  1.4739 | Function Loss:  -15.532
# Total loss:  1.4719 | PDE Loss:  1.4719 | Function Loss:  -15.5386
# Total loss:  1.4681 | PDE Loss:  1.4681 | Function Loss:  -15.5408
# Total loss:  1.4657 | PDE Loss:  1.4657 | Function Loss:  -15.5442
# Total loss:  1.464 | PDE Loss:  1.464 | Function Loss:  -15.5469
# Total loss:  1.4614 | PDE Loss:  1.4614 | Function Loss:  -15.5469
# Total loss:  1.4568 | PDE Loss:  1.4568 | Function Loss:  -15.5508
# Total loss:  1.4512 | PDE Loss:  1.4512 | Function Loss:  -15.5496
# Total loss:  1.4489 | PDE Loss:  1.4489 | Function Loss:  -15.5544
# Total loss:  1.4409 | PDE Loss:  1.4409 | Function Loss:  -15.5441
# Total loss:  1.4332 | PDE Loss:  1.4332 | Function Loss:  -15.5541
# Total loss:  1.4254 | PDE Loss:  1.4254 | Function Loss:  -15.5561
# Total loss:  1.4114 | PDE Loss:  1.4114 | Function Loss:  -15.5671
# Total loss:  1.4001 | PDE Loss:  1.4001 | Function Loss:  -15.5856
# Total loss:  1.3837 | PDE Loss:  1.3837 | Function Loss:  -15.5877
# Total loss:  1.372 | PDE Loss:  1.372 | Function Loss:  -15.6056
# Total loss:  1.3472 | PDE Loss:  1.3472 | Function Loss:  -15.6581
# Total loss:  1.3674 | PDE Loss:  1.3674 | Function Loss:  -15.561
# Total loss:  1.3332 | PDE Loss:  1.3332 | Function Loss:  -15.6101
# Total loss:  1.3275 | PDE Loss:  1.3275 | Function Loss:  -15.577
# Total loss:  1.3243 | PDE Loss:  1.3243 | Function Loss:  -15.5681
# Total loss:  1.3204 | PDE Loss:  1.3204 | Function Loss:  -15.5887
# Total loss:  1.3147 | PDE Loss:  1.3147 | Function Loss:  -15.6001
# Total loss:  1.3079 | PDE Loss:  1.3079 | Function Loss:  -15.6143
# Total loss:  1.3006 | PDE Loss:  1.3006 | Function Loss:  -15.6203
# Total loss:  1.2951 | PDE Loss:  1.2951 | Function Loss:  -15.6171
# Total loss:  1.2819 | PDE Loss:  1.2819 | Function Loss:  -15.6415
# Total loss:  1.2743 | PDE Loss:  1.2743 | Function Loss:  -15.6623
# Total loss:  1.2692 | PDE Loss:  1.2692 | Function Loss:  -15.6683
# Total loss:  1.2667 | PDE Loss:  1.2667 | Function Loss:  -15.6883
# Total loss:  1.2605 | PDE Loss:  1.2605 | Function Loss:  -15.6909
# Total loss:  1.2556 | PDE Loss:  1.2556 | Function Loss:  -15.6869
# Total loss:  1.2513 | PDE Loss:  1.2513 | Function Loss:  -15.689
# Total loss:  1.2422 | PDE Loss:  1.2422 | Function Loss:  -15.7004
# Total loss:  1.2402 | PDE Loss:  1.2402 | Function Loss:  -15.7053
# Total loss:  1.2256 | PDE Loss:  1.2256 | Function Loss:  -15.7095
# Total loss:  1.2087 | PDE Loss:  1.2087 | Function Loss:  -15.7172
# Total loss:  2.0234 | PDE Loss:  2.0234 | Function Loss:  -15.2654
# Total loss:  1.2053 | PDE Loss:  1.2053 | Function Loss:  -15.7201
# Total loss:  1.1892 | PDE Loss:  1.1892 | Function Loss:  -15.7387
# Total loss:  1.1674 | PDE Loss:  1.1674 | Function Loss:  -15.7447
# Total loss:  1.1659 | PDE Loss:  1.1659 | Function Loss:  -15.7601
# Total loss:  1.145 | PDE Loss:  1.145 | Function Loss:  -15.752
# Total loss:  1.1271 | PDE Loss:  1.1271 | Function Loss:  -15.7684
# Total loss:  1.1149 | PDE Loss:  1.1149 | Function Loss:  -15.7873
# Total loss:  1.0946 | PDE Loss:  1.0946 | Function Loss:  -15.7933
# Total loss:  1.0743 | PDE Loss:  1.0743 | Function Loss:  -15.7914
# Total loss:  1.0507 | PDE Loss:  1.0507 | Function Loss:  -15.8054
# Total loss:  1.0229 | PDE Loss:  1.0229 | Function Loss:  -15.8099
# Total loss:  1.0091 | PDE Loss:  1.0091 | Function Loss:  -15.8139
# Total loss:  0.9919 | PDE Loss:  0.9919 | Function Loss:  -15.8285
# Total loss:  0.9815 | PDE Loss:  0.9815 | Function Loss:  -15.8258
# Total loss:  0.9708 | PDE Loss:  0.9708 | Function Loss:  -15.8231
# Total loss:  0.9465 | PDE Loss:  0.9465 | Function Loss:  -15.8154
# Total loss:  0.9254 | PDE Loss:  0.9254 | Function Loss:  -15.8069
# Total loss:  0.9102 | PDE Loss:  0.9102 | Function Loss:  -15.7956
# Total loss:  0.9014 | PDE Loss:  0.9014 | Function Loss:  -15.8188
# Total loss:  0.8842 | PDE Loss:  0.8842 | Function Loss:  -15.8158
# Total loss:  0.8727 | PDE Loss:  0.8727 | Function Loss:  -15.8149
# Total loss:  0.8585 | PDE Loss:  0.8585 | Function Loss:  -15.8209
# Total loss:  0.8349 | PDE Loss:  0.8349 | Function Loss:  -15.8316
# Total loss:  0.802 | PDE Loss:  0.802 | Function Loss:  -15.8491
# Total loss:  0.7719 | PDE Loss:  0.7719 | Function Loss:  -15.8533
# Total loss:  0.7122 | PDE Loss:  0.7122 | Function Loss:  -15.9007
# Total loss:  0.6861 | PDE Loss:  0.6861 | Function Loss:  -15.896
# Total loss:  0.6883 | PDE Loss:  0.6883 | Function Loss:  -15.9173
# Total loss:  0.6473 | PDE Loss:  0.6473 | Function Loss:  -15.9072
# Total loss:  0.6278 | PDE Loss:  0.6278 | Function Loss:  -15.8859
# Total loss:  0.6217 | PDE Loss:  0.6217 | Function Loss:  -15.8293
# Total loss:  0.598 | PDE Loss:  0.598 | Function Loss:  -15.852
# Total loss:  0.5906 | PDE Loss:  0.5906 | Function Loss:  -15.8643
# Total loss:  0.5756 | PDE Loss:  0.5756 | Function Loss:  -15.8712
# Total loss:  0.5634 | PDE Loss:  0.5634 | Function Loss:  -15.8692
# Total loss:  0.5549 | PDE Loss:  0.5549 | Function Loss:  -15.8647
# Total loss:  0.5422 | PDE Loss:  0.5422 | Function Loss:  -15.8636
# Total loss:  0.5336 | PDE Loss:  0.5336 | Function Loss:  -15.867
# Total loss:  0.5224 | PDE Loss:  0.5224 | Function Loss:  -15.86
# Total loss:  0.5157 | PDE Loss:  0.5157 | Function Loss:  -15.8566
# Total loss:  0.5107 | PDE Loss:  0.5107 | Function Loss:  -15.8639
# Total loss:  0.5047 | PDE Loss:  0.5047 | Function Loss:  -15.8588
# Total loss:  0.4937 | PDE Loss:  0.4937 | Function Loss:  -15.8582
# Total loss:  0.477 | PDE Loss:  0.477 | Function Loss:  -15.8542
# Total loss:  0.4566 | PDE Loss:  0.4566 | Function Loss:  -15.8414
# Total loss:  0.4417 | PDE Loss:  0.4417 | Function Loss:  -15.8363
# Total loss:  0.5008 | PDE Loss:  0.5008 | Function Loss:  -15.8205
# Total loss:  0.4323 | PDE Loss:  0.4323 | Function Loss:  -15.8328
# Total loss:  0.4373 | PDE Loss:  0.4373 | Function Loss:  -15.7999
# Total loss:  0.4195 | PDE Loss:  0.4195 | Function Loss:  -15.8168
# Total loss:  0.3987 | PDE Loss:  0.3987 | Function Loss:  -15.8383
# Total loss:  0.3826 | PDE Loss:  0.3826 | Function Loss:  -15.8636
# Total loss:  0.3621 | PDE Loss:  0.3621 | Function Loss:  -15.8781
# Total loss:  0.3406 | PDE Loss:  0.3406 | Function Loss:  -15.916
# Total loss:  0.3254 | PDE Loss:  0.3254 | Function Loss:  -15.8831
# Total loss:  0.2886 | PDE Loss:  0.2886 | Function Loss:  -15.8964
# Total loss:  0.3483 | PDE Loss:  0.3483 | Function Loss:  -15.9221
# Total loss:  0.2776 | PDE Loss:  0.2776 | Function Loss:  -15.9076
# Total loss:  0.2719 | PDE Loss:  0.2719 | Function Loss:  -15.9242
# Total loss:  0.2629 | PDE Loss:  0.2629 | Function Loss:  -15.9168
# Total loss:  0.249 | PDE Loss:  0.249 | Function Loss:  -15.9074
# Total loss:  0.2341 | PDE Loss:  0.2341 | Function Loss:  -15.9129
# Total loss:  0.2121 | PDE Loss:  0.2121 | Function Loss:  -15.9074
# Total loss:  0.1969 | PDE Loss:  0.1969 | Function Loss:  -15.9058
# Total loss:  0.1841 | PDE Loss:  0.1841 | Function Loss:  -15.9072
# Total loss:  0.1712 | PDE Loss:  0.1712 | Function Loss:  -15.9083
# Total loss:  0.1534 | PDE Loss:  0.1534 | Function Loss:  -15.9122
# Total loss:  0.1392 | PDE Loss:  0.1392 | Function Loss:  -15.9204
# Total loss:  0.1248 | PDE Loss:  0.1248 | Function Loss:  -15.9243
# Total loss:  0.1107 | PDE Loss:  0.1107 | Function Loss:  -15.9312
# Total loss:  0.098 | PDE Loss:  0.098 | Function Loss:  -15.934
# Total loss:  0.085 | PDE Loss:  0.085 | Function Loss:  -15.9392
# Total loss:  0.0668 | PDE Loss:  0.0668 | Function Loss:  -15.9412
# Total loss:  0.0481 | PDE Loss:  0.0481 | Function Loss:  -15.9446
# Total loss:  0.0322 | PDE Loss:  0.0322 | Function Loss:  -15.9463
# Total loss:  0.014 | PDE Loss:  0.014 | Function Loss:  -15.9497
# Total loss:  0.0346 | PDE Loss:  0.0346 | Function Loss:  -15.9194
# Total loss:  0.0002 | PDE Loss:  0.0002 | Function Loss:  -15.9408
# Total loss:  -0.0038 | PDE Loss:  -0.0038 | Function Loss:  -15.9431
# Total loss:  -0.0109 | PDE Loss:  -0.0109 | Function Loss:  -15.9448
# Total loss:  -0.0179 | PDE Loss:  -0.0179 | Function Loss:  -15.9445
# Total loss:  -0.0239 | PDE Loss:  -0.0239 | Function Loss:  -15.9441
# Total loss:  -0.03 | PDE Loss:  -0.03 | Function Loss:  -15.9431
# Total loss:  -0.0375 | PDE Loss:  -0.0375 | Function Loss:  -15.9427
# Total loss:  -0.045 | PDE Loss:  -0.045 | Function Loss:  -15.9422
# Total loss:  -0.0509 | PDE Loss:  -0.0509 | Function Loss:  -15.9415
# Total loss:  -0.0563 | PDE Loss:  -0.0563 | Function Loss:  -15.9386
# Total loss:  -0.0601 | PDE Loss:  -0.0601 | Function Loss:  -15.938
# Total loss:  -0.0647 | PDE Loss:  -0.0647 | Function Loss:  -15.936
# Total loss:  -0.0707 | PDE Loss:  -0.0707 | Function Loss:  -15.9376
# Total loss:  -0.0791 | PDE Loss:  -0.0791 | Function Loss:  -15.936
# Total loss:  -0.0895 | PDE Loss:  -0.0895 | Function Loss:  -15.9361
# Total loss:  -0.1038 | PDE Loss:  -0.1038 | Function Loss:  -15.9397
# Total loss:  -0.1156 | PDE Loss:  -0.1156 | Function Loss:  -15.9363
# Total loss:  -0.1237 | PDE Loss:  -0.1237 | Function Loss:  -15.9369
# Total loss:  -0.1358 | PDE Loss:  -0.1358 | Function Loss:  -15.9336
# Total loss:  -0.1533 | PDE Loss:  -0.1533 | Function Loss:  -15.9312
# Total loss:  -0.1707 | PDE Loss:  -0.1707 | Function Loss:  -15.9283
# Total loss:  -0.1256 | PDE Loss:  -0.1256 | Function Loss:  -15.9227
# Total loss:  -0.1768 | PDE Loss:  -0.1768 | Function Loss:  -15.9276
# Total loss:  -0.1857 | PDE Loss:  -0.1857 | Function Loss:  -15.9312
# Total loss:  -0.1944 | PDE Loss:  -0.1944 | Function Loss:  -15.9291
# Total loss:  -0.2035 | PDE Loss:  -0.2035 | Function Loss:  -15.9345
# Total loss:  -0.2159 | PDE Loss:  -0.2159 | Function Loss:  -15.9379
# Total loss:  -0.2318 | PDE Loss:  -0.2318 | Function Loss:  -15.9421
# Total loss:  -0.2444 | PDE Loss:  -0.2444 | Function Loss:  -15.9395
# Total loss:  -0.2539 | PDE Loss:  -0.2539 | Function Loss:  -15.9403
# Total loss:  -0.2611 | PDE Loss:  -0.2611 | Function Loss:  -15.9404
# Total loss:  -0.2698 | PDE Loss:  -0.2698 | Function Loss:  -15.9375
# Total loss:  -0.2753 | PDE Loss:  -0.2753 | Function Loss:  -15.9355
# Total loss:  -0.2798 | PDE Loss:  -0.2798 | Function Loss:  -15.9345
# Total loss:  -0.285 | PDE Loss:  -0.285 | Function Loss:  -15.9343
# Total loss:  -0.2926 | PDE Loss:  -0.2926 | Function Loss:  -15.9353
# Total loss:  -0.3021 | PDE Loss:  -0.3021 | Function Loss:  -15.936
# Total loss:  -0.3156 | PDE Loss:  -0.3156 | Function Loss:  -15.9362
# Total loss:  -0.3287 | PDE Loss:  -0.3287 | Function Loss:  -15.9375
# Total loss:  -0.3381 | PDE Loss:  -0.3381 | Function Loss:  -15.9321
# Total loss:  -0.3429 | PDE Loss:  -0.3429 | Function Loss:  -15.9329
# Total loss:  -0.3486 | PDE Loss:  -0.3486 | Function Loss:  -15.9334
# Total loss:  -0.3531 | PDE Loss:  -0.3531 | Function Loss:  -15.9325
# Total loss:  -0.3574 | PDE Loss:  -0.3574 | Function Loss:  -15.9323
# Total loss:  -0.3622 | PDE Loss:  -0.3622 | Function Loss:  -15.9319
# Total loss:  -0.3671 | PDE Loss:  -0.3671 | Function Loss:  -15.9309
# Total loss:  -0.3769 | PDE Loss:  -0.3769 | Function Loss:  -15.9317
# Total loss:  -0.3866 | PDE Loss:  -0.3866 | Function Loss:  -15.9329
# Total loss:  -0.3955 | PDE Loss:  -0.3955 | Function Loss:  -15.9355
# Total loss:  -0.4016 | PDE Loss:  -0.4016 | Function Loss:  -15.9371
# Total loss:  -0.4098 | PDE Loss:  -0.4098 | Function Loss:  -15.9377
# Total loss:  -0.4172 | PDE Loss:  -0.4172 | Function Loss:  -15.9411
# Total loss:  -0.4239 | PDE Loss:  -0.4239 | Function Loss:  -15.9417
# Total loss:  -0.4307 | PDE Loss:  -0.4307 | Function Loss:  -15.9414
# Total loss:  -0.4358 | PDE Loss:  -0.4358 | Function Loss:  -15.9418
# Total loss:  -0.4413 | PDE Loss:  -0.4413 | Function Loss:  -15.9409
# Total loss:  -0.447 | PDE Loss:  -0.447 | Function Loss:  -15.9405
# Total loss:  -0.4521 | PDE Loss:  -0.4521 | Function Loss:  -15.9401
# Total loss:  -0.4559 | PDE Loss:  -0.4559 | Function Loss:  -15.9409
# Total loss:  -0.4593 | PDE Loss:  -0.4593 | Function Loss:  -15.941
# Total loss:  -0.4618 | PDE Loss:  -0.4618 | Function Loss:  -15.9417
# Total loss:  -0.4661 | PDE Loss:  -0.4661 | Function Loss:  -15.9434
# Total loss:  -0.471 | PDE Loss:  -0.471 | Function Loss:  -15.9446
# Total loss:  -0.4747 | PDE Loss:  -0.4747 | Function Loss:  -15.9457
# Total loss:  -0.4781 | PDE Loss:  -0.4781 | Function Loss:  -15.9462
# Total loss:  -0.4823 | PDE Loss:  -0.4823 | Function Loss:  -15.9464
# Total loss:  -0.4872 | PDE Loss:  -0.4872 | Function Loss:  -15.9457
# Total loss:  -0.4918 | PDE Loss:  -0.4918 | Function Loss:  -15.9466
# Total loss:  -0.4963 | PDE Loss:  -0.4963 | Function Loss:  -15.945
# Total loss:  -0.5002 | PDE Loss:  -0.5002 | Function Loss:  -15.9454
# Total loss:  -0.5036 | PDE Loss:  -0.5036 | Function Loss:  -15.9452
# Total loss:  -0.5088 | PDE Loss:  -0.5088 | Function Loss:  -15.9464
# Total loss:  -0.5149 | PDE Loss:  -0.5149 | Function Loss:  -15.9478
# Total loss:  -0.5207 | PDE Loss:  -0.5207 | Function Loss:  -15.9488
# Total loss:  -0.5243 | PDE Loss:  -0.5243 | Function Loss:  -15.95
# Total loss:  -0.5268 | PDE Loss:  -0.5268 | Function Loss:  -15.9495
# Total loss:  -0.5308 | PDE Loss:  -0.5308 | Function Loss:  -15.9501
# Total loss:  -0.5356 | PDE Loss:  -0.5356 | Function Loss:  -15.9505
# Total loss:  -0.5432 | PDE Loss:  -0.5432 | Function Loss:  -15.9505
# Total loss:  -0.5557 | PDE Loss:  -0.5557 | Function Loss:  -15.9499
# Total loss:  -0.5667 | PDE Loss:  -0.5667 | Function Loss:  -15.9506
# Total loss:  -0.5661 | PDE Loss:  -0.5661 | Function Loss:  -15.9481
# Total loss:  -0.5727 | PDE Loss:  -0.5727 | Function Loss:  -15.9495
# Total loss:  -0.5795 | PDE Loss:  -0.5795 | Function Loss:  -15.9496
# Total loss:  -0.5873 | PDE Loss:  -0.5873 | Function Loss:  -15.9501
# Total loss:  -0.5913 | PDE Loss:  -0.5913 | Function Loss:  -15.9504
# Total loss:  -0.5953 | PDE Loss:  -0.5953 | Function Loss:  -15.9504
# Total loss:  -0.6003 | PDE Loss:  -0.6003 | Function Loss:  -15.9506
# Total loss:  -0.6057 | PDE Loss:  -0.6057 | Function Loss:  -15.9506
# Total loss:  -0.6143 | PDE Loss:  -0.6143 | Function Loss:  -15.9493
# Total loss:  -0.6165 | PDE Loss:  -0.6165 | Function Loss:  -15.949
# Total loss:  -0.6189 | PDE Loss:  -0.6189 | Function Loss:  -15.949
# Total loss:  -0.6254 | PDE Loss:  -0.6254 | Function Loss:  -15.9476
# Total loss:  -0.6337 | PDE Loss:  -0.6337 | Function Loss:  -15.9461
# Total loss:  -0.6409 | PDE Loss:  -0.6409 | Function Loss:  -15.945
# Total loss:  -0.6459 | PDE Loss:  -0.6459 | Function Loss:  -15.9458
# Total loss:  -0.6499 | PDE Loss:  -0.6499 | Function Loss:  -15.9472
# Total loss:  -0.6546 | PDE Loss:  -0.6546 | Function Loss:  -15.9491
# Total loss:  -0.6582 | PDE Loss:  -0.6582 | Function Loss:  -15.9492
# Total loss:  -0.6629 | PDE Loss:  -0.6629 | Function Loss:  -15.9489
# Total loss:  -0.6719 | PDE Loss:  -0.6719 | Function Loss:  -15.9478
# Total loss:  -0.6831 | PDE Loss:  -0.6831 | Function Loss:  -15.9476
# Total loss:  -0.6899 | PDE Loss:  -0.6899 | Function Loss:  -15.947
# Total loss:  -0.6942 | PDE Loss:  -0.6942 | Function Loss:  -15.9463
# Total loss:  -0.6981 | PDE Loss:  -0.6981 | Function Loss:  -15.9466
# Total loss:  -0.7016 | PDE Loss:  -0.7016 | Function Loss:  -15.9469
# Total loss:  -0.7057 | PDE Loss:  -0.7057 | Function Loss:  -15.9464
# Total loss:  -0.7098 | PDE Loss:  -0.7098 | Function Loss:  -15.9471
# Total loss:  -0.712 | PDE Loss:  -0.712 | Function Loss:  -15.9469
# Total loss:  -0.7141 | PDE Loss:  -0.7141 | Function Loss:  -15.9465
# Total loss:  -0.717 | PDE Loss:  -0.717 | Function Loss:  -15.9463
# Total loss:  -0.721 | PDE Loss:  -0.721 | Function Loss:  -15.9459
# Total loss:  -0.7268 | PDE Loss:  -0.7268 | Function Loss:  -15.9458
# Total loss:  -0.7329 | PDE Loss:  -0.7329 | Function Loss:  -15.9455
# Total loss:  -0.7396 | PDE Loss:  -0.7396 | Function Loss:  -15.9453
# Total loss:  -0.7436 | PDE Loss:  -0.7436 | Function Loss:  -15.9453
# Total loss:  -0.7475 | PDE Loss:  -0.7475 | Function Loss:  -15.9449
# Total loss:  -0.75 | PDE Loss:  -0.75 | Function Loss:  -15.9452
# Total loss:  -0.7528 | PDE Loss:  -0.7528 | Function Loss:  -15.9454
# Total loss:  -0.7552 | PDE Loss:  -0.7552 | Function Loss:  -15.9458
# Total loss:  -0.7574 | PDE Loss:  -0.7574 | Function Loss:  -15.9459
# Total loss:  -0.7592 | PDE Loss:  -0.7592 | Function Loss:  -15.9464
# Total loss:  -0.7606 | PDE Loss:  -0.7606 | Function Loss:  -15.9463
# Total loss:  -0.762 | PDE Loss:  -0.762 | Function Loss:  -15.9463
# Total loss:  -0.7632 | PDE Loss:  -0.7632 | Function Loss:  -15.9461
# Total loss:  -0.7642 | PDE Loss:  -0.7642 | Function Loss:  -15.946
# Total loss:  -0.7652 | PDE Loss:  -0.7652 | Function Loss:  -15.9459
# Total loss:  -0.7664 | PDE Loss:  -0.7664 | Function Loss:  -15.9458
# Total loss:  -0.768 | PDE Loss:  -0.768 | Function Loss:  -15.9458
# Total loss:  -0.7705 | PDE Loss:  -0.7705 | Function Loss:  -15.9457
# Total loss:  -0.7739 | PDE Loss:  -0.7739 | Function Loss:  -15.9457
# Total loss:  -0.7781 | PDE Loss:  -0.7781 | Function Loss:  -15.9456
# Total loss:  -0.7831 | PDE Loss:  -0.7831 | Function Loss:  -15.9456
# Total loss:  -0.7874 | PDE Loss:  -0.7874 | Function Loss:  -15.9457
# Total loss:  -0.7903 | PDE Loss:  -0.7903 | Function Loss:  -15.9456
# Total loss:  -0.7922 | PDE Loss:  -0.7922 | Function Loss:  -15.9458
# Total loss:  -0.7936 | PDE Loss:  -0.7936 | Function Loss:  -15.9457
# Total loss:  -0.7951 | PDE Loss:  -0.7951 | Function Loss:  -15.9458
# Total loss:  -0.7968 | PDE Loss:  -0.7968 | Function Loss:  -15.9459
# Total loss:  -0.7987 | PDE Loss:  -0.7987 | Function Loss:  -15.9459
# Total loss:  -0.8008 | PDE Loss:  -0.8008 | Function Loss:  -15.9461
# Total loss:  -0.803 | PDE Loss:  -0.803 | Function Loss:  -15.9462
# Total loss:  -0.8053 | PDE Loss:  -0.8053 | Function Loss:  -15.9465
# Total loss:  -0.8086 | PDE Loss:  -0.8086 | Function Loss:  -15.9465
# Total loss:  -0.8127 | PDE Loss:  -0.8127 | Function Loss:  -15.9467
# Total loss:  -0.8159 | PDE Loss:  -0.8159 | Function Loss:  -15.9467
# Total loss:  -0.8183 | PDE Loss:  -0.8183 | Function Loss:  -15.9469
# Total loss:  -0.8202 | PDE Loss:  -0.8202 | Function Loss:  -15.9467
# Total loss:  -0.8213 | PDE Loss:  -0.8213 | Function Loss:  -15.9467
# Total loss:  -0.8226 | PDE Loss:  -0.8226 | Function Loss:  -15.9467
# Total loss:  -0.8251 | PDE Loss:  -0.8251 | Function Loss:  -15.9466
# Total loss:  -0.8277 | PDE Loss:  -0.8277 | Function Loss:  -15.9465
# Total loss:  -0.8301 | PDE Loss:  -0.8301 | Function Loss:  -15.9462
# Total loss:  -0.8327 | PDE Loss:  -0.8327 | Function Loss:  -15.9461
# Total loss:  -0.8369 | PDE Loss:  -0.8369 | Function Loss:  -15.9459
# Total loss:  -0.8426 | PDE Loss:  -0.8426 | Function Loss:  -15.9458
# Total loss:  -0.8497 | PDE Loss:  -0.8497 | Function Loss:  -15.9455
# Total loss:  -0.8563 | PDE Loss:  -0.8563 | Function Loss:  -15.9453
# Total loss:  -0.8637 | PDE Loss:  -0.8637 | Function Loss:  -15.9451
# Total loss:  -0.8704 | PDE Loss:  -0.8704 | Function Loss:  -15.945
# Total loss:  -0.8763 | PDE Loss:  -0.8763 | Function Loss:  -15.9446
# Total loss:  -0.8808 | PDE Loss:  -0.8808 | Function Loss:  -15.9448
# Total loss:  -0.8845 | PDE Loss:  -0.8845 | Function Loss:  -15.9444
# Total loss:  -0.8872 | PDE Loss:  -0.8872 | Function Loss:  -15.9444
# Total loss:  -0.8914 | PDE Loss:  -0.8914 | Function Loss:  -15.9445
# Total loss:  -0.8999 | PDE Loss:  -0.8999 | Function Loss:  -15.9451
# Total loss:  -0.9063 | PDE Loss:  -0.9063 | Function Loss:  -15.9447
# Total loss:  -0.9109 | PDE Loss:  -0.9109 | Function Loss:  -15.945
# Total loss:  -0.9172 | PDE Loss:  -0.9172 | Function Loss:  -15.9451
# Total loss:  -0.9234 | PDE Loss:  -0.9234 | Function Loss:  -15.945
# Total loss:  -0.9268 | PDE Loss:  -0.9268 | Function Loss:  -15.9449
# Total loss:  -0.9288 | PDE Loss:  -0.9288 | Function Loss:  -15.9448
# Total loss:  -0.9313 | PDE Loss:  -0.9313 | Function Loss:  -15.9446
# Total loss:  -0.9341 | PDE Loss:  -0.9341 | Function Loss:  -15.9446
# Total loss:  -0.9368 | PDE Loss:  -0.9368 | Function Loss:  -15.9444
# Total loss:  -0.9399 | PDE Loss:  -0.9399 | Function Loss:  -15.9444
# Total loss:  -0.944 | PDE Loss:  -0.944 | Function Loss:  -15.9442
# Total loss:  -0.9474 | PDE Loss:  -0.9474 | Function Loss:  -15.9444
# Total loss:  -0.951 | PDE Loss:  -0.951 | Function Loss:  -15.9445
# Total loss:  -0.9553 | PDE Loss:  -0.9553 | Function Loss:  -15.9448
# Total loss:  -0.9594 | PDE Loss:  -0.9594 | Function Loss:  -15.9447
# Total loss:  -0.9636 | PDE Loss:  -0.9636 | Function Loss:  -15.9452
# Total loss:  -0.9663 | PDE Loss:  -0.9663 | Function Loss:  -15.9451
# Total loss:  -0.9702 | PDE Loss:  -0.9702 | Function Loss:  -15.9453
# Total loss:  -0.9737 | PDE Loss:  -0.9737 | Function Loss:  -15.9456
# Total loss:  -0.9765 | PDE Loss:  -0.9765 | Function Loss:  -15.9459
# Total loss:  -0.9787 | PDE Loss:  -0.9787 | Function Loss:  -15.946
# Total loss:  -0.9808 | PDE Loss:  -0.9808 | Function Loss:  -15.9464
# Total loss:  -0.9829 | PDE Loss:  -0.9829 | Function Loss:  -15.9466
# Total loss:  -0.9855 | PDE Loss:  -0.9855 | Function Loss:  -15.9466
# Total loss:  -0.9903 | PDE Loss:  -0.9903 | Function Loss:  -15.9471
# Total loss:  -0.9953 | PDE Loss:  -0.9953 | Function Loss:  -15.9468
# Total loss:  -0.9989 | PDE Loss:  -0.9989 | Function Loss:  -15.9467
# Total loss:  -1.0024 | PDE Loss:  -1.0024 | Function Loss:  -15.9468
# Total loss:  -1.0054 | PDE Loss:  -1.0054 | Function Loss:  -15.9459
# Total loss:  -1.0068 | PDE Loss:  -1.0068 | Function Loss:  -15.9459
# Total loss:  -1.0083 | PDE Loss:  -1.0083 | Function Loss:  -15.9458
# Total loss:  -1.0106 | PDE Loss:  -1.0106 | Function Loss:  -15.9458
# Total loss:  -1.0135 | PDE Loss:  -1.0135 | Function Loss:  -15.9458
# Total loss:  -1.0164 | PDE Loss:  -1.0164 | Function Loss:  -15.9461
# Total loss:  -1.0185 | PDE Loss:  -1.0185 | Function Loss:  -15.946
# Total loss:  -1.0197 | PDE Loss:  -1.0197 | Function Loss:  -15.9462
# Total loss:  -1.0206 | PDE Loss:  -1.0206 | Function Loss:  -15.9464
# Total loss:  -1.0214 | PDE Loss:  -1.0214 | Function Loss:  -15.9463
# Total loss:  -1.0223 | PDE Loss:  -1.0223 | Function Loss:  -15.9464
# Total loss:  -1.0231 | PDE Loss:  -1.0231 | Function Loss:  -15.9463
# Total loss:  -1.024 | PDE Loss:  -1.024 | Function Loss:  -15.9463
# Total loss:  -1.0252 | PDE Loss:  -1.0252 | Function Loss:  -15.9461
# Total loss:  -1.0264 | PDE Loss:  -1.0264 | Function Loss:  -15.946
# Total loss:  -1.0278 | PDE Loss:  -1.0278 | Function Loss:  -15.946
# Total loss:  -1.0298 | PDE Loss:  -1.0298 | Function Loss:  -15.9462
# Total loss:  -1.0323 | PDE Loss:  -1.0323 | Function Loss:  -15.9463
# Total loss:  -1.0352 | PDE Loss:  -1.0352 | Function Loss:  -15.9465
# Total loss:  -1.0385 | PDE Loss:  -1.0385 | Function Loss:  -15.9468
# Total loss:  -1.0418 | PDE Loss:  -1.0418 | Function Loss:  -15.9469
# Total loss:  -1.0445 | PDE Loss:  -1.0445 | Function Loss:  -15.9471
# Total loss:  -1.0467 | PDE Loss:  -1.0467 | Function Loss:  -15.9471
# Total loss:  -1.0486 | PDE Loss:  -1.0486 | Function Loss:  -15.947
# Total loss:  -1.0511 | PDE Loss:  -1.0511 | Function Loss:  -15.947
# Total loss:  -1.055 | PDE Loss:  -1.055 | Function Loss:  -15.9467
# Total loss:  -1.0597 | PDE Loss:  -1.0597 | Function Loss:  -15.9467
# Total loss:  -1.0641 | PDE Loss:  -1.0641 | Function Loss:  -15.9464
# Total loss:  -1.0677 | PDE Loss:  -1.0677 | Function Loss:  -15.9462
# Total loss:  -1.0708 | PDE Loss:  -1.0708 | Function Loss:  -15.9458
# Total loss:  -1.0737 | PDE Loss:  -1.0737 | Function Loss:  -15.9456
# Total loss:  -1.0763 | PDE Loss:  -1.0763 | Function Loss:  -15.9454
# Total loss:  -1.0792 | PDE Loss:  -1.0792 | Function Loss:  -15.9449
# Total loss:  -1.0815 | PDE Loss:  -1.0815 | Function Loss:  -15.9452
# Total loss:  -1.0835 | PDE Loss:  -1.0835 | Function Loss:  -15.9451
# Total loss:  -1.0854 | PDE Loss:  -1.0854 | Function Loss:  -15.9451
# Total loss:  -1.0871 | PDE Loss:  -1.0871 | Function Loss:  -15.9451
# Total loss:  -1.089 | PDE Loss:  -1.089 | Function Loss:  -15.9452
# Total loss:  -1.0914 | PDE Loss:  -1.0914 | Function Loss:  -15.9452
# Total loss:  -1.0942 | PDE Loss:  -1.0942 | Function Loss:  -15.9452
# Total loss:  -1.0966 | PDE Loss:  -1.0966 | Function Loss:  -15.9453
# Total loss:  -1.0987 | PDE Loss:  -1.0987 | Function Loss:  -15.9454
# Total loss:  -1.1005 | PDE Loss:  -1.1005 | Function Loss:  -15.9455
# Total loss:  -1.102 | PDE Loss:  -1.102 | Function Loss:  -15.9456
# Total loss:  -1.104 | PDE Loss:  -1.104 | Function Loss:  -15.9457
# Total loss:  -1.1055 | PDE Loss:  -1.1055 | Function Loss:  -15.9458
# Total loss:  -1.1068 | PDE Loss:  -1.1068 | Function Loss:  -15.9457
# Total loss:  -1.1077 | PDE Loss:  -1.1077 | Function Loss:  -15.9458
# Total loss:  -1.1088 | PDE Loss:  -1.1088 | Function Loss:  -15.9457
# Total loss:  -1.1098 | PDE Loss:  -1.1098 | Function Loss:  -15.9458
# Total loss:  -1.1109 | PDE Loss:  -1.1109 | Function Loss:  -15.9458
# Total loss:  -1.1122 | PDE Loss:  -1.1122 | Function Loss:  -15.9459
# Total loss:  -1.114 | PDE Loss:  -1.114 | Function Loss:  -15.9458
# Total loss:  -1.1157 | PDE Loss:  -1.1157 | Function Loss:  -15.9459
# Total loss:  -1.1176 | PDE Loss:  -1.1176 | Function Loss:  -15.9459
# Total loss:  -1.1199 | PDE Loss:  -1.1199 | Function Loss:  -15.946
# Total loss:  -1.1223 | PDE Loss:  -1.1223 | Function Loss:  -15.9461
# Total loss:  -1.1248 | PDE Loss:  -1.1248 | Function Loss:  -15.946
# Total loss:  -1.1275 | PDE Loss:  -1.1275 | Function Loss:  -15.9463
# Total loss:  -1.1301 | PDE Loss:  -1.1301 | Function Loss:  -15.9462
# Total loss:  -1.132 | PDE Loss:  -1.132 | Function Loss:  -15.9464
# Total loss:  -1.1342 | PDE Loss:  -1.1342 | Function Loss:  -15.9465
# Total loss:  -1.1377 | PDE Loss:  -1.1377 | Function Loss:  -15.9465
# Total loss:  -1.1417 | PDE Loss:  -1.1417 | Function Loss:  -15.9465
# Total loss:  -1.1451 | PDE Loss:  -1.1451 | Function Loss:  -15.9459
# Total loss:  -1.1482 | PDE Loss:  -1.1482 | Function Loss:  -15.9461
# Total loss:  -1.1503 | PDE Loss:  -1.1503 | Function Loss:  -15.9462
# Total loss:  -1.1518 | PDE Loss:  -1.1518 | Function Loss:  -15.946
# Total loss:  -1.1525 | PDE Loss:  -1.1525 | Function Loss:  -15.9459
# Total loss:  -1.153 | PDE Loss:  -1.153 | Function Loss:  -15.946
# Total loss:  -1.1534 | PDE Loss:  -1.1534 | Function Loss:  -15.9459
# Total loss:  -1.1536 | PDE Loss:  -1.1536 | Function Loss:  -15.9459
# Total loss:  -1.1538 | PDE Loss:  -1.1538 | Function Loss:  -15.9458
# Total loss:  -1.1542 | PDE Loss:  -1.1542 | Function Loss:  -15.9458
# Total loss:  -1.1545 | PDE Loss:  -1.1545 | Function Loss:  -15.9458
# Total loss:  -1.1548 | PDE Loss:  -1.1548 | Function Loss:  -15.9458
# Total loss:  -1.1551 | PDE Loss:  -1.1551 | Function Loss:  -15.9457
# Total loss:  -1.1553 | PDE Loss:  -1.1553 | Function Loss:  -15.9457
# Total loss:  -1.1556 | PDE Loss:  -1.1556 | Function Loss:  -15.9457
# Total loss:  -1.1559 | PDE Loss:  -1.1559 | Function Loss:  -15.9456
# Total loss:  -1.1564 | PDE Loss:  -1.1564 | Function Loss:  -15.9456
# Total loss:  -1.1568 | PDE Loss:  -1.1568 | Function Loss:  -15.9456
# Total loss:  -1.1573 | PDE Loss:  -1.1573 | Function Loss:  -15.9456
# Total loss:  -1.158 | PDE Loss:  -1.158 | Function Loss:  -15.9456
# Total loss:  -1.1588 | PDE Loss:  -1.1588 | Function Loss:  -15.9456
# Total loss:  -1.1597 | PDE Loss:  -1.1597 | Function Loss:  -15.9457
# Total loss:  -1.1608 | PDE Loss:  -1.1608 | Function Loss:  -15.9458
# Total loss:  -1.1621 | PDE Loss:  -1.1621 | Function Loss:  -15.9458
# Total loss:  -1.1635 | PDE Loss:  -1.1635 | Function Loss:  -15.9459
# Total loss:  -1.1648 | PDE Loss:  -1.1648 | Function Loss:  -15.946
# Total loss:  -1.1662 | PDE Loss:  -1.1662 | Function Loss:  -15.9461
# Total loss:  -1.1673 | PDE Loss:  -1.1673 | Function Loss:  -15.946
# Total loss:  -1.1683 | PDE Loss:  -1.1683 | Function Loss:  -15.9461
# Total loss:  -1.169 | PDE Loss:  -1.169 | Function Loss:  -15.946
# Total loss:  -1.1702 | PDE Loss:  -1.1702 | Function Loss:  -15.9459
# Total loss:  -1.1718 | PDE Loss:  -1.1718 | Function Loss:  -15.9458
# Total loss:  -1.1739 | PDE Loss:  -1.1739 | Function Loss:  -15.9455
# Total loss:  -1.1761 | PDE Loss:  -1.1761 | Function Loss:  -15.9454
# Total loss:  -1.1777 | PDE Loss:  -1.1777 | Function Loss:  -15.9455
# Total loss:  -1.179 | PDE Loss:  -1.179 | Function Loss:  -15.9451
# Total loss:  -1.1816 | PDE Loss:  -1.1816 | Function Loss:  -15.9451
# Total loss:  -1.1833 | PDE Loss:  -1.1833 | Function Loss:  -15.9453
# Total loss:  -1.1846 | PDE Loss:  -1.1846 | Function Loss:  -15.9453
# Total loss:  -1.1854 | PDE Loss:  -1.1854 | Function Loss:  -15.9454
# Total loss:  -1.1862 | PDE Loss:  -1.1862 | Function Loss:  -15.9454
# Total loss:  -1.187 | PDE Loss:  -1.187 | Function Loss:  -15.9454
# Total loss:  -1.1879 | PDE Loss:  -1.1879 | Function Loss:  -15.9454
# Total loss:  -1.1888 | PDE Loss:  -1.1888 | Function Loss:  -15.9454
# Total loss:  -1.1895 | PDE Loss:  -1.1895 | Function Loss:  -15.9453
# Total loss:  -1.1901 | PDE Loss:  -1.1901 | Function Loss:  -15.9453
# Total loss:  -1.1907 | PDE Loss:  -1.1907 | Function Loss:  -15.9452
# Total loss:  -1.1915 | PDE Loss:  -1.1915 | Function Loss:  -15.9452
# Total loss:  -1.1927 | PDE Loss:  -1.1927 | Function Loss:  -15.9452
# Total loss:  -1.1949 | PDE Loss:  -1.1949 | Function Loss:  -15.9451
# Total loss:  -1.1974 | PDE Loss:  -1.1974 | Function Loss:  -15.9453
# Total loss:  -1.2 | PDE Loss:  -1.2 | Function Loss:  -15.9451
# Total loss:  -1.2029 | PDE Loss:  -1.2029 | Function Loss:  -15.9456
# Total loss:  -1.2045 | PDE Loss:  -1.2045 | Function Loss:  -15.9457
# Total loss:  -1.2065 | PDE Loss:  -1.2065 | Function Loss:  -15.9456
# Total loss:  -1.2082 | PDE Loss:  -1.2082 | Function Loss:  -15.9457
# Total loss:  -1.2099 | PDE Loss:  -1.2099 | Function Loss:  -15.9456
# Total loss:  -1.2114 | PDE Loss:  -1.2114 | Function Loss:  -15.9454
# Total loss:  -1.2131 | PDE Loss:  -1.2131 | Function Loss:  -15.9454
# Total loss:  -1.2143 | PDE Loss:  -1.2143 | Function Loss:  -15.9453
# Total loss:  -1.2159 | PDE Loss:  -1.2159 | Function Loss:  -15.9451
# Total loss:  -1.2177 | PDE Loss:  -1.2177 | Function Loss:  -15.9451
# Total loss:  -1.2185 | PDE Loss:  -1.2185 | Function Loss:  -15.9452
# Total loss:  -1.2197 | PDE Loss:  -1.2197 | Function Loss:  -15.9453
# Total loss:  -1.2204 | PDE Loss:  -1.2204 | Function Loss:  -15.9453
# Total loss:  -1.2212 | PDE Loss:  -1.2212 | Function Loss:  -15.9453
# Total loss:  -1.2219 | PDE Loss:  -1.2219 | Function Loss:  -15.9454
# Total loss:  -1.223 | PDE Loss:  -1.223 | Function Loss:  -15.9456
# Total loss:  -1.2234 | PDE Loss:  -1.2234 | Function Loss:  -15.9456
# Total loss:  -1.2242 | PDE Loss:  -1.2242 | Function Loss:  -15.9456
# Total loss:  -1.2249 | PDE Loss:  -1.2249 | Function Loss:  -15.9456
# Total loss:  -1.2255 | PDE Loss:  -1.2255 | Function Loss:  -15.9455
# Total loss:  -1.226 | PDE Loss:  -1.226 | Function Loss:  -15.9456
# Total loss:  -1.2266 | PDE Loss:  -1.2266 | Function Loss:  -15.9455
# Total loss:  -1.2277 | PDE Loss:  -1.2277 | Function Loss:  -15.9455
# Total loss:  -1.229 | PDE Loss:  -1.229 | Function Loss:  -15.9455
# Total loss:  -1.23 | PDE Loss:  -1.23 | Function Loss:  -15.9454
# Total loss:  -1.2307 | PDE Loss:  -1.2307 | Function Loss:  -15.9452
# Total loss:  -1.2314 | PDE Loss:  -1.2314 | Function Loss:  -15.9452
# Total loss:  -1.2321 | PDE Loss:  -1.2321 | Function Loss:  -15.9451
# Total loss:  -1.2332 | PDE Loss:  -1.2332 | Function Loss:  -15.945
# Total loss:  -1.2343 | PDE Loss:  -1.2343 | Function Loss:  -15.945
# Total loss:  -1.235 | PDE Loss:  -1.235 | Function Loss:  -15.9451
# Total loss:  -1.2359 | PDE Loss:  -1.2359 | Function Loss:  -15.9448
# Total loss:  -1.2366 | PDE Loss:  -1.2366 | Function Loss:  -15.9449
# Total loss:  -1.2373 | PDE Loss:  -1.2373 | Function Loss:  -15.9449
# Total loss:  -1.238 | PDE Loss:  -1.238 | Function Loss:  -15.945
# Total loss:  -1.2386 | PDE Loss:  -1.2386 | Function Loss:  -15.9449
# Total loss:  -1.2389 | PDE Loss:  -1.2389 | Function Loss:  -15.945
# Total loss:  -1.2392 | PDE Loss:  -1.2392 | Function Loss:  -15.9449
# Total loss:  -1.2395 | PDE Loss:  -1.2395 | Function Loss:  -15.9448
# Total loss:  -1.2399 | PDE Loss:  -1.2399 | Function Loss:  -15.9447
# Total loss:  -1.2402 | PDE Loss:  -1.2402 | Function Loss:  -15.9446
# Total loss:  -1.2405 | PDE Loss:  -1.2405 | Function Loss:  -15.9446
# Total loss:  -1.2408 | PDE Loss:  -1.2408 | Function Loss:  -15.9447
# Total loss:  -1.2411 | PDE Loss:  -1.2411 | Function Loss:  -15.9446
# Total loss:  -1.2413 | PDE Loss:  -1.2413 | Function Loss:  -15.9447
# Total loss:  -1.2417 | PDE Loss:  -1.2417 | Function Loss:  -15.9448
# Total loss:  -1.2421 | PDE Loss:  -1.2421 | Function Loss:  -15.945
# Total loss:  -1.2425 | PDE Loss:  -1.2425 | Function Loss:  -15.9451
# Total loss:  -1.2429 | PDE Loss:  -1.2429 | Function Loss:  -15.9451
# Total loss:  -1.2434 | PDE Loss:  -1.2434 | Function Loss:  -15.9452
# Total loss:  -1.2439 | PDE Loss:  -1.2439 | Function Loss:  -15.9451
# Total loss:  -1.2444 | PDE Loss:  -1.2444 | Function Loss:  -15.9451
# Total loss:  -1.245 | PDE Loss:  -1.245 | Function Loss:  -15.945
# Total loss:  -1.2456 | PDE Loss:  -1.2456 | Function Loss:  -15.945
# Total loss:  -1.2334 | PDE Loss:  -1.2334 | Function Loss:  -15.945
# Total loss:  -1.2458 | PDE Loss:  -1.2458 | Function Loss:  -15.945
# Total loss:  -1.2463 | PDE Loss:  -1.2463 | Function Loss:  -15.9449
# Total loss:  -1.2471 | PDE Loss:  -1.2471 | Function Loss:  -15.9447
# Total loss:  -1.2479 | PDE Loss:  -1.2479 | Function Loss:  -15.9447
# Total loss:  -1.2486 | PDE Loss:  -1.2486 | Function Loss:  -15.9446
# Total loss:  -1.2494 | PDE Loss:  -1.2494 | Function Loss:  -15.9447
# Total loss:  -1.2502 | PDE Loss:  -1.2502 | Function Loss:  -15.9447
# Total loss:  -1.2512 | PDE Loss:  -1.2512 | Function Loss:  -15.9449
# Total loss:  -1.2521 | PDE Loss:  -1.2521 | Function Loss:  -15.945
# Total loss:  -1.2528 | PDE Loss:  -1.2528 | Function Loss:  -15.9451
# Total loss:  -1.2538 | PDE Loss:  -1.2538 | Function Loss:  -15.9453
# Total loss:  -1.2544 | PDE Loss:  -1.2544 | Function Loss:  -15.9452
# Total loss:  -1.2562 | PDE Loss:  -1.2562 | Function Loss:  -15.9453
# Total loss:  -1.2583 | PDE Loss:  -1.2583 | Function Loss:  -15.945
# Total loss:  -1.2598 | PDE Loss:  -1.2598 | Function Loss:  -15.945
# Total loss:  -1.2612 | PDE Loss:  -1.2612 | Function Loss:  -15.9447
# Total loss:  -1.2612 | PDE Loss:  -1.2612 | Function Loss:  -15.9444
# Total loss:  -1.2619 | PDE Loss:  -1.2619 | Function Loss:  -15.9445
# Total loss:  -1.2628 | PDE Loss:  -1.2628 | Function Loss:  -15.9444
# Total loss:  -1.2639 | PDE Loss:  -1.2639 | Function Loss:  -15.9443
# Total loss:  -1.265 | PDE Loss:  -1.265 | Function Loss:  -15.9442
# Total loss:  -1.2659 | PDE Loss:  -1.2659 | Function Loss:  -15.9442
# Total loss:  -1.2664 | PDE Loss:  -1.2664 | Function Loss:  -15.9442
# Total loss:  -1.2668 | PDE Loss:  -1.2668 | Function Loss:  -15.9442
# Total loss:  -1.2671 | PDE Loss:  -1.2671 | Function Loss:  -15.9442
# Total loss:  -1.2673 | PDE Loss:  -1.2673 | Function Loss:  -15.9442
# Total loss:  -1.2675 | PDE Loss:  -1.2675 | Function Loss:  -15.9441
# Total loss:  -1.2677 | PDE Loss:  -1.2677 | Function Loss:  -15.9441
# Total loss:  -1.2679 | PDE Loss:  -1.2679 | Function Loss:  -15.944
# Total loss:  -1.2683 | PDE Loss:  -1.2683 | Function Loss:  -15.944
# Total loss:  -1.2687 | PDE Loss:  -1.2687 | Function Loss:  -15.9439
# Total loss:  -1.2692 | PDE Loss:  -1.2692 | Function Loss:  -15.9438
# Total loss:  -1.2697 | PDE Loss:  -1.2697 | Function Loss:  -15.9438
# Total loss:  -1.2704 | PDE Loss:  -1.2704 | Function Loss:  -15.9437
# Total loss:  -1.2708 | PDE Loss:  -1.2708 | Function Loss:  -15.9438
# Total loss:  -1.2712 | PDE Loss:  -1.2712 | Function Loss:  -15.9438
# Total loss:  -1.2717 | PDE Loss:  -1.2717 | Function Loss:  -15.9437
# Total loss:  -1.2722 | PDE Loss:  -1.2722 | Function Loss:  -15.9437
# Total loss:  -1.2725 | PDE Loss:  -1.2725 | Function Loss:  -15.9437
# Total loss:  -1.2731 | PDE Loss:  -1.2731 | Function Loss:  -15.9438
# Total loss:  -1.2737 | PDE Loss:  -1.2737 | Function Loss:  -15.9438
# Total loss:  -1.2745 | PDE Loss:  -1.2745 | Function Loss:  -15.9438
# Total loss:  -1.2752 | PDE Loss:  -1.2752 | Function Loss:  -15.9438
# Total loss:  -1.2761 | PDE Loss:  -1.2761 | Function Loss:  -15.9437
# Total loss:  -1.2767 | PDE Loss:  -1.2767 | Function Loss:  -15.9437
# Total loss:  -1.2776 | PDE Loss:  -1.2776 | Function Loss:  -15.9436
# Total loss:  -1.2787 | PDE Loss:  -1.2787 | Function Loss:  -15.9437
# Total loss:  -1.2799 | PDE Loss:  -1.2799 | Function Loss:  -15.9436
# Total loss:  -1.2765 | PDE Loss:  -1.2765 | Function Loss:  -15.9444
# Total loss:  -1.2803 | PDE Loss:  -1.2803 | Function Loss:  -15.9438
# Total loss:  -1.2814 | PDE Loss:  -1.2814 | Function Loss:  -15.9438
# Total loss:  -1.283 | PDE Loss:  -1.283 | Function Loss:  -15.9437
# Total loss:  -1.2849 | PDE Loss:  -1.2849 | Function Loss:  -15.9437
# Total loss:  -1.2877 | PDE Loss:  -1.2877 | Function Loss:  -15.9436
# Total loss:  -1.2913 | PDE Loss:  -1.2913 | Function Loss:  -15.9435
# Total loss:  -1.1444 | PDE Loss:  -1.1444 | Function Loss:  -15.9453
# Total loss:  -1.2929 | PDE Loss:  -1.2929 | Function Loss:  -15.9435
# Total loss:  -1.2959 | PDE Loss:  -1.2959 | Function Loss:  -15.9434
# Total loss:  -1.2982 | PDE Loss:  -1.2982 | Function Loss:  -15.9439
# Total loss:  -1.3021 | PDE Loss:  -1.3021 | Function Loss:  -15.9435
# Total loss:  -1.3053 | PDE Loss:  -1.3053 | Function Loss:  -15.9431
# Total loss:  -1.3083 | PDE Loss:  -1.3083 | Function Loss:  -15.9432
# Total loss:  -1.3111 | PDE Loss:  -1.3111 | Function Loss:  -15.9433
# Total loss:  -1.313 | PDE Loss:  -1.313 | Function Loss:  -15.9434
# Total loss:  -1.3146 | PDE Loss:  -1.3146 | Function Loss:  -15.9434
# Total loss:  -1.3161 | PDE Loss:  -1.3161 | Function Loss:  -15.9435
# Total loss:  -1.3177 | PDE Loss:  -1.3177 | Function Loss:  -15.9435
# Total loss:  -1.3193 | PDE Loss:  -1.3193 | Function Loss:  -15.9433
# Total loss:  -1.3206 | PDE Loss:  -1.3206 | Function Loss:  -15.9434
# Total loss:  -1.3217 | PDE Loss:  -1.3217 | Function Loss:  -15.9431
# Total loss:  -1.3225 | PDE Loss:  -1.3225 | Function Loss:  -15.9431
# Total loss:  -1.3232 | PDE Loss:  -1.3232 | Function Loss:  -15.943
# Total loss:  -1.3244 | PDE Loss:  -1.3244 | Function Loss:  -15.9429
# Total loss:  -1.3259 | PDE Loss:  -1.3259 | Function Loss:  -15.9429
# Total loss:  -1.3277 | PDE Loss:  -1.3277 | Function Loss:  -15.9428
# Total loss:  -1.3295 | PDE Loss:  -1.3295 | Function Loss:  -15.9427
# Total loss:  -1.3308 | PDE Loss:  -1.3308 | Function Loss:  -15.9428
# Total loss:  -1.3323 | PDE Loss:  -1.3323 | Function Loss:  -15.9429
# Total loss:  -1.3331 | PDE Loss:  -1.3331 | Function Loss:  -15.943
# Total loss:  -1.3335 | PDE Loss:  -1.3335 | Function Loss:  -15.943
# Total loss:  -1.3339 | PDE Loss:  -1.3339 | Function Loss:  -15.9431
# Total loss:  -1.3342 | PDE Loss:  -1.3342 | Function Loss:  -15.9431
# Total loss:  -1.3346 | PDE Loss:  -1.3346 | Function Loss:  -15.9432
# Total loss:  -1.3352 | PDE Loss:  -1.3352 | Function Loss:  -15.9431
# Total loss:  -1.3359 | PDE Loss:  -1.3359 | Function Loss:  -15.9431
# Total loss:  -1.3366 | PDE Loss:  -1.3366 | Function Loss:  -15.943
# Total loss:  -1.3375 | PDE Loss:  -1.3375 | Function Loss:  -15.9429
# Total loss:  -1.338 | PDE Loss:  -1.338 | Function Loss:  -15.9428
# Total loss:  -1.3388 | PDE Loss:  -1.3388 | Function Loss:  -15.9428
# Total loss:  -1.3398 | PDE Loss:  -1.3398 | Function Loss:  -15.9428
# Total loss:  -1.3408 | PDE Loss:  -1.3408 | Function Loss:  -15.9429
# Total loss:  -1.3416 | PDE Loss:  -1.3416 | Function Loss:  -15.943
# Total loss:  -1.3423 | PDE Loss:  -1.3423 | Function Loss:  -15.9431
# Total loss:  -1.343 | PDE Loss:  -1.343 | Function Loss:  -15.9431
# Total loss:  -1.3436 | PDE Loss:  -1.3436 | Function Loss:  -15.9432
# Total loss:  -1.3442 | PDE Loss:  -1.3442 | Function Loss:  -15.9432
# Total loss:  -1.3449 | PDE Loss:  -1.3449 | Function Loss:  -15.9432
# Total loss:  -1.3456 | PDE Loss:  -1.3456 | Function Loss:  -15.9431
# Total loss:  -1.3464 | PDE Loss:  -1.3464 | Function Loss:  -15.943
# Total loss:  -1.3472 | PDE Loss:  -1.3472 | Function Loss:  -15.9429
# Total loss:  -1.3483 | PDE Loss:  -1.3483 | Function Loss:  -15.9427
# Total loss:  -1.3499 | PDE Loss:  -1.3499 | Function Loss:  -15.9426
# Total loss:  -1.3517 | PDE Loss:  -1.3517 | Function Loss:  -15.9425
# Total loss:  -1.3533 | PDE Loss:  -1.3533 | Function Loss:  -15.9425
# Total loss:  -1.3548 | PDE Loss:  -1.3548 | Function Loss:  -15.9425
# Total loss:  -1.3558 | PDE Loss:  -1.3558 | Function Loss:  -15.9425
# Total loss:  -1.3568 | PDE Loss:  -1.3568 | Function Loss:  -15.9426
# Total loss:  -1.3576 | PDE Loss:  -1.3576 | Function Loss:  -15.9427
# Total loss:  -1.3586 | PDE Loss:  -1.3586 | Function Loss:  -15.9428
# Total loss:  -1.3596 | PDE Loss:  -1.3596 | Function Loss:  -15.9429
# Total loss:  -1.3606 | PDE Loss:  -1.3606 | Function Loss:  -15.943
# Total loss:  -1.3615 | PDE Loss:  -1.3615 | Function Loss:  -15.943
# Total loss:  -1.3621 | PDE Loss:  -1.3621 | Function Loss:  -15.943
# Total loss:  -1.3596 | PDE Loss:  -1.3596 | Function Loss:  -15.9429
# Total loss:  -1.3624 | PDE Loss:  -1.3624 | Function Loss:  -15.9429
# Total loss:  -1.3627 | PDE Loss:  -1.3627 | Function Loss:  -15.9429
# Total loss:  -1.3629 | PDE Loss:  -1.3629 | Function Loss:  -15.9428
# Total loss:  -1.3631 | PDE Loss:  -1.3631 | Function Loss:  -15.9428
# Total loss:  -1.3632 | PDE Loss:  -1.3632 | Function Loss:  -15.9427
# Total loss:  -1.3633 | PDE Loss:  -1.3633 | Function Loss:  -15.9426
# Total loss:  -1.3635 | PDE Loss:  -1.3635 | Function Loss:  -15.9426
# Total loss:  -1.3638 | PDE Loss:  -1.3638 | Function Loss:  -15.9426
# Total loss:  -1.3641 | PDE Loss:  -1.3641 | Function Loss:  -15.9426
# Total loss:  -1.3644 | PDE Loss:  -1.3644 | Function Loss:  -15.9426
# Total loss:  -1.3647 | PDE Loss:  -1.3647 | Function Loss:  -15.9426
# Total loss:  -1.3649 | PDE Loss:  -1.3649 | Function Loss:  -15.9427
# Total loss:  -1.3651 | PDE Loss:  -1.3651 | Function Loss:  -15.9428
# Total loss:  -1.3654 | PDE Loss:  -1.3654 | Function Loss:  -15.9428
# Total loss:  -1.3657 | PDE Loss:  -1.3657 | Function Loss:  -15.9429
# Total loss:  -1.3661 | PDE Loss:  -1.3661 | Function Loss:  -15.9429
# Total loss:  -1.3665 | PDE Loss:  -1.3665 | Function Loss:  -15.943
# Total loss:  -1.3671 | PDE Loss:  -1.3671 | Function Loss:  -15.943
# Total loss:  -1.368 | PDE Loss:  -1.368 | Function Loss:  -15.943
# Total loss:  -1.3686 | PDE Loss:  -1.3686 | Function Loss:  -15.943
# Total loss:  -1.3695 | PDE Loss:  -1.3695 | Function Loss:  -15.943
# Total loss:  -1.3703 | PDE Loss:  -1.3703 | Function Loss:  -15.943
# Total loss:  -1.3709 | PDE Loss:  -1.3709 | Function Loss:  -15.943
# Total loss:  -1.3716 | PDE Loss:  -1.3716 | Function Loss:  -15.9429
# Total loss:  -1.372 | PDE Loss:  -1.372 | Function Loss:  -15.943
# Total loss:  -1.3727 | PDE Loss:  -1.3727 | Function Loss:  -15.943
# Total loss:  -1.3735 | PDE Loss:  -1.3735 | Function Loss:  -15.9431
# Total loss:  -1.3743 | PDE Loss:  -1.3743 | Function Loss:  -15.9431
# Total loss:  -1.3752 | PDE Loss:  -1.3752 | Function Loss:  -15.9432
# Total loss:  -1.3761 | PDE Loss:  -1.3761 | Function Loss:  -15.9432
# Total loss:  -1.3769 | PDE Loss:  -1.3769 | Function Loss:  -15.9432
# Total loss:  -1.3776 | PDE Loss:  -1.3776 | Function Loss:  -15.9432
# Total loss:  -1.3781 | PDE Loss:  -1.3781 | Function Loss:  -15.9432
# Total loss:  -1.3786 | PDE Loss:  -1.3786 | Function Loss:  -15.9432
# Total loss:  -1.379 | PDE Loss:  -1.379 | Function Loss:  -15.9432
# Total loss:  -1.3794 | PDE Loss:  -1.3794 | Function Loss:  -15.9432
# Total loss:  -1.3797 | PDE Loss:  -1.3797 | Function Loss:  -15.9434
# Total loss:  -1.3801 | PDE Loss:  -1.3801 | Function Loss:  -15.9434
# Total loss:  -1.3808 | PDE Loss:  -1.3808 | Function Loss:  -15.9433
# Total loss:  -1.3818 | PDE Loss:  -1.3818 | Function Loss:  -15.9434
# Total loss:  -1.3829 | PDE Loss:  -1.3829 | Function Loss:  -15.9434
# Total loss:  -1.3842 | PDE Loss:  -1.3842 | Function Loss:  -15.9434
# Total loss:  -1.3849 | PDE Loss:  -1.3849 | Function Loss:  -15.9433
# Total loss:  -1.3863 | PDE Loss:  -1.3863 | Function Loss:  -15.9434
# Total loss:  -1.3875 | PDE Loss:  -1.3875 | Function Loss:  -15.9432
# Total loss:  -1.3882 | PDE Loss:  -1.3882 | Function Loss:  -15.9432
# Total loss:  -1.3897 | PDE Loss:  -1.3897 | Function Loss:  -15.9432
# Total loss:  -1.3913 | PDE Loss:  -1.3913 | Function Loss:  -15.9433
# Total loss:  -1.3918 | PDE Loss:  -1.3918 | Function Loss:  -15.9428
# Total loss:  -1.3937 | PDE Loss:  -1.3937 | Function Loss:  -15.9429
# Total loss:  -1.3954 | PDE Loss:  -1.3954 | Function Loss:  -15.9432
# Total loss:  -1.3969 | PDE Loss:  -1.3969 | Function Loss:  -15.9433
# Total loss:  -1.3992 | PDE Loss:  -1.3992 | Function Loss:  -15.9434
# Total loss:  -1.4007 | PDE Loss:  -1.4007 | Function Loss:  -15.943
# Total loss:  -1.4042 | PDE Loss:  -1.4042 | Function Loss:  -15.943
# Total loss:  -1.4056 | PDE Loss:  -1.4056 | Function Loss:  -15.9432
# Total loss:  -1.4071 | PDE Loss:  -1.4071 | Function Loss:  -15.9433
# Total loss:  -1.4091 | PDE Loss:  -1.4091 | Function Loss:  -15.9434
# Total loss:  -1.41 | PDE Loss:  -1.41 | Function Loss:  -15.9435
# Total loss:  -1.4116 | PDE Loss:  -1.4116 | Function Loss:  -15.9433
# Total loss:  -1.4126 | PDE Loss:  -1.4126 | Function Loss:  -15.9435
# Total loss:  -1.414 | PDE Loss:  -1.414 | Function Loss:  -15.9434
# Total loss:  -1.416 | PDE Loss:  -1.416 | Function Loss:  -15.9435
# Total loss:  -1.4181 | PDE Loss:  -1.4181 | Function Loss:  -15.9434
# Total loss:  -1.4196 | PDE Loss:  -1.4196 | Function Loss:  -15.943
# Total loss:  -1.4214 | PDE Loss:  -1.4214 | Function Loss:  -15.943
# ...
# Total loss:  -2.0789 | PDE Loss:  -2.0789 | Function Loss:  -15.9408
# Total loss:  -2.0793 | PDE Loss:  -2.0793 | Function Loss:  -15.9408
# Total loss:  -2.0797 | PDE Loss:  -2.0797 | Function Loss:  -15.9408
# Total loss:  -2.08 | PDE Loss:  -2.08 | Function Loss:  -15.9408
# Total loss:  -2.0803 | PDE Loss:  -2.0803 | Function Loss:  -15.9408
# Total loss:  -2.0805 | PDE Loss:  -2.0805 | Function Loss:  -15.9408
# Total loss:  -2.0807 | PDE Loss:  -2.0807 | Function Loss:  -15.9408
# Total loss:  -2.081 | PDE Loss:  -2.081 | Function Loss:  -15.9408
# Total loss:  -2.0812 | PDE Loss:  -2.0812 | Function Loss:  -15.9408
# Total loss:  -2.0814 | PDE Loss:  -2.0814 | Function Loss:  -15.9408
# Total loss:  -2.0816 | PDE Loss:  -2.0816 | Function Loss:  -15.9409
# Total loss:  -2.0818 | PDE Loss:  -2.0818 | Function Loss:  -15.9409
# Total loss:  -2.082 | PDE Loss:  -2.082 | Function Loss:  -15.9409
# Total loss:  -2.0822 | PDE Loss:  -2.0822 | Function Loss:  -15.9409
# Total loss:  -2.0824 | PDE Loss:  -2.0824 | Function Loss:  -15.9409
# Total loss:  -2.0827 | PDE Loss:  -2.0827 | Function Loss:  -15.9409
# Total loss:  -2.083 | PDE Loss:  -2.083 | Function Loss:  -15.9409
# Total loss:  -2.0834 | PDE Loss:  -2.0834 | Function Loss:  -15.9408
# Total loss:  -2.0836 | PDE Loss:  -2.0836 | Function Loss:  -15.9408
# Total loss:  -2.0838 | PDE Loss:  -2.0838 | Function Loss:  -15.9408
# Total loss:  -2.0841 | PDE Loss:  -2.0841 | Function Loss:  -15.9408
# Total loss:  -2.0843 | PDE Loss:  -2.0843 | Function Loss:  -15.9408
# Total loss:  -2.0845 | PDE Loss:  -2.0845 | Function Loss:  -15.9409
# Total loss:  -2.0848 | PDE Loss:  -2.0848 | Function Loss:  -15.9409
# Total loss:  -2.0853 | PDE Loss:  -2.0853 | Function Loss:  -15.9409
# Total loss:  -2.0858 | PDE Loss:  -2.0858 | Function Loss:  -15.9409
# Total loss:  -2.0863 | PDE Loss:  -2.0863 | Function Loss:  -15.9409
# Total loss:  -2.0866 | PDE Loss:  -2.0866 | Function Loss:  -15.9408
# Total loss:  -2.0871 | PDE Loss:  -2.0871 | Function Loss:  -15.9409
# Total loss:  -2.0875 | PDE Loss:  -2.0875 | Function Loss:  -15.9409
# Total loss:  -2.088 | PDE Loss:  -2.088 | Function Loss:  -15.9408
# Total loss:  -2.0885 | PDE Loss:  -2.0885 | Function Loss:  -15.9408
# Total loss:  -2.089 | PDE Loss:  -2.089 | Function Loss:  -15.9407
# Total loss:  -2.0895 | PDE Loss:  -2.0895 | Function Loss:  -15.9408
# Total loss:  -2.0894 | PDE Loss:  -2.0894 | Function Loss:  -15.9406
# Total loss:  -2.0899 | PDE Loss:  -2.0899 | Function Loss:  -15.9407
# Total loss:  -2.0903 | PDE Loss:  -2.0903 | Function Loss:  -15.9407
# Total loss:  -2.091 | PDE Loss:  -2.091 | Function Loss:  -15.9407
# Total loss:  -2.0906 | PDE Loss:  -2.0906 | Function Loss:  -15.9409
# Total loss:  -2.0914 | PDE Loss:  -2.0914 | Function Loss:  -15.9408
# Total loss:  -2.0919 | PDE Loss:  -2.0919 | Function Loss:  -15.9408
# Total loss:  -2.0923 | PDE Loss:  -2.0923 | Function Loss:  -15.9408
# Total loss:  -2.0928 | PDE Loss:  -2.0928 | Function Loss:  -15.9408
# Total loss:  -2.0933 | PDE Loss:  -2.0933 | Function Loss:  -15.9409
# Total loss:  -2.0938 | PDE Loss:  -2.0938 | Function Loss:  -15.941
# Total loss:  -2.0942 | PDE Loss:  -2.0942 | Function Loss:  -15.941
# Total loss:  -2.0948 | PDE Loss:  -2.0948 | Function Loss:  -15.941
# Total loss:  -2.0951 | PDE Loss:  -2.0951 | Function Loss:  -15.941
# Total loss:  -2.0953 | PDE Loss:  -2.0953 | Function Loss:  -15.941
# Total loss:  -2.0954 | PDE Loss:  -2.0954 | Function Loss:  -15.941
# Total loss:  -2.0956 | PDE Loss:  -2.0956 | Function Loss:  -15.941
# Total loss:  -2.0957 | PDE Loss:  -2.0957 | Function Loss:  -15.941
# Total loss:  -2.0958 | PDE Loss:  -2.0958 | Function Loss:  -15.941
# Total loss:  -2.0959 | PDE Loss:  -2.0959 | Function Loss:  -15.941
# Total loss:  -2.0961 | PDE Loss:  -2.0961 | Function Loss:  -15.941
# Total loss:  -2.0962 | PDE Loss:  -2.0962 | Function Loss:  -15.941
# Total loss:  -2.0963 | PDE Loss:  -2.0963 | Function Loss:  -15.941
# Total loss:  -2.0964 | PDE Loss:  -2.0964 | Function Loss:  -15.941
# Total loss:  -2.0967 | PDE Loss:  -2.0967 | Function Loss:  -15.9409
# Total loss:  -2.0969 | PDE Loss:  -2.0969 | Function Loss:  -15.9409
# Total loss:  -2.0972 | PDE Loss:  -2.0972 | Function Loss:  -15.9409
# Total loss:  -2.0954 | PDE Loss:  -2.0954 | Function Loss:  -15.9406
# Total loss:  -2.0975 | PDE Loss:  -2.0975 | Function Loss:  -15.9408
# Total loss:  -2.0978 | PDE Loss:  -2.0978 | Function Loss:  -15.9409
# Total loss:  -2.0983 | PDE Loss:  -2.0983 | Function Loss:  -15.9409
# Total loss:  -2.0987 | PDE Loss:  -2.0987 | Function Loss:  -15.9409
# Total loss:  -2.0989 | PDE Loss:  -2.0989 | Function Loss:  -15.9409
# Total loss:  -2.0991 | PDE Loss:  -2.0991 | Function Loss:  -15.941
# Total loss:  -2.0992 | PDE Loss:  -2.0992 | Function Loss:  -15.9409
# Total loss:  -2.0993 | PDE Loss:  -2.0993 | Function Loss:  -15.941
# Total loss:  -2.0994 | PDE Loss:  -2.0994 | Function Loss:  -15.9409
# Total loss:  -2.0994 | PDE Loss:  -2.0994 | Function Loss:  -15.9409
# Total loss:  -2.0995 | PDE Loss:  -2.0995 | Function Loss:  -15.9409
# Total loss:  -2.0995 | PDE Loss:  -2.0995 | Function Loss:  -15.9409
# Total loss:  -2.0996 | PDE Loss:  -2.0996 | Function Loss:  -15.9409
# Total loss:  -2.0997 | PDE Loss:  -2.0997 | Function Loss:  -15.9409
# Total loss:  -2.0998 | PDE Loss:  -2.0998 | Function Loss:  -15.9409
# Total loss:  -2.0999 | PDE Loss:  -2.0999 | Function Loss:  -15.9409
# Total loss:  -2.1001 | PDE Loss:  -2.1001 | Function Loss:  -15.9409
# Total loss:  -2.1002 | PDE Loss:  -2.1002 | Function Loss:  -15.9409
# Total loss:  -2.1 | PDE Loss:  -2.1 | Function Loss:  -15.9408
# Total loss:  -2.1002 | PDE Loss:  -2.1002 | Function Loss:  -15.9409
# Total loss:  -2.1004 | PDE Loss:  -2.1004 | Function Loss:  -15.9409
# Total loss:  -2.1005 | PDE Loss:  -2.1005 | Function Loss:  -15.9409
# Total loss:  -2.1006 | PDE Loss:  -2.1006 | Function Loss:  -15.9409
# Total loss:  -2.1006 | PDE Loss:  -2.1006 | Function Loss:  -15.9409
# Total loss:  -2.1007 | PDE Loss:  -2.1007 | Function Loss:  -15.9409
# Total loss:  -2.1009 | PDE Loss:  -2.1009 | Function Loss:  -15.9409
# Total loss:  -2.101 | PDE Loss:  -2.101 | Function Loss:  -15.9409
# Total loss:  -2.1011 | PDE Loss:  -2.1011 | Function Loss:  -15.9409
# Total loss:  -2.1012 | PDE Loss:  -2.1012 | Function Loss:  -15.9409
# Total loss:  -2.1012 | PDE Loss:  -2.1012 | Function Loss:  -15.9409
# Total loss:  -2.1013 | PDE Loss:  -2.1013 | Function Loss:  -15.9409
# Total loss:  -2.1014 | PDE Loss:  -2.1014 | Function Loss:  -15.941
# Total loss:  -2.1014 | PDE Loss:  -2.1014 | Function Loss:  -15.9409
# Total loss:  -2.1015 | PDE Loss:  -2.1015 | Function Loss:  -15.941
# Total loss:  -2.1016 | PDE Loss:  -2.1016 | Function Loss:  -15.941
# Total loss:  -2.1017 | PDE Loss:  -2.1017 | Function Loss:  -15.941
# Total loss:  -2.1018 | PDE Loss:  -2.1018 | Function Loss:  -15.941
# Total loss:  -2.1019 | PDE Loss:  -2.1019 | Function Loss:  -15.941
# Total loss:  -2.102 | PDE Loss:  -2.102 | Function Loss:  -15.9409
# Total loss:  -2.1021 | PDE Loss:  -2.1021 | Function Loss:  -15.9409
# Total loss:  -2.1021 | PDE Loss:  -2.1021 | Function Loss:  -15.9409
# Total loss:  -2.1022 | PDE Loss:  -2.1022 | Function Loss:  -15.9409
# Total loss:  -2.1023 | PDE Loss:  -2.1023 | Function Loss:  -15.9409
# Total loss:  -2.1024 | PDE Loss:  -2.1024 | Function Loss:  -15.941
# Total loss:  -2.1024 | PDE Loss:  -2.1024 | Function Loss:  -15.9409
# Total loss:  -2.1025 | PDE Loss:  -2.1025 | Function Loss:  -15.9409
# Total loss:  -2.1026 | PDE Loss:  -2.1026 | Function Loss:  -15.9409
# Total loss:  -2.1026 | PDE Loss:  -2.1026 | Function Loss:  -15.9409
# Total loss:  -2.1026 | PDE Loss:  -2.1026 | Function Loss:  -15.9409
# Total loss:  -2.1027 | PDE Loss:  -2.1027 | Function Loss:  -15.9409
# Total loss:  -2.1027 | PDE Loss:  -2.1027 | Function Loss:  -15.9409
# Total loss:  -2.1028 | PDE Loss:  -2.1028 | Function Loss:  -15.9409
# Total loss:  -2.1029 | PDE Loss:  -2.1029 | Function Loss:  -15.9409
# Total loss:  -2.103 | PDE Loss:  -2.103 | Function Loss:  -15.9409
# Total loss:  -2.1032 | PDE Loss:  -2.1032 | Function Loss:  -15.941
# Total loss:  -2.1033 | PDE Loss:  -2.1033 | Function Loss:  -15.941
# Total loss:  -2.1036 | PDE Loss:  -2.1036 | Function Loss:  -15.941
# Total loss:  -2.1037 | PDE Loss:  -2.1037 | Function Loss:  -15.941
# Total loss:  -2.1039 | PDE Loss:  -2.1039 | Function Loss:  -15.941
# Total loss:  -2.1041 | PDE Loss:  -2.1041 | Function Loss:  -15.941
# Total loss:  -2.1043 | PDE Loss:  -2.1043 | Function Loss:  -15.941
# Total loss:  -2.1045 | PDE Loss:  -2.1045 | Function Loss:  -15.941
# Total loss:  -2.1047 | PDE Loss:  -2.1047 | Function Loss:  -15.941
# Total loss:  -2.1048 | PDE Loss:  -2.1048 | Function Loss:  -15.941
# Total loss:  -2.1051 | PDE Loss:  -2.1051 | Function Loss:  -15.941
# Total loss:  -2.1053 | PDE Loss:  -2.1053 | Function Loss:  -15.941
# Total loss:  -2.1055 | PDE Loss:  -2.1055 | Function Loss:  -15.941
# Total loss:  -2.1057 | PDE Loss:  -2.1057 | Function Loss:  -15.941
# Total loss:  -2.1058 | PDE Loss:  -2.1058 | Function Loss:  -15.941
# Total loss:  -2.1061 | PDE Loss:  -2.1061 | Function Loss:  -15.941
# Total loss:  -2.1063 | PDE Loss:  -2.1063 | Function Loss:  -15.941
# Total loss:  -2.1065 | PDE Loss:  -2.1065 | Function Loss:  -15.9409
# Total loss:  -2.1067 | PDE Loss:  -2.1067 | Function Loss:  -15.9409
# Total loss:  -2.107 | PDE Loss:  -2.107 | Function Loss:  -15.9409
# Total loss:  -2.1075 | PDE Loss:  -2.1075 | Function Loss:  -15.9409
# Total loss:  -2.1082 | PDE Loss:  -2.1082 | Function Loss:  -15.941
# Total loss:  -2.1086 | PDE Loss:  -2.1086 | Function Loss:  -15.941
# Total loss:  -2.1093 | PDE Loss:  -2.1093 | Function Loss:  -15.9411
# Total loss:  -2.1095 | PDE Loss:  -2.1095 | Function Loss:  -15.941
# Total loss:  -2.1098 | PDE Loss:  -2.1098 | Function Loss:  -15.941
# Total loss:  -2.1103 | PDE Loss:  -2.1103 | Function Loss:  -15.9411
# Total loss:  -2.1108 | PDE Loss:  -2.1108 | Function Loss:  -15.9411
# Total loss:  -2.1112 | PDE Loss:  -2.1112 | Function Loss:  -15.9411
# Total loss:  -2.1115 | PDE Loss:  -2.1115 | Function Loss:  -15.9411
# Total loss:  -2.112 | PDE Loss:  -2.112 | Function Loss:  -15.9411
# Total loss:  -2.1125 | PDE Loss:  -2.1125 | Function Loss:  -15.9411
# Total loss:  -2.1133 | PDE Loss:  -2.1133 | Function Loss:  -15.9411
# Total loss:  -2.1142 | PDE Loss:  -2.1142 | Function Loss:  -15.9411
# Total loss:  -2.1153 | PDE Loss:  -2.1153 | Function Loss:  -15.9411
# Total loss:  -2.1159 | PDE Loss:  -2.1159 | Function Loss:  -15.941
# Total loss:  -2.1165 | PDE Loss:  -2.1165 | Function Loss:  -15.9411
# Total loss:  -2.1177 | PDE Loss:  -2.1177 | Function Loss:  -15.9411
# Total loss:  -2.1191 | PDE Loss:  -2.1191 | Function Loss:  -15.9411
# Total loss:  -2.1203 | PDE Loss:  -2.1203 | Function Loss:  -15.9412
# Total loss:  -2.1207 | PDE Loss:  -2.1207 | Function Loss:  -15.9412
# Total loss:  -2.1214 | PDE Loss:  -2.1214 | Function Loss:  -15.9412
# Total loss:  -2.1223 | PDE Loss:  -2.1223 | Function Loss:  -15.9413
# Total loss:  -2.1232 | PDE Loss:  -2.1232 | Function Loss:  -15.9412
# Total loss:  -2.1239 | PDE Loss:  -2.1239 | Function Loss:  -15.9412
# Total loss:  -2.1247 | PDE Loss:  -2.1247 | Function Loss:  -15.9412
# Total loss:  -2.1256 | PDE Loss:  -2.1256 | Function Loss:  -15.9412
# Total loss:  -2.1267 | PDE Loss:  -2.1267 | Function Loss:  -15.9412
# Total loss:  -2.127 | PDE Loss:  -2.127 | Function Loss:  -15.941
# Total loss:  -2.1274 | PDE Loss:  -2.1274 | Function Loss:  -15.9411
# Total loss:  -2.1282 | PDE Loss:  -2.1282 | Function Loss:  -15.9411
# Total loss:  -2.1297 | PDE Loss:  -2.1297 | Function Loss:  -15.9411
# Total loss:  -2.131 | PDE Loss:  -2.131 | Function Loss:  -15.9411
# Total loss:  -2.1324 | PDE Loss:  -2.1324 | Function Loss:  -15.9412
# Total loss:  -2.1305 | PDE Loss:  -2.1305 | Function Loss:  -15.9411
# Total loss:  -2.1331 | PDE Loss:  -2.1331 | Function Loss:  -15.9412
# Total loss:  -2.134 | PDE Loss:  -2.134 | Function Loss:  -15.9412
# Total loss:  -2.135 | PDE Loss:  -2.135 | Function Loss:  -15.9413
# Total loss:  -2.1362 | PDE Loss:  -2.1362 | Function Loss:  -15.9413
# Total loss:  -2.1369 | PDE Loss:  -2.1369 | Function Loss:  -15.9413
# Total loss:  -2.1377 | PDE Loss:  -2.1377 | Function Loss:  -15.9413
# Total loss:  -2.1381 | PDE Loss:  -2.1381 | Function Loss:  -15.9412
# Total loss:  -2.1385 | PDE Loss:  -2.1385 | Function Loss:  -15.9412
# Total loss:  -2.1391 | PDE Loss:  -2.1391 | Function Loss:  -15.9412
# Total loss:  -2.1396 | PDE Loss:  -2.1396 | Function Loss:  -15.9412
# Total loss:  -2.1402 | PDE Loss:  -2.1402 | Function Loss:  -15.9412
# Total loss:  -2.1408 | PDE Loss:  -2.1408 | Function Loss:  -15.9412
# Total loss:  -2.1412 | PDE Loss:  -2.1412 | Function Loss:  -15.9412
# Total loss:  -2.1416 | PDE Loss:  -2.1416 | Function Loss:  -15.9412
# Total loss:  -2.1422 | PDE Loss:  -2.1422 | Function Loss:  -15.9412
# Total loss:  -2.1426 | PDE Loss:  -2.1426 | Function Loss:  -15.9412
# Total loss:  -2.1435 | PDE Loss:  -2.1435 | Function Loss:  -15.9413
# Total loss:  -2.1445 | PDE Loss:  -2.1445 | Function Loss:  -15.9413
# Total loss:  -2.1454 | PDE Loss:  -2.1454 | Function Loss:  -15.9413
# Total loss:  -2.1462 | PDE Loss:  -2.1462 | Function Loss:  -15.9415
# Total loss:  -2.1468 | PDE Loss:  -2.1468 | Function Loss:  -15.9414
# Total loss:  -2.1475 | PDE Loss:  -2.1475 | Function Loss:  -15.9414
# Total loss:  -2.1494 | PDE Loss:  -2.1494 | Function Loss:  -15.9414
# Total loss:  -2.151 | PDE Loss:  -2.151 | Function Loss:  -15.9413
# Total loss:  -2.1523 | PDE Loss:  -2.1523 | Function Loss:  -15.9413
# Total loss:  -2.153 | PDE Loss:  -2.153 | Function Loss:  -15.9413
# Total loss:  -2.1538 | PDE Loss:  -2.1538 | Function Loss:  -15.9414
# Total loss:  -2.1544 | PDE Loss:  -2.1544 | Function Loss:  -15.9414
# Total loss:  -2.1551 | PDE Loss:  -2.1551 | Function Loss:  -15.9415
# Total loss:  -2.1558 | PDE Loss:  -2.1558 | Function Loss:  -15.9415
# Total loss:  -2.1565 | PDE Loss:  -2.1565 | Function Loss:  -15.9416
# Total loss:  -2.1574 | PDE Loss:  -2.1574 | Function Loss:  -15.9416
# Total loss:  -2.158 | PDE Loss:  -2.158 | Function Loss:  -15.9416
# Total loss:  -2.1585 | PDE Loss:  -2.1585 | Function Loss:  -15.9416
# Total loss:  -2.1588 | PDE Loss:  -2.1588 | Function Loss:  -15.9416
# Total loss:  -2.1591 | PDE Loss:  -2.1591 | Function Loss:  -15.9416
# Total loss:  -2.1595 | PDE Loss:  -2.1595 | Function Loss:  -15.9416
# Total loss:  -2.1598 | PDE Loss:  -2.1598 | Function Loss:  -15.9415
# Total loss:  -2.1601 | PDE Loss:  -2.1601 | Function Loss:  -15.9415
# Total loss:  -2.1604 | PDE Loss:  -2.1604 | Function Loss:  -15.9415
# Total loss:  -2.1606 | PDE Loss:  -2.1606 | Function Loss:  -15.9415
# Total loss:  -2.1609 | PDE Loss:  -2.1609 | Function Loss:  -15.9415
# Total loss:  -2.1611 | PDE Loss:  -2.1611 | Function Loss:  -15.9415
# Total loss:  -2.1613 | PDE Loss:  -2.1613 | Function Loss:  -15.9414
# Total loss:  -2.1615 | PDE Loss:  -2.1615 | Function Loss:  -15.9414
# Total loss:  -2.1618 | PDE Loss:  -2.1618 | Function Loss:  -15.9414
# Total loss:  -2.1622 | PDE Loss:  -2.1622 | Function Loss:  -15.9415
# Total loss:  -2.1626 | PDE Loss:  -2.1626 | Function Loss:  -15.9415
# Total loss:  -2.1631 | PDE Loss:  -2.1631 | Function Loss:  -15.9415
# Total loss:  -2.1636 | PDE Loss:  -2.1636 | Function Loss:  -15.9415
# Total loss:  -2.1644 | PDE Loss:  -2.1644 | Function Loss:  -15.9415
# Total loss:  -2.1651 | PDE Loss:  -2.1651 | Function Loss:  -15.9415
# Total loss:  -2.1659 | PDE Loss:  -2.1659 | Function Loss:  -15.9416
# Total loss:  -2.1668 | PDE Loss:  -2.1668 | Function Loss:  -15.9416
# Total loss:  -2.1674 | PDE Loss:  -2.1674 | Function Loss:  -15.9416
# Total loss:  -2.168 | PDE Loss:  -2.168 | Function Loss:  -15.9416
# Total loss:  -2.1684 | PDE Loss:  -2.1684 | Function Loss:  -15.9416
# Total loss:  -2.1688 | PDE Loss:  -2.1688 | Function Loss:  -15.9416
# Total loss:  -2.1693 | PDE Loss:  -2.1693 | Function Loss:  -15.9416
# Total loss:  -2.1696 | PDE Loss:  -2.1696 | Function Loss:  -15.9416
# Total loss:  -2.1698 | PDE Loss:  -2.1698 | Function Loss:  -15.9416
# Total loss:  -2.17 | PDE Loss:  -2.17 | Function Loss:  -15.9416

# %%
pinn.plotting()
# Out:
# L2 Relative Error Norm:  0.27703702449798584 %
# L2 Relative Error Norm:  0.1943197101354599 %
# L2 Relative Error Norm:  0.42037954926490784 %
# L2 Relative Error Norm:  0.20819377899169922 %
# L2 Relative Error Norm:  0.2189546525478363 %
