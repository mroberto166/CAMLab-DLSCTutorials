# %% [markdown]
# ## Physics Informed Neural Networks to Approximate Solution of PDEs

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.optim as optim
from torch.utils.data import DataLoader

from Common import NeuralNet

torch.manual_seed(128)

# %% [markdown]
# Consider the one-dimensional heat equation:
#
# $$
# u_t(t, x) = k(t,x)u_{xx}(t, x) + s(t, x), \quad t\in[0,T], ~x\in [-1,1]
# $$
#
# with zero Dirichlet boundary conditions
#
# $$
# u_b(t, -1)=u_b(t,1)=0,
# $$
#
# and initial condition
#
# $$
# u(x, 0) = u_0(x) = - \sin(\pi x)
# $$
#
# The equation parameter $k:[0,T]\times[-1,1]\mapsto \mathbb{R} $ denotes the medium conductivity and $s:[0,T]\times[-1,1]\mapsto \mathbb{R}$ is a source term.
#
# We want to solve a parameter identification inverse problem, which can be formulated as follows:
#
# *given observation measurements of the medium temperature $S_{meas}=\{(t_i, x_i, u^{meas}_{i})\}_{i=1}^{N_{meas}}$, find $u: [0,T]\times[-1,1]\mapsto\mathbb{R}$ and $k:[-1,1]\mapsto \mathbb{R}$, such that $u_t(t, x) = k(t,x)u_{xx}(t, x) + s(t,x)$, $u_b(t, -1)=u_b(t,1)=0, $ and $u(x, 0) = u_0(x) = -\sin(\pi x)$*
#
#
#
# To do so, we approximate the underlying solution and the medium conductivity with two feedforward dense neural network with tunable parameters $\theta$ and $\phi$:
#
# $$
# u_\theta(t,x) \approx u(t,x), \quad k_\phi(t, x) \approx k(t, x)
# $$
# To do so, define the following residuals:
#
#    - Interior residual given by,
#    $$r_{int,\theta, \phi}(t, x):=  u_{\theta, t}(t, x) - k_\phi(t,x)u_{\theta, xx}(t, x) -s(t,x), \quad \forall ~t \in [0,T],~ x \in [-1,1].$$
#
#
#
#    - Spatial boundary residual given by,
#
#         $$r_{sb,\theta}(t,-1):= u_{\theta}(t,-1)- u_b(t,-1), \quad r_{sb,\theta}(t,1):= u_{\theta}(t,1)- u_b(t,1), \quad \forall t \in (0,T].$$
#
#    - Temporal boundary residual given by,
#
#         $$r_{tb,\theta}(x):= u_{\theta}(x,0) - u_0(x), \quad \forall x \in [-1,1].$$
#
# and compute the corresponding loss functions:
#
# $$
# L_{int}(\theta, \phi) = \int_{[0,T]\times[-1,1]}r_{int,\theta, \phi}^2(t, x) dtdx, \quad
# L_{sb}(\theta) = \int_{[0,T]}r_{sb,\theta}^2(t,-1) dt + \int_{[0,T]}r_{sb,\theta}^2(t,1)dt, \quad
# L_{tb}(\theta) = \int_{[-1,1]}r_{tb,\theta}^2(x) dx
# $$
#
# The loss functions include integrals that can be approximated by suitable quadrature rule. We use quasi Monte-Carlo and accordingly define the following training sets
#
# $$
# S_{int} =\{y_n\}, \quad 1 \leq n \leq N_{int},\quad y_n = (x,t)_n \in D_T,
# $$
#
# $$
# S_{sb, -1} =\{t_n, u_b(t_n,-1) \}, \quad 1 \leq n \leq N_{sb}, t_n \in [0,T],
# $$
#
# $$
# S_{sb, 1} =\{t_n, u_b(t_n,1) \}, \quad1 \leq n \leq N_{sb}, t_n \in [0,T],
# $$
#
# $$
# S_{tb}=\{x_n, u_0(x_n)\}\quad  1 \leq n \leq N_{tb}, x_n \in [-1,1].
# $$
#
# with the training inputs points corresponding to low-discrepancy Sobol sequences:
#
# $$
# L_{int}(\theta, \phi) = \frac{1}{N_{int}}\sum_{i=1}^{N_{int}}r_{int,\theta,\phi}^2(y_n), \quad
# L_{sb}(\theta) = \frac{1}{N_{sb}}\sum_{i=1}^{N_{sb}}r_{sb,\theta}^2(t_n,-1) + \frac{1}{N_{sb}}\sum_{i=1}^{N_{sb}}r_{sb,\theta}^2(t_n,1), \quad
# L_{tb}(\theta) = \frac{1}{N_{tb}}\sum_{i=1}^{N_{tb}}r_{tb,\theta}^2(x_n)
# $$
#
# Also the measurements data $S_{meas}$ have to taken into account. To do so, we define ad additional loss term:
# $$
# L_{meas} = \frac{1}{N_{meas}}\sum_{i=1}^{N_{mean}}(u_\theta(t_i, x_i) - u^{meas}_i)^2(x_n)
# $$
# and eventually solve the following minimization problem
#
# $$
# \theta^\ast, \phi^\ast = argmin_{\theta, \phi} \Big(L_{int}(\theta, \phi) + \lambda_u L_u(\theta)\Big)
# $$
#
# with
#
# $$
# L_u(\theta) = L_{tb}(\theta) + L_{sb}(\theta) + L_{meas}(\theta)
# $$
#
#
# In the following let's assume
#
# $$u_{ex}(t,x) = -\exp(-\pi^2 t)\sin(\pi x), \quad k(t,x)=k(x)=\sin(\pi x).$$
#
# Then, the source term $s$ can be computed by plugging the expression above in the PDE:
#
# $$
# s(t,x) = -\pi^2u_{ex}(t,x)*(1 - k(t,x))
# $$
#
# Moreover, let us assume that the measurments data are given as follows:
#
# $$
# u_{meas}(x_i, t_i) = u_{ex}(x_i t_i) + 0.01\xi, \quad \xi \sim \mathcal{N(0, 1)}
# $$
#
# where $\mathcal{N(0, 1)}$ is a standard normal distribution.

# %%
class Pinns:
    def __init__(self, n_int_, n_sb_, n_tb_):
        self.n_int = n_int_
        self.n_sb = n_sb_
        self.n_tb = n_tb_


        # Extrema of the solution domain (t,x) in [0,0.1]x[-1,1]
        self.domain_extrema = torch.tensor([[0, 0.1],  # Time dimension
                                            [-1, 1]])  # Space dimension

        # Number of space dimensions
        self.space_dimensions = 1

        # Parameter to balance role of data and PDE
        self.lambda_u = 10

        # FF Dense NN to approximate the solution of the underlying heat equation
        self.approximate_solution = NeuralNet(input_dimension=self.domain_extrema.shape[0], output_dimension=1,
                                              n_hidden_layers=4,
                                              neurons=20,
                                              regularization_param=0.,
                                              regularization_exp=2.,
                                              retrain_seed=42)

        # FF Dense NN to approximate the conductivity we wish to infer
        self.approximate_coefficient = NeuralNet(input_dimension=self.domain_extrema.shape[0], output_dimension=1,
                                                 n_hidden_layers=4,
                                                 neurons=20,
                                                 regularization_param=0.,
                                                 regularization_exp=2.,
                                                 retrain_seed=42)

        # Generator of Sobol sequences
        self.soboleng = torch.quasirandom.SobolEngine(dimension=self.domain_extrema.shape[0])

        # Training sets S_sb, S_tb, S_int as torch dataloader
        self.training_set_sb, self.training_set_tb, self.training_set_int = self.assemble_datasets()

        # number of sensors to record temperature
        self.n_sensor = 50

    ################################################################################################
    # Function to linearly transform a tensor whose value are between 0 and 1
    # to a tensor whose values are between the domain extrema
    def convert(self, tens):
        assert (tens.shape[1] == self.domain_extrema.shape[0])
        return tens * (self.domain_extrema[:, 1] - self.domain_extrema[:, 0]) + self.domain_extrema[:, 0]

    # Initial condition to solve the heat equation u0(x)=-sin(pi x)
    def initial_condition(self, x):
        return -torch.sin(np.pi * x)

    # Exact solution for the heat equation ut = u_xx with the IC above
    def exact_solution(self, inputs):
        t = inputs[:, 0]
        x = inputs[:, 1]

        u = -torch.exp(-np.pi ** 2 * t) * torch.sin(np.pi * x)
        return u

    def exact_conductivity(self, inputs):
        t = inputs[:, 0]
        x = inputs[:, 1]
        k = (torch.sin(np.pi * x) + 1.1)

        return k


    def source(self, inputs):

        s = -np.pi**2*self.exact_solution(inputs)*(1 - self.exact_conductivity(inputs))
        return s

    ################################################################################################
    # Function returning the input-output tensor required to assemble the training set S_tb corresponding to the temporal boundary
    def add_temporal_boundary_points(self):
        t0 = self.domain_extrema[0, 0]
        input_tb = self.convert(self.soboleng.draw(self.n_tb))
        input_tb[:, 0] = torch.full(input_tb[:, 0].shape, t0)
        output_tb = self.initial_condition(input_tb[:, 1]).reshape(-1, 1)

        return input_tb, output_tb

    # Function returning the input-output tensor required to assemble the training set S_sb corresponding to the spatial boundary
    def add_spatial_boundary_points(self):
        x0 = self.domain_extrema[1, 0]
        xL = self.domain_extrema[1, 1]

        input_sb = self.convert(self.soboleng.draw(self.n_sb))

        input_sb_0 = torch.clone(input_sb)
        input_sb_0[:, 1] = torch.full(input_sb_0[:, 1].shape, x0)

        input_sb_L = torch.clone(input_sb)
        input_sb_L[:, 1] = torch.full(input_sb_L[:, 1].shape, xL)

        output_sb_0 = torch.zeros((input_sb.shape[0], 1))
        output_sb_L = torch.zeros((input_sb.shape[0], 1))

        return torch.cat([input_sb_0, input_sb_L], 0), torch.cat([output_sb_0, output_sb_L], 0)

    #  Function returning the input-output tensor required to assemble the training set S_int corresponding to the interior domain where the PDE is enforced
    def add_interior_points(self):
        input_int = self.convert(self.soboleng.draw(self.n_int))
        output_int = torch.zeros((input_int.shape[0], 1))
        return input_int, output_int
    

    def get_measurement_data(self):
        torch.random.manual_seed(42)
        # take measurments every 0.001 sec on a set of randomly placed (in space) sensors
        t = torch.linspace(0, self.domain_extrema[0, 1], 25)
        x = torch.linspace(self.domain_extrema[1, 0], self.domain_extrema[1, 1], self.n_sensor)


        input_meas = torch.cartesian_prod(t, x)

        output_meas = self.exact_solution(input_meas).reshape(-1,1)
        noise = 0.01*torch.randn_like(output_meas)
        output_meas = output_meas + noise

        return input_meas, output_meas



    # Function returning the training sets S_sb, S_tb, S_int as dataloader
    def assemble_datasets(self):
        input_sb, output_sb = self.add_spatial_boundary_points()  # S_sb
        input_tb, output_tb = self.add_temporal_boundary_points()  # S_tb
        input_int, output_int = self.add_interior_points()  # S_int

        training_set_sb = DataLoader(torch.utils.data.TensorDataset(input_sb, output_sb), batch_size=2 * self.space_dimensions * self.n_sb, shuffle=False)
        training_set_tb = DataLoader(torch.utils.data.TensorDataset(input_tb, output_tb), batch_size=self.n_tb, shuffle=False)
        training_set_int = DataLoader(torch.utils.data.TensorDataset(input_int, output_int), batch_size=self.n_int, shuffle=False)

        return training_set_sb, training_set_tb, training_set_int

    ################################################################################################
    # Function to compute the terms required in the definition of the TEMPORAL boundary residual
    def apply_initial_condition(self, input_tb):
        u_pred_tb = self.approximate_solution(input_tb)
        return u_pred_tb

    # Function to compute the terms required in the definition of the SPATIAL boundary residual
    def apply_boundary_conditions(self, input_sb):
        u_pred_sb = self.approximate_solution(input_sb)

        return u_pred_sb


    # Function to compute the PDE residuals
    def compute_pde_residual(self, input_int):
        input_int.requires_grad = True
        u = self.approximate_solution(input_int).reshape(-1,)
        k = self.approximate_coefficient(input_int).reshape(-1,)

        # grad compute the gradient of a "SCALAR" function L with respect to some input nxm TENSOR Z=[[x1, y1],[x2,y2],[x3,y3],...,[xn,yn]], m=2
        # it returns grad_L = [[dL/dx1, dL/dy1],[dL/dx2, dL/dy2],[dL/dx3, dL/dy3],...,[dL/dxn, dL/dyn]]
        # Note: pytorch considers a tensor [u1, u2,u3, ... ,un] a vectorial function
        # whereas sum_u = u1 + u2 u3 + u4 + ... + un as a "scalar" one

        # In our case ui = u(xi), therefore the line below returns:
        # grad_u = [[dsum_u/dx1, dsum_u/dy1],[dsum_u/dx2, dsum_u/dy2],[dsum_u/dx3, dL/dy3],...,[dsum_u/dxm, dsum_u/dyn]]
        # and dsum_u/dxi = d(u1 + u2 u3 + u4 + ... + un)/dxi = d(u(x1) + u(x2) u3(x3) + u4(x4) + ... + u(xn))/dxi = dui/dxi
        grad_u = torch.autograd.grad(u.sum(), input_int, create_graph=True)[0]
        grad_u_t = grad_u[:, 0]
        grad_u_x = grad_u[:, 1]
        grad_u_xx = torch.autograd.grad(grad_u_x.sum(), input_int, create_graph=True)[0][:, 1]


        s = self.source(input_int)


        residual = grad_u_t - k*grad_u_xx - s

        return residual.reshape(-1, )

    # Function to compute the total loss (weighted sum of spatial boundary loss, temporal boundary loss and interior loss)
    def compute_loss(self, inp_train_sb, u_train_sb, inp_train_tb, u_train_tb, inp_train_int, verbose=True):
        u_pred_sb = self.apply_boundary_conditions(inp_train_sb)
        u_pred_tb = self.apply_initial_condition(inp_train_tb)

        inp_train_meas, u_train_meas = self.get_measurement_data()
        u_pred_meas = self.approximate_solution(inp_train_meas)

        assert (u_pred_sb.shape[1] == u_train_sb.shape[1])
        assert (u_pred_tb.shape[1] == u_train_tb.shape[1])
        assert (u_pred_meas.shape[1] == u_train_meas.shape[1])

        r_int = self.compute_pde_residual(inp_train_int)
        r_sb = u_train_sb - u_pred_sb
        r_tb = u_train_tb - u_pred_tb
        r_meas = u_train_meas - u_pred_meas

        loss_sb = torch.mean(abs(r_sb) ** 2)
        loss_tb = torch.mean(abs(r_tb) ** 2)
        loss_int = torch.mean(abs(r_int) ** 2)
        loss_meas = torch.mean(abs(r_meas) ** 2)

        loss_u = loss_sb + loss_tb + loss_meas

        loss = torch.log10(self.lambda_u * loss_u + loss_int)
        if verbose: print("Total loss: ", round(loss.item(), 4), "| PDE Loss: ", round(torch.log10(loss_int).item(), 4), "| Function Loss: ", round(torch.log10(loss_u).item(), 4))

        return loss

    ################################################################################################
    def fit(self, num_epochs, optimizer, verbose=True):
        history = list()

        # Loop over epochs
        for epoch in range(num_epochs):
            if verbose: print("################################ ", epoch, " ################################")

            for j, ((inp_train_sb, u_train_sb), (inp_train_tb, u_train_tb), (inp_train_int, u_train_int)) in enumerate(zip(self.training_set_sb, self.training_set_tb, self.training_set_int)):
                def closure():
                    optimizer.zero_grad()
                    loss = self.compute_loss(inp_train_sb, u_train_sb, inp_train_tb, u_train_tb, inp_train_int, verbose=verbose)
                    loss.backward()

                    history.append(loss.item())
                    return loss

                optimizer.step(closure=closure)

        print('Final Loss: ', history[-1])

        return history

    ################################################################################################
    def plotting(self):
        inputs = self.soboleng.draw(100000)
        inputs = self.convert(inputs)

        output = self.approximate_solution(inputs).reshape(-1, )
        exact_output = self.exact_solution(inputs).reshape(-1, )

        fig, axs = plt.subplots(1, 2, figsize=(16, 8), dpi=150)
        im1 = axs[0].scatter(inputs[:, 1].detach(), inputs[:, 0].detach(), c=exact_output.detach(), cmap="jet")
        axs[0].set_xlabel("x")
        axs[0].set_ylabel("t")
        plt.colorbar(im1, ax=axs[0])
        axs[0].grid(True, which="both", ls=":")
        im2 = axs[1].scatter(inputs[:, 1].detach(), inputs[:, 0].detach(), c=output.detach(), cmap="jet")
        axs[1].set_xlabel("x")
        axs[1].set_ylabel("t")
        plt.colorbar(im2, ax=axs[1])
        axs[1].grid(True, which="both", ls=":")
        axs[0].set_title("Exact Solution")
        axs[1].set_title("Approximate Solution")

        err = (torch.mean((output - exact_output) ** 2) / torch.mean(exact_output ** 2)) ** 0.5 * 100
        print("L2 Relative Error Norm U: ", err.item(), "%")

        approximate_conductivity = self.approximate_coefficient(inputs).reshape(-1, )
        exact_conductivity = self.exact_conductivity(inputs).reshape(-1, )


        fig, axs = plt.subplots(1, 2, figsize=(16, 8), dpi=150)
        im1 = axs[0].scatter(inputs[:, 1].detach(), inputs[:, 0].detach(), c=exact_conductivity.detach(), cmap="jet")
        axs[0].set_xlabel("x")
        axs[0].set_ylabel("t")
        plt.colorbar(im1, ax=axs[0])
        axs[0].grid(True, which="both", ls=":")
        im2 = axs[1].scatter(inputs[:, 1].detach(), inputs[:, 0].detach(), c=approximate_conductivity.detach(), cmap="jet")
        axs[1].set_xlabel("x")
        axs[1].set_ylabel("t")
        plt.colorbar(im2, ax=axs[1])
        axs[1].grid(True, which="both", ls=":")
        axs[0].set_title("Exact Conductivity")
        axs[1].set_title("Approximate Conductivity")

        err = (torch.mean((approximate_conductivity - exact_conductivity) ** 2) / torch.mean(exact_conductivity ** 2)) ** 0.5 * 100
        print("L2 Relative Error Norm K: ", err.item(), "%")

        plt.show()

# %%
# Solve the heat equation:
# u_t = u_xx, (t,x) in [0, 0.1]x[-1,1]
# with zero dirichlet BC and
# u(x,0)= -sin(pi x)

n_int = 256
n_sb = 64
n_tb = 64

pinn = Pinns(n_int, n_sb, n_tb)

# %%
# Plot the input training points
input_sb_, output_sb_ = pinn.add_spatial_boundary_points()
input_tb_, output_tb_ = pinn.add_temporal_boundary_points()
input_int_, output_int_ = pinn.add_interior_points()
input_meas_, output_meas_ = pinn.get_measurement_data()

plt.figure(figsize=(16, 8), dpi=150)
plt.scatter(input_sb_[:, 1].detach().numpy(), input_sb_[:, 0].detach().numpy(), label="Boundary Points")
plt.scatter(input_int_[:, 1].detach().numpy(), input_int_[:, 0].detach().numpy(), label="Interior Points")
plt.scatter(input_tb_[:, 1].detach().numpy(), input_tb_[:, 0].detach().numpy(), label="Initial Points")
plt.scatter(input_meas_[:, 1].detach().numpy(), input_meas_[:, 0].detach().numpy(), label="Sensors Points", marker="*")
plt.xlabel("x")
plt.ylabel("t")
plt.legend()
plt.show()

# %%
n_epochs = 1
optimizer_LBFGS = optim.LBFGS(list(pinn.approximate_solution.parameters()) + list(pinn.approximate_coefficient.parameters()),
                              lr=float(0.5),
                              max_iter=1000,
                              max_eval=50000,
                              history_size=150,
                              line_search_fn="strong_wolfe",
                              tolerance_change=1.0 * np.finfo(float).eps)
optimizer_ADAM = optim.Adam(pinn.approximate_solution.parameters(),
                            lr=float(0.005))

# %%
hist = pinn.fit(num_epochs=n_epochs,
                optimizer=optimizer_LBFGS,
                verbose=True)

plt.figure(dpi=150)
plt.grid(True, which="both", ls=":")
plt.plot(np.arange(1, len(hist) + 1), hist, label="Train Loss")
plt.xscale("log")
plt.legend()
# Out:
# ################################  0  ################################
# Total loss:  1.9527 | PDE Loss:  1.8761 | Function Loss:  0.1619
# Total loss:  1.9061 | PDE Loss:  1.8385 | Function Loss:  0.0651
# Total loss:  1.521 | PDE Loss:  1.3634 | Function Loss:  0.0043
# Total loss:  1.6588 | PDE Loss:  0.7416 | Function Loss:  0.6028
# Total loss:  1.4441 | PDE Loss:  1.0571 | Function Loss:  0.2148
# Total loss:  1.3283 | PDE Loss:  0.9053 | Function Loss:  0.1223
# Total loss:  1.0769 | PDE Loss:  0.7616 | Function Loss:  -0.2104
# Total loss:  0.9578 | PDE Loss:  0.6288 | Function Loss:  -0.317
# Total loss:  0.9077 | PDE Loss:  0.5676 | Function Loss:  -0.3576
# Total loss:  0.8718 | PDE Loss:  0.5121 | Function Loss:  -0.3775
# Total loss:  0.8571 | PDE Loss:  0.4938 | Function Loss:  -0.3895
# Total loss:  0.8437 | PDE Loss:  0.4778 | Function Loss:  -0.4009
# Total loss:  0.8078 | PDE Loss:  0.4427 | Function Loss:  -0.4374
# Total loss:  0.7239 | PDE Loss:  0.4144 | Function Loss:  -0.5689
# Total loss:  0.6475 | PDE Loss:  0.3431 | Function Loss:  -0.6502
# Total loss:  0.5538 | PDE Loss:  0.2427 | Function Loss:  -0.7375
# Total loss:  0.53 | PDE Loss:  0.206 | Function Loss:  -0.7492
# Total loss:  0.5065 | PDE Loss:  0.1676 | Function Loss:  -0.7597
# Total loss:  0.4678 | PDE Loss:  0.117 | Function Loss:  -0.7886
# Total loss:  0.4378 | PDE Loss:  0.0608 | Function Loss:  -0.7985
# Total loss:  0.4015 | PDE Loss:  0.055 | Function Loss:  -0.8583
# Total loss:  0.3608 | PDE Loss:  0.0228 | Function Loss:  -0.9062
# Total loss:  0.2745 | PDE Loss:  -0.0626 | Function Loss:  -0.9931
# Total loss:  0.2438 | PDE Loss:  -0.1055 | Function Loss:  -1.0137
# Total loss:  0.2291 | PDE Loss:  -0.1367 | Function Loss:  -1.0155
# Total loss:  0.2113 | PDE Loss:  -0.1617 | Function Loss:  -1.028
# Total loss:  0.1851 | PDE Loss:  -0.2011 | Function Loss:  -1.0447
# Total loss:  0.153 | PDE Loss:  -0.2335 | Function Loss:  -1.0766
# Total loss:  0.1214 | PDE Loss:  -0.2751 | Function Loss:  -1.1013
# Total loss:  0.1085 | PDE Loss:  -0.2967 | Function Loss:  -1.1086
# Total loss:  0.091 | PDE Loss:  -0.3346 | Function Loss:  -1.1134
# Total loss:  0.0778 | PDE Loss:  -0.3632 | Function Loss:  -1.1175
# Total loss:  0.0677 | PDE Loss:  -0.3865 | Function Loss:  -1.1203
# Total loss:  0.0549 | PDE Loss:  -0.4135 | Function Loss:  -1.1256
# Total loss:  0.0264 | PDE Loss:  -0.4703 | Function Loss:  -1.1402
# Total loss:  -0.0077 | PDE Loss:  -0.5389 | Function Loss:  -1.1591
# Total loss:  -0.0381 | PDE Loss:  -0.5813 | Function Loss:  -1.1845
# Total loss:  -0.0622 | PDE Loss:  -0.583 | Function Loss:  -1.218
# Total loss:  -0.0778 | PDE Loss:  -0.6039 | Function Loss:  -1.2313
# Total loss:  -0.0871 | PDE Loss:  -0.6199 | Function Loss:  -1.2378
# Total loss:  -0.099 | PDE Loss:  -0.6404 | Function Loss:  -1.2462
# Total loss:  -0.1159 | PDE Loss:  -0.676 | Function Loss:  -1.2558
# Total loss:  -0.1343 | PDE Loss:  -0.72 | Function Loss:  -1.2649
# Total loss:  -0.1495 | PDE Loss:  -0.7629 | Function Loss:  -1.2707
# Total loss:  -0.1682 | PDE Loss:  -0.8232 | Function Loss:  -1.2768
# Total loss:  -0.1995 | PDE Loss:  -0.9264 | Function Loss:  -1.2897
# Total loss:  -0.2297 | PDE Loss:  -0.9794 | Function Loss:  -1.3148
# Total loss:  -0.2532 | PDE Loss:  -1.0067 | Function Loss:  -1.3374
# Total loss:  -0.2744 | PDE Loss:  -1.0241 | Function Loss:  -1.3595
# Total loss:  -0.2872 | PDE Loss:  -1.0062 | Function Loss:  -1.3793
# Total loss:  -0.2959 | PDE Loss:  -0.9752 | Function Loss:  -1.3978
# Total loss:  -0.3191 | PDE Loss:  -1.0302 | Function Loss:  -1.4131
# Total loss:  -0.3571 | PDE Loss:  -1.1318 | Function Loss:  -1.437
# Total loss:  -0.3816 | PDE Loss:  -1.0888 | Function Loss:  -1.4765
# Total loss:  -0.3908 | PDE Loss:  -1.1377 | Function Loss:  -1.4765
# Total loss:  -0.3943 | PDE Loss:  -1.1473 | Function Loss:  -1.4786
# Total loss:  -0.3966 | PDE Loss:  -1.1657 | Function Loss:  -1.4777
# Total loss:  -0.3999 | PDE Loss:  -1.1828 | Function Loss:  -1.4782
# Total loss:  -0.4038 | PDE Loss:  -1.1929 | Function Loss:  -1.4808
# Total loss:  -0.4078 | PDE Loss:  -1.2246 | Function Loss:  -1.4797
# Total loss:  -0.4117 | PDE Loss:  -1.2424 | Function Loss:  -1.4811
# Total loss:  -0.4164 | PDE Loss:  -1.2559 | Function Loss:  -1.4842
# Total loss:  -0.4232 | PDE Loss:  -1.2868 | Function Loss:  -1.4872
# Total loss:  -0.4308 | PDE Loss:  -1.2932 | Function Loss:  -1.495
# Total loss:  -0.4377 | PDE Loss:  -1.294 | Function Loss:  -1.5028
# Total loss:  -0.4455 | PDE Loss:  -1.2807 | Function Loss:  -1.5142
# Total loss:  -0.4523 | PDE Loss:  -1.2589 | Function Loss:  -1.526
# Total loss:  -0.4576 | PDE Loss:  -1.2375 | Function Loss:  -1.5365
# Total loss:  -0.4614 | PDE Loss:  -1.2212 | Function Loss:  -1.5444
# Total loss:  -0.4656 | PDE Loss:  -1.2037 | Function Loss:  -1.5533
# Total loss:  -0.4707 | PDE Loss:  -1.1938 | Function Loss:  -1.5618
# Total loss:  -0.4781 | PDE Loss:  -1.174 | Function Loss:  -1.5758
# Total loss:  -0.487 | PDE Loss:  -1.1712 | Function Loss:  -1.5878
# Total loss:  -0.498 | PDE Loss:  -1.1635 | Function Loss:  -1.6038
# Total loss:  -0.5138 | PDE Loss:  -1.1782 | Function Loss:  -1.6198
# Total loss:  -0.5319 | PDE Loss:  -1.177 | Function Loss:  -1.6434
# Total loss:  -0.5514 | PDE Loss:  -1.2108 | Function Loss:  -1.6589
# Total loss:  -0.5647 | PDE Loss:  -1.2174 | Function Loss:  -1.6739
# Total loss:  -0.5731 | PDE Loss:  -1.2132 | Function Loss:  -1.6861
# Total loss:  -0.5774 | PDE Loss:  -1.2389 | Function Loss:  -1.6842
# Total loss:  -0.5794 | PDE Loss:  -1.2426 | Function Loss:  -1.6858
# Total loss:  -0.5817 | PDE Loss:  -1.248 | Function Loss:  -1.6872
# Total loss:  -0.5853 | PDE Loss:  -1.2588 | Function Loss:  -1.6888
# Total loss:  -0.5877 | PDE Loss:  -1.2641 | Function Loss:  -1.6904
# Total loss:  -0.5898 | PDE Loss:  -1.2604 | Function Loss:  -1.6941
# Total loss:  -0.5922 | PDE Loss:  -1.2647 | Function Loss:  -1.696
# Total loss:  -0.5953 | PDE Loss:  -1.2667 | Function Loss:  -1.6993
# Total loss:  -0.6001 | PDE Loss:  -1.2747 | Function Loss:  -1.7033
# Total loss:  -0.6071 | PDE Loss:  -1.2855 | Function Loss:  -1.7093
# Total loss:  -0.6161 | PDE Loss:  -1.2908 | Function Loss:  -1.7194
# Total loss:  -0.6251 | PDE Loss:  -1.2862 | Function Loss:  -1.732
# Total loss:  -0.6328 | PDE Loss:  -1.2789 | Function Loss:  -1.744
# Total loss:  -0.6395 | PDE Loss:  -1.2643 | Function Loss:  -1.7571
# Total loss:  -0.6463 | PDE Loss:  -1.2721 | Function Loss:  -1.7636
# Total loss:  -0.6542 | PDE Loss:  -1.2843 | Function Loss:  -1.7702
# Total loss:  -0.6654 | PDE Loss:  -1.2967 | Function Loss:  -1.781
# Total loss:  -0.6812 | PDE Loss:  -1.33 | Function Loss:  -1.7916
# Total loss:  -0.6928 | PDE Loss:  -1.3184 | Function Loss:  -1.8101
# Total loss:  -0.7049 | PDE Loss:  -1.3624 | Function Loss:  -1.8128
# Total loss:  -0.7117 | PDE Loss:  -1.3632 | Function Loss:  -1.8214
# Total loss:  -0.7176 | PDE Loss:  -1.3768 | Function Loss:  -1.8251
# Total loss:  -0.7242 | PDE Loss:  -1.3987 | Function Loss:  -1.8275
# Total loss:  -0.7297 | PDE Loss:  -1.4237 | Function Loss:  -1.8279
# Total loss:  -0.7336 | PDE Loss:  -1.4385 | Function Loss:  -1.829
# Total loss:  -0.7372 | PDE Loss:  -1.4402 | Function Loss:  -1.8331
# Total loss:  -0.7432 | PDE Loss:  -1.4423 | Function Loss:  -1.8401
# Total loss:  -0.7522 | PDE Loss:  -1.4336 | Function Loss:  -1.8537
# Total loss:  -0.762 | PDE Loss:  -1.4063 | Function Loss:  -1.8737
# Total loss:  -0.7716 | PDE Loss:  -1.3879 | Function Loss:  -1.8919
# Total loss:  -0.7822 | PDE Loss:  -1.3548 | Function Loss:  -1.9175
# Total loss:  -0.7931 | PDE Loss:  -1.3142 | Function Loss:  -1.9488
# Total loss:  -0.8049 | PDE Loss:  -1.3133 | Function Loss:  -1.9661
# Total loss:  -0.8197 | PDE Loss:  -1.2892 | Function Loss:  -1.9996
# Total loss:  -0.8331 | PDE Loss:  -1.2889 | Function Loss:  -2.0202
# Total loss:  -0.8345 | PDE Loss:  -1.2728 | Function Loss:  -2.0314
# Total loss:  -0.8373 | PDE Loss:  -1.2977 | Function Loss:  -2.022
# Total loss:  -0.8436 | PDE Loss:  -1.3326 | Function Loss:  -2.014
# Total loss:  -0.8481 | PDE Loss:  -1.3576 | Function Loss:  -2.0089
# Total loss:  -0.8529 | PDE Loss:  -1.3647 | Function Loss:  -2.0126
# Total loss:  -0.8585 | PDE Loss:  -1.3845 | Function Loss:  -2.012
# Total loss:  -0.8637 | PDE Loss:  -1.3991 | Function Loss:  -2.0133
# Total loss:  -0.8694 | PDE Loss:  -1.4096 | Function Loss:  -2.017
# Total loss:  -0.8778 | PDE Loss:  -1.4181 | Function Loss:  -2.0255
# Total loss:  -0.889 | PDE Loss:  -1.4279 | Function Loss:  -2.0372
# Total loss:  -0.9047 | PDE Loss:  -1.4397 | Function Loss:  -2.0545
# Total loss:  -0.9204 | PDE Loss:  -1.4476 | Function Loss:  -2.0735
# Total loss:  -0.9409 | PDE Loss:  -1.467 | Function Loss:  -2.0945
# Total loss:  -0.9618 | PDE Loss:  -1.4685 | Function Loss:  -2.1238
# Total loss:  -0.9754 | PDE Loss:  -1.4888 | Function Loss:  -2.1344
# Total loss:  -0.9907 | PDE Loss:  -1.4771 | Function Loss:  -2.1622
# Total loss:  -0.9958 | PDE Loss:  -1.4749 | Function Loss:  -2.1709
# Total loss:  -0.9996 | PDE Loss:  -1.4911 | Function Loss:  -2.1687
# Total loss:  -1.0041 | PDE Loss:  -1.5065 | Function Loss:  -2.1681
# Total loss:  -1.0109 | PDE Loss:  -1.5245 | Function Loss:  -2.1699
# Total loss:  -1.0242 | PDE Loss:  -1.5539 | Function Loss:  -2.1761
# Total loss:  -1.0483 | PDE Loss:  -1.5881 | Function Loss:  -2.1962
# Total loss:  -1.0719 | PDE Loss:  -1.6048 | Function Loss:  -2.2226
# Total loss:  -1.0912 | PDE Loss:  -1.6064 | Function Loss:  -2.2494
# Total loss:  -1.1027 | PDE Loss:  -1.5821 | Function Loss:  -2.2776
# Total loss:  -1.1203 | PDE Loss:  -1.5996 | Function Loss:  -2.2954
# Total loss:  -1.1255 | PDE Loss:  -1.6172 | Function Loss:  -2.2945
# Total loss:  -1.1283 | PDE Loss:  -1.6282 | Function Loss:  -2.2935
# Total loss:  -1.1307 | PDE Loss:  -1.637 | Function Loss:  -2.293
# Total loss:  -1.1336 | PDE Loss:  -1.6438 | Function Loss:  -2.2941
# Total loss:  -1.1399 | PDE Loss:  -1.6519 | Function Loss:  -2.2995
# Total loss:  -1.1494 | PDE Loss:  -1.6598 | Function Loss:  -2.3098
# Total loss:  -1.1603 | PDE Loss:  -1.6531 | Function Loss:  -2.3288
# Total loss:  -1.1708 | PDE Loss:  -1.6497 | Function Loss:  -2.346
# Total loss:  -1.1796 | PDE Loss:  -1.6326 | Function Loss:  -2.3683
# Total loss:  -1.1854 | PDE Loss:  -1.6077 | Function Loss:  -2.3916
# Total loss:  -1.1881 | PDE Loss:  -1.6064 | Function Loss:  -2.3968
# Total loss:  -1.1905 | PDE Loss:  -1.6053 | Function Loss:  -2.4014
# Total loss:  -1.1939 | PDE Loss:  -1.6016 | Function Loss:  -2.4093
# Total loss:  -1.1998 | PDE Loss:  -1.6027 | Function Loss:  -2.4184
# Total loss:  -1.2068 | PDE Loss:  -1.5974 | Function Loss:  -2.4335
# Total loss:  -1.2163 | PDE Loss:  -1.5993 | Function Loss:  -2.4484
# Total loss:  -1.2253 | PDE Loss:  -1.6098 | Function Loss:  -2.4563
# Total loss:  -1.2413 | PDE Loss:  -1.6322 | Function Loss:  -2.4679
# Total loss:  -1.2614 | PDE Loss:  -1.6324 | Function Loss:  -2.5022
# Total loss:  -1.2745 | PDE Loss:  -1.6626 | Function Loss:  -2.5031
# Total loss:  -1.273 | PDE Loss:  -1.6571 | Function Loss:  -2.5044
# Total loss:  -1.2805 | PDE Loss:  -1.6714 | Function Loss:  -2.5072
# Total loss:  -1.2924 | PDE Loss:  -1.6908 | Function Loss:  -2.5139
# Total loss:  -1.3076 | PDE Loss:  -1.6997 | Function Loss:  -2.5334
# Total loss:  -1.316 | PDE Loss:  -1.6939 | Function Loss:  -2.5517
# Total loss:  -1.3221 | PDE Loss:  -1.6881 | Function Loss:  -2.5666
# Total loss:  -1.3261 | PDE Loss:  -1.6893 | Function Loss:  -2.5727
# Total loss:  -1.3286 | PDE Loss:  -1.6875 | Function Loss:  -2.5786
# Total loss:  -1.3323 | PDE Loss:  -1.6916 | Function Loss:  -2.5819
# Total loss:  -1.3358 | PDE Loss:  -1.7012 | Function Loss:  -2.5807
# Total loss:  -1.3414 | PDE Loss:  -1.7177 | Function Loss:  -2.5783
# Total loss:  -1.3465 | PDE Loss:  -1.7137 | Function Loss:  -2.5902
# Total loss:  -1.3537 | PDE Loss:  -1.7335 | Function Loss:  -2.5881
# Total loss:  -1.3574 | PDE Loss:  -1.7576 | Function Loss:  -2.5778
# Total loss:  -1.3622 | PDE Loss:  -1.7566 | Function Loss:  -2.5865
# Total loss:  -1.3705 | PDE Loss:  -1.7641 | Function Loss:  -2.5952
# Total loss:  -1.3786 | PDE Loss:  -1.7519 | Function Loss:  -2.6177
# Total loss:  -1.3844 | PDE Loss:  -1.7601 | Function Loss:  -2.6217
# Total loss:  -1.3901 | PDE Loss:  -1.7543 | Function Loss:  -2.636
# Total loss:  -1.3954 | PDE Loss:  -1.759 | Function Loss:  -2.6418
# Total loss:  -1.3996 | PDE Loss:  -1.7626 | Function Loss:  -2.6464
# Total loss:  -1.4106 | PDE Loss:  -1.7764 | Function Loss:  -2.6553
# Total loss:  -1.4269 | PDE Loss:  -1.8017 | Function Loss:  -2.6649
# Total loss:  -1.4414 | PDE Loss:  -1.8379 | Function Loss:  -2.6642
# Total loss:  -1.4485 | PDE Loss:  -1.8618 | Function Loss:  -2.6605
# Total loss:  -1.4574 | PDE Loss:  -1.8827 | Function Loss:  -2.6619
# Total loss:  -1.4678 | PDE Loss:  -1.8976 | Function Loss:  -2.6697
# Total loss:  -1.4778 | PDE Loss:  -1.9051 | Function Loss:  -2.6811
# Total loss:  -1.4896 | PDE Loss:  -1.9188 | Function Loss:  -2.6918
# Total loss:  -1.4978 | PDE Loss:  -1.9033 | Function Loss:  -2.7147
# Total loss:  -1.5079 | PDE Loss:  -1.9094 | Function Loss:  -2.7274
# Total loss:  -1.5178 | PDE Loss:  -1.9053 | Function Loss:  -2.7468
# Total loss:  -1.5253 | PDE Loss:  -1.8985 | Function Loss:  -2.7645
# Total loss:  -1.5308 | PDE Loss:  -1.8988 | Function Loss:  -2.7738
# Total loss:  -1.5356 | PDE Loss:  -1.8927 | Function Loss:  -2.787
# Total loss:  -1.5375 | PDE Loss:  -1.8941 | Function Loss:  -2.7893
# Total loss:  -1.5393 | PDE Loss:  -1.9016 | Function Loss:  -2.7866
# Total loss:  -1.5409 | PDE Loss:  -1.9021 | Function Loss:  -2.7892
# Total loss:  -1.5425 | PDE Loss:  -1.9084 | Function Loss:  -2.787
# Total loss:  -1.5463 | PDE Loss:  -1.9153 | Function Loss:  -2.7885
# Total loss:  -1.5543 | PDE Loss:  -1.9272 | Function Loss:  -2.7937
# Total loss:  -1.5674 | PDE Loss:  -1.945 | Function Loss:  -2.8034
# Total loss:  -1.5829 | PDE Loss:  -1.9567 | Function Loss:  -2.8216
# Total loss:  -1.6024 | PDE Loss:  -1.9816 | Function Loss:  -2.8372
# Total loss:  -1.6187 | PDE Loss:  -1.9723 | Function Loss:  -2.8728
# Total loss:  -1.6308 | PDE Loss:  -1.9776 | Function Loss:  -2.8904
# Total loss:  -1.6368 | PDE Loss:  -1.9732 | Function Loss:  -2.9052
# Total loss:  -1.6351 | PDE Loss:  -1.9353 | Function Loss:  -2.937
# Total loss:  -1.6389 | PDE Loss:  -1.9609 | Function Loss:  -2.9198
# Total loss:  -1.641 | PDE Loss:  -1.9521 | Function Loss:  -2.9321
# Total loss:  -1.6438 | PDE Loss:  -1.9484 | Function Loss:  -2.9412
# Total loss:  -1.6479 | PDE Loss:  -1.9492 | Function Loss:  -2.9486
# Total loss:  -1.6594 | PDE Loss:  -1.9404 | Function Loss:  -2.9814
# Total loss:  -1.674 | PDE Loss:  -1.9482 | Function Loss:  -3.0037
# Total loss:  -1.693 | PDE Loss:  -1.9669 | Function Loss:  -3.023
# Total loss:  -1.7037 | PDE Loss:  -1.9731 | Function Loss:  -3.0389
# Total loss:  -1.7167 | PDE Loss:  -2.0114 | Function Loss:  -3.0241
# Total loss:  -1.7259 | PDE Loss:  -2.0128 | Function Loss:  -3.0416
# Total loss:  -1.7292 | PDE Loss:  -2.0112 | Function Loss:  -3.0501
# Total loss:  -1.7321 | PDE Loss:  -2.008 | Function Loss:  -3.0598
# Total loss:  -1.7362 | PDE Loss:  -2.0111 | Function Loss:  -3.065
# Total loss:  -1.7429 | PDE Loss:  -2.0047 | Function Loss:  -3.087
# Total loss:  -1.7496 | PDE Loss:  -2.0041 | Function Loss:  -3.1027
# Total loss:  -1.7575 | PDE Loss:  -2.0115 | Function Loss:  -3.1112
# Total loss:  -1.7647 | PDE Loss:  -2.0067 | Function Loss:  -3.1341
# Total loss:  -1.7741 | PDE Loss:  -2.0056 | Function Loss:  -3.1581
# Total loss:  -1.7822 | PDE Loss:  -2.0104 | Function Loss:  -3.1709
# Total loss:  -1.7906 | PDE Loss:  -2.0157 | Function Loss:  -3.1837
# Total loss:  -1.7948 | PDE Loss:  -2.0115 | Function Loss:  -3.2006
# Total loss:  -1.7992 | PDE Loss:  -2.0092 | Function Loss:  -3.2154
# Total loss:  -1.8024 | PDE Loss:  -2.0223 | Function Loss:  -3.2033
# Total loss:  -1.8053 | PDE Loss:  -2.0264 | Function Loss:  -3.2044
# Total loss:  -1.8108 | PDE Loss:  -2.0386 | Function Loss:  -3.2001
# Total loss:  -1.8154 | PDE Loss:  -2.0457 | Function Loss:  -3.2011
# Total loss:  -1.8188 | PDE Loss:  -2.0552 | Function Loss:  -3.1958
# Total loss:  -1.8216 | PDE Loss:  -2.062 | Function Loss:  -3.1931
# Total loss:  -1.8245 | PDE Loss:  -2.0716 | Function Loss:  -3.1871
# Total loss:  -1.8285 | PDE Loss:  -2.0805 | Function Loss:  -3.1848
# Total loss:  -1.8316 | PDE Loss:  -2.0848 | Function Loss:  -3.1864
# Total loss:  -1.8366 | PDE Loss:  -2.0922 | Function Loss:  -3.1882
# Total loss:  -1.8426 | PDE Loss:  -2.0926 | Function Loss:  -3.2014
# Total loss:  -1.8483 | PDE Loss:  -2.0994 | Function Loss:  -3.2057
# Total loss:  -1.852 | PDE Loss:  -2.0978 | Function Loss:  -3.2163
# Total loss:  -1.8552 | PDE Loss:  -2.0991 | Function Loss:  -3.2221
# Total loss:  -1.8598 | PDE Loss:  -2.1049 | Function Loss:  -3.2251
# Total loss:  -1.8661 | PDE Loss:  -2.1127 | Function Loss:  -3.2295
# Total loss:  -1.8718 | PDE Loss:  -2.1237 | Function Loss:  -3.2284
# Total loss:  -1.8769 | PDE Loss:  -2.1334 | Function Loss:  -3.2275
# Total loss:  -1.8829 | PDE Loss:  -2.145 | Function Loss:  -3.2266
# Total loss:  -1.8899 | PDE Loss:  -2.1605 | Function Loss:  -3.2238
# Total loss:  -1.8979 | PDE Loss:  -2.1752 | Function Loss:  -3.224
# Total loss:  -1.9089 | PDE Loss:  -2.1997 | Function Loss:  -3.2205
# Total loss:  -1.9235 | PDE Loss:  -2.2293 | Function Loss:  -3.2199
# Total loss:  -1.9412 | PDE Loss:  -2.2677 | Function Loss:  -3.2182
# Total loss:  -1.9661 | PDE Loss:  -2.3283 | Function Loss:  -3.2135
# Total loss:  -1.9868 | PDE Loss:  -2.3733 | Function Loss:  -3.2164
# Total loss:  -2.0087 | PDE Loss:  -2.4239 | Function Loss:  -3.2195
# Total loss:  -2.029 | PDE Loss:  -2.4874 | Function Loss:  -3.2148
# Total loss:  -2.0396 | PDE Loss:  -2.5218 | Function Loss:  -3.2132
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 hist = pinn.fit(num_epochs=n_epochs,
#       2                 optimizer=optimizer_LBFGS,
#       3                 verbose=True)
#       5 plt.figure(dpi=150)
#       6 plt.grid(True, which="both", ls=":")
#
# Cell In[2], line 225, in Pinns.fit(self, num_epochs, optimizer, verbose)
#     222             history.append(loss.item())
#     223             return loss
# --> 225         optimizer.step(closure=closure)
#     227 print('Final Loss: ', history[-1])
#     229 return history
#
# File ~/opt/anaconda3/envs/dlsc/lib/python3.8/site-packages/torch/optim/optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# File ~/opt/anaconda3/envs/dlsc/lib/python3.8/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/dlsc/lib/python3.8/site-packages/torch/optim/lbfgs.py:426, in LBFGS.step(self, closure)
#     423     def obj_func(x, t, d):
#     424         return self._directional_evaluate(closure, x, t, d)
# --> 426     loss, flat_grad, t, ls_func_evals = _strong_wolfe(
#     427         obj_func, x_init, t, d, loss, flat_grad, gtd)
#     428 self._add_grad(t, d)
#     429 opt_cond = flat_grad.abs().max() <= tolerance_grad
#
# File ~/opt/anaconda3/envs/dlsc/lib/python3.8/site-packages/torch/optim/lbfgs.py:50, in _strong_wolfe(obj_func, x, t, d, f, g, gtd, c1, c2, tolerance_change, max_ls)
#      48 g = g.clone(memory_format=torch.contiguous_format)
#      49 # evaluate objective and gradient using initial step
# ---> 50 f_new, g_new = obj_func(x, t, d)
#      51 ls_func_evals = 1
#      52 gtd_new = g_new.dot(d)
#
# File ~/opt/anaconda3/envs/dlsc/lib/python3.8/site-packages/torch/optim/lbfgs.py:424, in LBFGS.step.<locals>.obj_func(x, t, d)
#     423 def obj_func(x, t, d):
# --> 424     return self._directional_evaluate(closure, x, t, d)
#
# File ~/opt/anaconda3/envs/dlsc/lib/python3.8/site-packages/torch/optim/lbfgs.py:278, in LBFGS._directional_evaluate(self, closure, x, t, d)
#     276 def _directional_evaluate(self, closure, x, t, d):
#     277     self._add_grad(t, d)
# --> 278     loss = float(closure())
#     279     flat_grad = self._gather_flat_grad()
#     280     self._set_param(x)
#
# File ~/opt/anaconda3/envs/dlsc/lib/python3.8/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[2], line 219, in Pinns.fit.<locals>.closure()
#     217 def closure():
#     218     optimizer.zero_grad()
# --> 219     loss = self.compute_loss(inp_train_sb, u_train_sb, inp_train_tb, u_train_tb, inp_train_int, verbose=verbose)
#     220     loss.backward()
#     222     history.append(loss.item())
#
# Cell In[2], line 191, in Pinns.compute_loss(self, inp_train_sb, u_train_sb, inp_train_tb, u_train_tb, inp_train_int, verbose)
#     188 assert (u_pred_tb.shape[1] == u_train_tb.shape[1])
#     189 assert (u_pred_meas.shape[1] == u_train_meas.shape[1])
# --> 191 r_int = self.compute_pde_residual(inp_train_int)
#     192 r_sb = u_train_sb - u_pred_sb
#     193 r_tb = u_train_tb - u_pred_tb
#
# Cell In[2], line 155, in Pinns.compute_pde_residual(self, input_int)
#     153 def compute_pde_residual(self, input_int):
#     154     input_int.requires_grad = True
# --> 155     u = self.approximate_solution(input_int).reshape(-1,)
#     156     k = self.approximate_coefficient(input_int).reshape(-1,)
#     158     # grad compute the gradient of a "SCALAR" function L with respect to some input nxm TENSOR Z=[[x1, y1],[x2,y2],[x3,y3],...,[xn,yn]], m=2
#     159     # it returns grad_L = [[dL/dx1, dL/dy1],[dL/dx2, dL/dy2],[dL/dx3, dL/dy3],...,[dL/dxn, dL/dyn]]
#     160     # Note: pytorch considers a tensor [u1, u2,u3, ... ,un] a vectorial function
#    (...)
#     164     # grad_u = [[dsum_u/dx1, dsum_u/dy1],[dsum_u/dx2, dsum_u/dy2],[dsum_u/dx3, dL/dy3],...,[dsum_u/dxm, dsum_u/dyn]]
#     165     # and dsum_u/dxi = d(u1 + u2 u3 + u4 + ... + un)/dxi = d(u(x1) + u(x2) u3(x3) + u4(x4) + ... + u(xn))/dxi = dui/dxi
#
# File ~/opt/anaconda3/envs/dlsc/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/CAMLab-DLSCTutorial/Common.py:38, in NeuralNet.forward(self, x)
#      35 def forward(self, x):
#      36     # The forward function performs the set of affine and non-linear transformations defining the network
#      37     # (see equation above)
# ---> 38     x = self.activation(self.input_layer(x))
#      39     for k, l in enumerate(self.hidden_layers):
#      40         x = self.activation(l(x))
#
# File ~/opt/anaconda3/envs/dlsc/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/dlsc/lib/python3.8/site-packages/torch/nn/modules/activation.py:359, in Tanh.forward(self, input)
#     358 def forward(self, input: Tensor) -> Tensor:
# --> 359     return torch.tanh(input)
#
# KeyboardInterrupt:

# %%
pinn.plotting()
