# %% [markdown]
# ## Physics Informed Neural Networks to Approximate Solution of PDEs

# %%
from google.colab import drive
drive.mount('/content/drive')
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.optim as optim
from torch.utils.data import DataLoader

from drive.MyDrive.DLSC.Common import NeuralNet

torch.autograd.set_detect_anomaly(True)
torch.manual_seed(128)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Consider the one-dimensional heat equation:
#
# $$
# u_t(t, x) = k(t,x)u_{xx}(t, x) + s(t, x), \quad t\in[0,T], ~x\in [-1,1]
# $$
#
# with zero Dirichlet boundary conditions
#
# $$
# u_b(t, -1)=u_b(t,1)=0,
# $$
#
# and initial condition
#
# $$
# u(x, 0) = u_0(x) = - \sin(\pi x)
# $$
#
# The equation parameter $k:[0,T]\times[-1,1]\mapsto \mathbb{R} $ denotes the medium conductivity and $s:[0,T]\times[-1,1]\mapsto \mathbb{R}$ is a source term.
#
# We want to solve a parameter identification inverse problem, which can be formulated as follows:
#
# *given observation measurements of the medium temperature $S_{meas}=\{(t_i, x_i, u^{meas}_{i})\}_{i=1}^{N_{meas}}$, find $u: [0,T]\times[-1,1]\mapsto\mathbb{R}$ and $k:[-1,1]\mapsto \mathbb{R}$, such that $u_t(t, x) = k(t,x)u_{xx}(t, x) + s(t,x)$, $u_b(t, -1)=u_b(t,1)=0, $ and $u(x, 0) = u_0(x) = -\sin(\pi x)$*
#
#
#
# To do so, we approximate the underlying solution and the medium conductivity with two feedforward dense neural network with tunable parameters $\theta$ and $\phi$:
#
# $$
# u_\theta(t,x) \approx u(t,x), \quad k_\phi(t, x) \approx k(t, x)
# $$
# To do so, define the following residuals:
#
#    - Interior residual given by,
#    $$r_{int,\theta, \phi}(t, x):=  u_{\theta, t}(t, x) - k_\phi(t,x)u_{\theta, xx}(t, x) -s(t,x), \quad \forall ~t \in [0,T],~ x \in [-1,1].$$
#
#
#
#    - Spatial boundary residual given by,
#
#         $$r_{sb,\theta}(t,-1):= u_{\theta}(t,-1)- u_b(t,-1), \quad r_{sb,\theta}(t,1):= u_{\theta}(t,1)- u_b(t,1), \quad \forall t \in (0,T].$$
#
#    - Temporal boundary residual given by,
#
#         $$r_{tb,\theta}(x):= u_{\theta}(x,0) - u_0(x), \quad \forall x \in [-1,1].$$
#
# and compute the corresponding loss functions:
#
# $$
# L_{int}(\theta, \phi) = \int_{[0,T]\times[-1,1]}r_{int,\theta, \phi}^2(t, x) dtdx, \quad
# L_{sb}(\theta) = \int_{[0,T]}r_{sb,\theta}^2(t,-1) dt + \int_{[0,T]}r_{sb,\theta}^2(t,1)dt, \quad
# L_{tb}(\theta) = \int_{[-1,1]}r_{tb,\theta}^2(x) dx
# $$
#
# The loss functions include integrals that can be approximated by suitable quadrature rule. We use quasi Monte-Carlo and accordingly define the following training sets
#
# $$
# S_{int} =\{y_n\}, \quad 1 \leq n \leq N_{int},\quad y_n = (x,t)_n \in D_T,
# $$
#
# $$
# S_{sb, -1} =\{t_n, u_b(t_n,-1) \}, \quad 1 \leq n \leq N_{sb}, t_n \in [0,T],
# $$
#
# $$
# S_{sb, 1} =\{t_n, u_b(t_n,1) \}, \quad1 \leq n \leq N_{sb}, t_n \in [0,T],
# $$
#
# $$
# S_{tb}=\{x_n, u_0(x_n)\}\quad  1 \leq n \leq N_{tb}, x_n \in [-1,1].
# $$
#
# with the training inputs points corresponding to low-discrepancy Sobol sequences:
#
# $$
# L_{int}(\theta, \phi) = \frac{1}{N_{int}}\sum_{i=1}^{N_{int}}r_{int,\theta,\phi}^2(y_n), \quad
# L_{sb}(\theta) = \frac{1}{N_{sb}}\sum_{i=1}^{N_{sb}}r_{sb,\theta}^2(t_n,-1) + \frac{1}{N_{sb}}\sum_{i=1}^{N_{sb}}r_{sb,\theta}^2(t_n,1), \quad
# L_{tb}(\theta) = \frac{1}{N_{tb}}\sum_{i=1}^{N_{tb}}r_{tb,\theta}^2(x_n)
# $$
#
# Also the measurements data $S_{meas}$ have to taken into account. To do so, we define ad additional loss term:
# $$
# L_{meas} = \frac{1}{N_{meas}}\sum_{i=1}^{N_{mean}}(u_\theta(t_i, x_i) - u^{meas}_i)^2(x_n)
# $$
# and eventually solve the following minimization problem
#
# $$
# \theta^\ast, \phi^\ast = argmin_{\theta, \phi} \Big(L_{int}(\theta, \phi) + \lambda_u L_u(\theta)\Big)
# $$
#
# with
#
# $$
# L_u(\theta) = L_{tb}(\theta) + L_{sb}(\theta) + L_{meas}(\theta)
# $$
#
#
# In the following let's assume
#
# $$u_{ex}(t,x) = -\exp(-\pi^2 t)\sin(\pi x), \quad k(t,x)=k(x)=\sin(\pi x).$$
#
# Then, the source term $s$ can be computed by plugging the expression above in the PDE:
#
# $$
# s(t,x) = -\pi^2u_{ex}(t,x)*(1 - k(t,x))
# $$
#
# Moreover, let us assume that the measurments data are given as follows:
#
# $$
# u_{meas}(x_i, t_i) = u_{ex}(x_i t_i) + 0.01\xi, \quad \xi \sim \mathcal{N(0, 1)}
# $$
#
# where $\mathcal{N(0, 1)}$ is a standard normal distribution.

# %%
class Pinns:
    def __init__(self, n_int_, n_sb_, n_tb_):
        self.n_int = n_int_
        self.n_sb = n_sb_
        self.n_tb = n_tb_


        # Extrema of the solution domain (t,x) in [0,0.1]x[-1,1]
        self.domain_extrema = torch.tensor([[0, 0.1],  # Time dimension
                                            [-1, 1]])  # Space dimension

        # Number of space dimensions
        self.space_dimensions = 1

        # Parameter to balance role of data and PDE
        self.lambda_u = 10

        # FF Dense NN to approximate the solution of the underlying heat equation
        self.approximate_solution = NeuralNet(input_dimension=self.domain_extrema.shape[0], output_dimension=1,
                                              n_hidden_layers=4,
                                              neurons=20,
                                              regularization_param=0.,
                                              regularization_exp=2.,
                                              retrain_seed=42)

        # FF Dense NN to approximate the conductivity we wish to infer
        self.approximate_coefficient = NeuralNet(input_dimension=self.domain_extrema.shape[0], output_dimension=1,
                                                 n_hidden_layers=4,
                                                 neurons=20,
                                                 regularization_param=0.,
                                                 regularization_exp=2.,
                                                 retrain_seed=42)

        # Generator of Sobol sequences
        self.soboleng = torch.quasirandom.SobolEngine(dimension=self.domain_extrema.shape[0])

        # Training sets S_sb, S_tb, S_int as torch dataloader
        self.training_set_sb, self.training_set_tb, self.training_set_int = self.assemble_datasets()

        # number of sensors to record temperature
        self.n_sensor = 50

    ################################################################################################
    # Function to linearly transform a tensor whose value are between 0 and 1
    # to a tensor whose values are between the domain extrema
    def convert(self, tens):
        assert (tens.shape[1] == self.domain_extrema.shape[0])
        return tens * (self.domain_extrema[:, 1] - self.domain_extrema[:, 0]) + self.domain_extrema[:, 0]

    # Initial condition to solve the heat equation u0(x)=-sin(pi x)
    def initial_condition(self, x):
        return -torch.sin(np.pi * x)

    # Exact solution for the heat equation ut = u_xx with the IC above
    def exact_solution(self, inputs):
        t = inputs[:, 0]
        x = inputs[:, 1]

        u = -torch.exp(-np.pi ** 2 * t) * torch.sin(np.pi * x)
        return u

    def exact_conductivity(self, inputs):
        t = inputs[:, 0]
        x = inputs[:, 1]
        k = (torch.sin(np.pi * x) + 1.1)

        return k


    def source(self, inputs):

        s = -np.pi**2*self.exact_solution(inputs)*(1 - self.exact_conductivity(inputs))
        return s

    ################################################################################################
    # Function returning the input-output tensor required to assemble the training set S_tb corresponding to the temporal boundary
    def add_temporal_boundary_points(self):
        t0 = self.domain_extrema[0, 0]
        input_tb = self.convert(self.soboleng.draw(self.n_tb))
        input_tb[:, 0] = torch.full(input_tb[:, 0].shape, t0)
        output_tb = self.initial_condition(input_tb[:, 1]).reshape(-1, 1)

        return input_tb, output_tb

    # Function returning the input-output tensor required to assemble the training set S_sb corresponding to the spatial boundary
    def add_spatial_boundary_points(self):
        x0 = self.domain_extrema[1, 0]
        xL = self.domain_extrema[1, 1]

        input_sb = self.convert(self.soboleng.draw(self.n_sb))

        input_sb_0 = torch.clone(input_sb)
        input_sb_0[:, 1] = torch.full(input_sb_0[:, 1].shape, x0)

        input_sb_L = torch.clone(input_sb)
        input_sb_L[:, 1] = torch.full(input_sb_L[:, 1].shape, xL)

        output_sb_0 = torch.zeros((input_sb.shape[0], 1))
        output_sb_L = torch.zeros((input_sb.shape[0], 1))

        return torch.cat([input_sb_0, input_sb_L], 0), torch.cat([output_sb_0, output_sb_L], 0)

    #  Function returning the input-output tensor required to assemble the training set S_int corresponding to the interior domain where the PDE is enforced
    def add_interior_points(self):
        input_int = self.convert(self.soboleng.draw(self.n_int))
        output_int = torch.zeros((input_int.shape[0], 1))
        return input_int, output_int
    

    def get_measurement_data(self):
        torch.random.manual_seed(42)
        # take measurments every 0.001 sec on a set of randomly placed (in space) sensors
        t = torch.linspace(0, self.domain_extrema[0, 1], 25)
        x = torch.linspace(self.domain_extrema[1, 0], self.domain_extrema[1, 1], self.n_sensor)


        input_meas = torch.cartesian_prod(t, x)

        output_meas = self.exact_solution(input_meas).reshape(-1,1)
        noise = 0.01*torch.randn_like(output_meas)
        output_meas = output_meas + noise

        return input_meas, output_meas



    # Function returning the training sets S_sb, S_tb, S_int as dataloader
    def assemble_datasets(self):
        input_sb, output_sb = self.add_spatial_boundary_points()  # S_sb
        input_tb, output_tb = self.add_temporal_boundary_points()  # S_tb
        input_int, output_int = self.add_interior_points()  # S_int

        training_set_sb = DataLoader(torch.utils.data.TensorDataset(input_sb, output_sb), batch_size=2 * self.space_dimensions * self.n_sb, shuffle=False)
        training_set_tb = DataLoader(torch.utils.data.TensorDataset(input_tb, output_tb), batch_size=self.n_tb, shuffle=False)
        training_set_int = DataLoader(torch.utils.data.TensorDataset(input_int, output_int), batch_size=self.n_int, shuffle=False)

        return training_set_sb, training_set_tb, training_set_int

    ################################################################################################
    # Function to compute the terms required in the definition of the TEMPORAL boundary residual
    def apply_initial_condition(self, input_tb):
        u_pred_tb = self.approximate_solution(input_tb)
        return u_pred_tb

    # Function to compute the terms required in the definition of the SPATIAL boundary residual
    def apply_boundary_conditions(self, input_sb):
        u_pred_sb = self.approximate_solution(input_sb)

        return u_pred_sb


    # Function to compute the PDE residuals
    def compute_pde_residual(self, input_int):
        input_int.requires_grad = True
        u = self.approximate_solution(input_int).reshape(-1,)
        k = self.approximate_coefficient(input_int).reshape(-1,)

        # grad compute the gradient of a "SCALAR" function L with respect to some input nxm TENSOR Z=[[x1, y1],[x2,y2],[x3,y3],...,[xn,yn]], m=2
        # it returns grad_L = [[dL/dx1, dL/dy1],[dL/dx2, dL/dy2],[dL/dx3, dL/dy3],...,[dL/dxn, dL/dyn]]
        # Note: pytorch considers a tensor [u1, u2,u3, ... ,un] a vectorial function
        # whereas sum_u = u1 + u2 u3 + u4 + ... + un as a "scalar" one

        # In our case ui = u(xi), therefore the line below returns:
        # grad_u = [[dsum_u/dx1, dsum_u/dy1],[dsum_u/dx2, dsum_u/dy2],[dsum_u/dx3, dL/dy3],...,[dsum_u/dxm, dsum_u/dyn]]
        # and dsum_u/dxi = d(u1 + u2 u3 + u4 + ... + un)/dxi = d(u(x1) + u(x2) u3(x3) + u4(x4) + ... + u(xn))/dxi = dui/dxi
        grad_u = torch.autograd.grad(u.sum(), input_int, create_graph=True)[0]
        grad_u_t = grad_u[:, 0]
        grad_u_x = grad_u[:, 1]
        grad_u_xx = torch.autograd.grad(grad_u_x.sum(), input_int, create_graph=True)[0][:, 1]


        s = self.source(input_int)


        residual = grad_u_t - k*grad_u_xx - s

        return residual.reshape(-1, )

    # Function to compute the total loss (weighted sum of spatial boundary loss, temporal boundary loss and interior loss)
    def compute_loss(self, inp_train_sb, u_train_sb, inp_train_tb, u_train_tb, inp_train_int, verbose=True):
        u_pred_sb = self.apply_boundary_conditions(inp_train_sb)
        u_pred_tb = self.apply_initial_condition(inp_train_tb)

        inp_train_meas, u_train_meas = self.get_measurement_data()
        u_pred_meas = self.approximate_solution(inp_train_meas)

        assert (u_pred_sb.shape[1] == u_train_sb.shape[1])
        assert (u_pred_tb.shape[1] == u_train_tb.shape[1])
        assert (u_pred_meas.shape[1] == u_train_meas.shape[1])

        r_int = self.compute_pde_residual(inp_train_int)
        r_sb = u_train_sb - u_pred_sb
        r_tb = u_train_tb - u_pred_tb
        r_meas = u_train_meas - u_pred_meas

        loss_sb = torch.mean(abs(r_sb) ** 2)
        loss_tb = torch.mean(abs(r_tb) ** 2)
        loss_int = torch.mean(abs(r_int) ** 2)
        loss_meas = torch.mean(abs(r_meas) ** 2)

        loss_u = loss_sb + loss_tb + loss_meas

        loss = torch.log10(self.lambda_u * loss_u + loss_int)
        if verbose: print("Total loss: ", round(loss.item(), 4), "| PDE Loss: ", round(torch.log10(loss_int).item(), 4), "| Function Loss: ", round(torch.log10(loss_u).item(), 4))

        return loss

    ################################################################################################
    def fit(self, num_epochs, optimizer, verbose=True):
        history = list()

        # Loop over epochs
        for epoch in range(num_epochs):
            if verbose: print("################################ ", epoch, " ################################")

            for j, ((inp_train_sb, u_train_sb), (inp_train_tb, u_train_tb), (inp_train_int, u_train_int)) in enumerate(zip(self.training_set_sb, self.training_set_tb, self.training_set_int)):
                def closure():
                    optimizer.zero_grad()
                    loss = self.compute_loss(inp_train_sb, u_train_sb, inp_train_tb, u_train_tb, inp_train_int, verbose=verbose)
                    loss.backward()

                    history.append(loss.item())
                    return loss

                optimizer.step(closure=closure)

        print('Final Loss: ', history[-1])

        return history

    ################################################################################################
    def plotting(self):
        inputs = self.soboleng.draw(100000)
        inputs = self.convert(inputs)

        output = self.approximate_solution(inputs).reshape(-1, )
        exact_output = self.exact_solution(inputs).reshape(-1, )

        fig, axs = plt.subplots(1, 2, figsize=(16, 8), dpi=150)
        im1 = axs[0].scatter(inputs[:, 1].detach(), inputs[:, 0].detach(), c=exact_output.detach(), cmap="jet")
        axs[0].set_xlabel("x")
        axs[0].set_ylabel("t")
        plt.colorbar(im1, ax=axs[0])
        axs[0].grid(True, which="both", ls=":")
        im2 = axs[1].scatter(inputs[:, 1].detach(), inputs[:, 0].detach(), c=output.detach(), cmap="jet")
        axs[1].set_xlabel("x")
        axs[1].set_ylabel("t")
        plt.colorbar(im2, ax=axs[1])
        axs[1].grid(True, which="both", ls=":")
        axs[0].set_title("Exact Solution")
        axs[1].set_title("Approximate Solution")

        err = (torch.mean((output - exact_output) ** 2) / torch.mean(exact_output ** 2)) ** 0.5 * 100
        print("L2 Relative Error Norm U: ", err.item(), "%")

        approximate_conductivity = self.approximate_coefficient(inputs).reshape(-1, )
        exact_conductivity = self.exact_conductivity(inputs).reshape(-1, )


        fig, axs = plt.subplots(1, 2, figsize=(16, 8), dpi=150)
        im1 = axs[0].scatter(inputs[:, 1].detach(), inputs[:, 0].detach(), c=exact_conductivity.detach(), cmap="jet")
        axs[0].set_xlabel("x")
        axs[0].set_ylabel("t")
        plt.colorbar(im1, ax=axs[0])
        axs[0].grid(True, which="both", ls=":")
        im2 = axs[1].scatter(inputs[:, 1].detach(), inputs[:, 0].detach(), c=approximate_conductivity.detach(), cmap="jet")
        axs[1].set_xlabel("x")
        axs[1].set_ylabel("t")
        plt.colorbar(im2, ax=axs[1])
        axs[1].grid(True, which="both", ls=":")
        axs[0].set_title("Exact Conductivity")
        axs[1].set_title("Approximate Conductivity")

        err = (torch.mean((approximate_conductivity - exact_conductivity) ** 2) / torch.mean(exact_conductivity ** 2)) ** 0.5 * 100
        print("L2 Relative Error Norm K: ", err.item(), "%")

        plt.show()

# %%
# Solve the heat equation:
# u_t = u_xx, (t,x) in [0, 0.1]x[-1,1]
# with zero dirichlet BC and
# u(x,0)= -sin(pi x)

n_int = 256
n_sb = 64
n_tb = 64

pinn = Pinns(n_int, n_sb, n_tb)

# %%
# Plot the input training points
input_sb_, output_sb_ = pinn.add_spatial_boundary_points()
input_tb_, output_tb_ = pinn.add_temporal_boundary_points()
input_int_, output_int_ = pinn.add_interior_points()
input_meas_, output_meas_ = pinn.get_measurement_data()

plt.figure(figsize=(16, 8), dpi=150)
plt.scatter(input_sb_[:, 1].detach().numpy(), input_sb_[:, 0].detach().numpy(), label="Boundary Points")
plt.scatter(input_int_[:, 1].detach().numpy(), input_int_[:, 0].detach().numpy(), label="Interior Points")
plt.scatter(input_tb_[:, 1].detach().numpy(), input_tb_[:, 0].detach().numpy(), label="Initial Points")
plt.scatter(input_meas_[:, 1].detach().numpy(), input_meas_[:, 0].detach().numpy(), label="Sensors Points", marker="*")
plt.xlabel("x")
plt.ylabel("t")
plt.legend()
plt.show()

# %%
n_epochs = 1
optimizer_LBFGS = optim.LBFGS(list(pinn.approximate_solution.parameters()) + list(pinn.approximate_coefficient.parameters()),
                              lr=float(0.5),
                              max_iter=1000,
                              max_eval=50000,
                              history_size=150,
                              line_search_fn="strong_wolfe",
                              tolerance_change=1.0 * np.finfo(float).eps)
optimizer_ADAM = optim.Adam(pinn.approximate_solution.parameters(),
                            lr=float(0.005))

# %%
hist = pinn.fit(num_epochs=n_epochs,
                optimizer=optimizer_LBFGS,
                verbose=True)

plt.figure(dpi=150)
plt.grid(True, which="both", ls=":")
plt.plot(np.arange(1, len(hist) + 1), hist, label="Train Loss")
plt.xscale("log")
plt.legend()
# Out:
# ################################  0  ################################
# Total loss:  1.9527 | PDE Loss:  1.8761 | Function Loss:  0.1619
# Total loss:  1.9061 | PDE Loss:  1.8385 | Function Loss:  0.0651
# Total loss:  1.521 | PDE Loss:  1.3634 | Function Loss:  0.0043
# Total loss:  1.6588 | PDE Loss:  0.7416 | Function Loss:  0.6028
# Total loss:  1.4441 | PDE Loss:  1.0571 | Function Loss:  0.2148
# Total loss:  1.3283 | PDE Loss:  0.9053 | Function Loss:  0.1223
# Total loss:  1.0769 | PDE Loss:  0.7616 | Function Loss:  -0.2104
# Total loss:  0.9578 | PDE Loss:  0.6288 | Function Loss:  -0.317
# Total loss:  0.9077 | PDE Loss:  0.5676 | Function Loss:  -0.3576
# Total loss:  0.8718 | PDE Loss:  0.5121 | Function Loss:  -0.3775
# Total loss:  0.8571 | PDE Loss:  0.4938 | Function Loss:  -0.3895
# Total loss:  0.8437 | PDE Loss:  0.4778 | Function Loss:  -0.4009
# Total loss:  0.8078 | PDE Loss:  0.4427 | Function Loss:  -0.4374
# Total loss:  0.7239 | PDE Loss:  0.4144 | Function Loss:  -0.5689
# Total loss:  0.6475 | PDE Loss:  0.3431 | Function Loss:  -0.6502
# Total loss:  0.5538 | PDE Loss:  0.2427 | Function Loss:  -0.7375
# Total loss:  0.53 | PDE Loss:  0.206 | Function Loss:  -0.7492
# Total loss:  0.5065 | PDE Loss:  0.1677 | Function Loss:  -0.7597
# Total loss:  0.4678 | PDE Loss:  0.117 | Function Loss:  -0.7886
# Total loss:  0.4379 | PDE Loss:  0.0608 | Function Loss:  -0.7984
# Total loss:  0.4016 | PDE Loss:  0.0548 | Function Loss:  -0.858
# Total loss:  0.3607 | PDE Loss:  0.0228 | Function Loss:  -0.9062
# Total loss:  0.2745 | PDE Loss:  -0.0625 | Function Loss:  -0.9933
# Total loss:  0.2436 | PDE Loss:  -0.1058 | Function Loss:  -1.0139
# Total loss:  0.229 | PDE Loss:  -0.1368 | Function Loss:  -1.0157
# Total loss:  0.2112 | PDE Loss:  -0.1618 | Function Loss:  -1.0282
# Total loss:  0.185 | PDE Loss:  -0.2012 | Function Loss:  -1.0449
# Total loss:  0.1528 | PDE Loss:  -0.2339 | Function Loss:  -1.0767
# Total loss:  0.1212 | PDE Loss:  -0.2758 | Function Loss:  -1.1013
# Total loss:  0.1083 | PDE Loss:  -0.2971 | Function Loss:  -1.1086
# Total loss:  0.0909 | PDE Loss:  -0.3349 | Function Loss:  -1.1133
# Total loss:  0.0778 | PDE Loss:  -0.3635 | Function Loss:  -1.1174
# Total loss:  0.0677 | PDE Loss:  -0.3868 | Function Loss:  -1.1201
# Total loss:  0.0549 | PDE Loss:  -0.4138 | Function Loss:  -1.1255
# Total loss:  0.0264 | PDE Loss:  -0.4706 | Function Loss:  -1.14
# Total loss:  -0.0078 | PDE Loss:  -0.5392 | Function Loss:  -1.1591
# Total loss:  -0.0386 | PDE Loss:  -0.5834 | Function Loss:  -1.1844
# Total loss:  -0.0626 | PDE Loss:  -0.5842 | Function Loss:  -1.2181
# Total loss:  -0.0784 | PDE Loss:  -0.601 | Function Loss:  -1.2335
# Total loss:  -0.0876 | PDE Loss:  -0.6185 | Function Loss:  -1.239
# Total loss:  -0.099 | PDE Loss:  -0.6404 | Function Loss:  -1.2462
# Total loss:  -0.1144 | PDE Loss:  -0.6732 | Function Loss:  -1.2548
# Total loss:  -0.1333 | PDE Loss:  -0.7194 | Function Loss:  -1.2637
# Total loss:  -0.1519 | PDE Loss:  -0.7694 | Function Loss:  -1.2718
# Total loss:  -0.1734 | PDE Loss:  -0.8453 | Function Loss:  -1.2774
# Total loss:  -0.204 | PDE Loss:  -0.9402 | Function Loss:  -1.2921
# Total loss:  -0.2332 | PDE Loss:  -0.9985 | Function Loss:  -1.315
# Total loss:  -0.2598 | PDE Loss:  -1.0374 | Function Loss:  -1.3391
# Total loss:  -0.2791 | PDE Loss:  -1.029 | Function Loss:  -1.3641
# Total loss:  -0.2944 | PDE Loss:  -1.0476 | Function Loss:  -1.3787
# Total loss:  -0.3049 | PDE Loss:  -0.9801 | Function Loss:  -1.408
# Total loss:  -0.3331 | PDE Loss:  -0.9931 | Function Loss:  -1.4404
# Total loss:  -0.3577 | PDE Loss:  -1.0463 | Function Loss:  -1.4573
# Total loss:  -0.3756 | PDE Loss:  -1.0247 | Function Loss:  -1.486
# Total loss:  -0.3799 | PDE Loss:  -1.0893 | Function Loss:  -1.4742
# Total loss:  -0.3864 | PDE Loss:  -1.0943 | Function Loss:  -1.4811
# Total loss:  -0.3916 | PDE Loss:  -1.1067 | Function Loss:  -1.4846
# Total loss:  -0.3973 | PDE Loss:  -1.1224 | Function Loss:  -1.4879
# Total loss:  -0.4025 | PDE Loss:  -1.1471 | Function Loss:  -1.4887
# Total loss:  -0.407 | PDE Loss:  -1.176 | Function Loss:  -1.4881
# Total loss:  -0.4116 | PDE Loss:  -1.204 | Function Loss:  -1.488
# Total loss:  -0.416 | PDE Loss:  -1.2245 | Function Loss:  -1.4894
# Total loss:  -0.4203 | PDE Loss:  -1.2541 | Function Loss:  -1.4891
# Total loss:  -0.4267 | PDE Loss:  -1.2713 | Function Loss:  -1.4938
# Total loss:  -0.4354 | PDE Loss:  -1.2969 | Function Loss:  -1.4996
# Total loss:  -0.4435 | PDE Loss:  -1.2917 | Function Loss:  -1.5099
# Total loss:  -0.4489 | PDE Loss:  -1.2732 | Function Loss:  -1.5194
# Total loss:  -0.4524 | PDE Loss:  -1.2508 | Function Loss:  -1.5276
# Total loss:  -0.456 | PDE Loss:  -1.2301 | Function Loss:  -1.536
# Total loss:  -0.4603 | PDE Loss:  -1.2123 | Function Loss:  -1.5449
# Total loss:  -0.4652 | PDE Loss:  -1.1996 | Function Loss:  -1.5537
# Total loss:  -0.4725 | PDE Loss:  -1.1898 | Function Loss:  -1.5649
# Total loss:  -0.4806 | PDE Loss:  -1.181 | Function Loss:  -1.5772
# Total loss:  -0.4905 | PDE Loss:  -1.1732 | Function Loss:  -1.5916
# Total loss:  -0.5042 | PDE Loss:  -1.1708 | Function Loss:  -1.6095
# Total loss:  -0.5207 | PDE Loss:  -1.1542 | Function Loss:  -1.6357
# Total loss:  -0.5385 | PDE Loss:  -1.1738 | Function Loss:  -1.653
# Total loss:  -0.5515 | PDE Loss:  -1.1829 | Function Loss:  -1.6671
# Total loss:  -0.5608 | PDE Loss:  -1.1889 | Function Loss:  -1.6774
# Total loss:  -0.5697 | PDE Loss:  -1.2348 | Function Loss:  -1.6756
# Total loss:  -0.572 | PDE Loss:  -1.2368 | Function Loss:  -1.6779
# Total loss:  -0.5733 | PDE Loss:  -1.2396 | Function Loss:  -1.6788
# Total loss:  -0.5759 | PDE Loss:  -1.2444 | Function Loss:  -1.6808
# Total loss:  -0.5793 | PDE Loss:  -1.2587 | Function Loss:  -1.6813
# Total loss:  -0.5821 | PDE Loss:  -1.2585 | Function Loss:  -1.6848
# Total loss:  -0.5847 | PDE Loss:  -1.2611 | Function Loss:  -1.6874
# Total loss:  -0.5884 | PDE Loss:  -1.257 | Function Loss:  -1.6932
# Total loss:  -0.5924 | PDE Loss:  -1.2581 | Function Loss:  -1.698
# Total loss:  -0.5959 | PDE Loss:  -1.2524 | Function Loss:  -1.7041
# Total loss:  -0.6001 | PDE Loss:  -1.254 | Function Loss:  -1.709
# Total loss:  -0.605 | PDE Loss:  -1.248 | Function Loss:  -1.7171
# Total loss:  -0.6095 | PDE Loss:  -1.2487 | Function Loss:  -1.7228
# Total loss:  -0.6165 | PDE Loss:  -1.2491 | Function Loss:  -1.7318
# Total loss:  -0.6256 | PDE Loss:  -1.2555 | Function Loss:  -1.7417
# Total loss:  -0.634 | PDE Loss:  -1.2622 | Function Loss:  -1.7506
# Total loss:  -0.6434 | PDE Loss:  -1.293 | Function Loss:  -1.7535
# Total loss:  -0.6517 | PDE Loss:  -1.3178 | Function Loss:  -1.7573
# Total loss:  -0.6575 | PDE Loss:  -1.3261 | Function Loss:  -1.7623
# Total loss:  -0.6642 | PDE Loss:  -1.342 | Function Loss:  -1.7666
# Total loss:  -0.6705 | PDE Loss:  -1.3483 | Function Loss:  -1.7728
# Total loss:  -0.686 | PDE Loss:  -1.3631 | Function Loss:  -1.7885
# Total loss:  -0.6999 | PDE Loss:  -1.36 | Function Loss:  -1.8071
# Total loss:  -0.712 | PDE Loss:  -1.3779 | Function Loss:  -1.8175
# Total loss:  -0.7209 | PDE Loss:  -1.354 | Function Loss:  -1.836
# Total loss:  -0.7318 | PDE Loss:  -1.3475 | Function Loss:  -1.8523
# Total loss:  -0.7471 | PDE Loss:  -1.3559 | Function Loss:  -1.8698
# Total loss:  -0.7577 | PDE Loss:  -1.3308 | Function Loss:  -1.8927
# Total loss:  -0.7771 | PDE Loss:  -1.3621 | Function Loss:  -1.9078
# Total loss:  -0.7924 | PDE Loss:  -1.3748 | Function Loss:  -1.9241
# Total loss:  -0.7974 | PDE Loss:  -1.2988 | Function Loss:  -1.9618
# Total loss:  -0.8062 | PDE Loss:  -1.3552 | Function Loss:  -1.9504
# Total loss:  -0.818 | PDE Loss:  -1.3599 | Function Loss:  -1.965
# Total loss:  -0.8271 | PDE Loss:  -1.3358 | Function Loss:  -1.9882
# Total loss:  -0.8408 | PDE Loss:  -1.327 | Function Loss:  -2.0124
# Total loss:  -0.8506 | PDE Loss:  -1.3181 | Function Loss:  -2.0316
# Total loss:  -0.8568 | PDE Loss:  -1.3237 | Function Loss:  -2.0381
# Total loss:  -0.86 | PDE Loss:  -1.3151 | Function Loss:  -2.0476
# Total loss:  -0.8657 | PDE Loss:  -1.3245 | Function Loss:  -2.0513
# Total loss:  -0.8685 | PDE Loss:  -1.3411 | Function Loss:  -2.0468
# Total loss:  -0.8732 | PDE Loss:  -1.3606 | Function Loss:  -2.0442
# Total loss:  -0.8791 | PDE Loss:  -1.3824 | Function Loss:  -2.0427
# Total loss:  -0.8889 | PDE Loss:  -1.416 | Function Loss:  -2.042
# Total loss:  -0.9054 | PDE Loss:  -1.4467 | Function Loss:  -2.0527
# Total loss:  -0.9309 | PDE Loss:  -1.4918 | Function Loss:  -2.0705
# Total loss:  -0.9462 | PDE Loss:  -1.5053 | Function Loss:  -2.0865
# Total loss:  -0.9568 | PDE Loss:  -1.5227 | Function Loss:  -2.0945
# Total loss:  -0.9554 | PDE Loss:  -1.4614 | Function Loss:  -2.1177
# Total loss:  -0.962 | PDE Loss:  -1.5117 | Function Loss:  -2.1058
# Total loss:  -0.9669 | PDE Loss:  -1.5126 | Function Loss:  -2.1124
# Total loss:  -0.9716 | PDE Loss:  -1.5214 | Function Loss:  -2.1155
# Total loss:  -0.9755 | PDE Loss:  -1.5372 | Function Loss:  -2.1148
# Total loss:  -0.9822 | PDE Loss:  -1.5388 | Function Loss:  -2.1234
# Total loss:  -0.9894 | PDE Loss:  -1.539 | Function Loss:  -2.1334
# Total loss:  -0.9959 | PDE Loss:  -1.5231 | Function Loss:  -2.149
# Total loss:  -1.0024 | PDE Loss:  -1.51 | Function Loss:  -2.1641
# Total loss:  -1.0107 | PDE Loss:  -1.4988 | Function Loss:  -2.1815
# Total loss:  -1.0236 | PDE Loss:  -1.4837 | Function Loss:  -2.2085
# Total loss:  -1.0381 | PDE Loss:  -1.4776 | Function Loss:  -2.2343
# Total loss:  -1.0535 | PDE Loss:  -1.4721 | Function Loss:  -2.2621
# Total loss:  -1.0739 | PDE Loss:  -1.4796 | Function Loss:  -2.2907
# Total loss:  -1.0977 | PDE Loss:  -1.494 | Function Loss:  -2.3206
# Total loss:  -1.1131 | PDE Loss:  -1.5031 | Function Loss:  -2.3404
# Total loss:  -1.121 | PDE Loss:  -1.5242 | Function Loss:  -2.3394
# Total loss:  -1.1253 | PDE Loss:  -1.5411 | Function Loss:  -2.3356
# Total loss:  -1.1284 | PDE Loss:  -1.5649 | Function Loss:  -2.3262
# Total loss:  -1.1296 | PDE Loss:  -1.5753 | Function Loss:  -2.3223
# Total loss:  -1.1325 | PDE Loss:  -1.593 | Function Loss:  -2.3171
# Total loss:  -1.1364 | PDE Loss:  -1.6094 | Function Loss:  -2.3145
# Total loss:  -1.1421 | PDE Loss:  -1.6272 | Function Loss:  -2.3142
# Total loss:  -1.1501 | PDE Loss:  -1.6433 | Function Loss:  -2.3184
# Total loss:  -1.1606 | PDE Loss:  -1.6557 | Function Loss:  -2.328
# Total loss:  -1.1714 | PDE Loss:  -1.6658 | Function Loss:  -2.3391
# Total loss:  -1.1847 | PDE Loss:  -1.6562 | Function Loss:  -2.3637
# Total loss:  -1.19 | PDE Loss:  -1.6538 | Function Loss:  -2.3729
# Total loss:  -1.195 | PDE Loss:  -1.6496 | Function Loss:  -2.3829
# Total loss:  -1.2025 | PDE Loss:  -1.6448 | Function Loss:  -2.3971
# Total loss:  -1.211 | PDE Loss:  -1.6321 | Function Loss:  -2.4181
# Total loss:  -1.2154 | PDE Loss:  -1.6215 | Function Loss:  -2.432
# Total loss:  -1.2244 | PDE Loss:  -1.6396 | Function Loss:  -2.4352
# Total loss:  -1.2354 | PDE Loss:  -1.6715 | Function Loss:  -2.4336
# Total loss:  -1.2476 | PDE Loss:  -1.7005 | Function Loss:  -2.4363
# Total loss:  -1.2565 | PDE Loss:  -1.7177 | Function Loss:  -2.4407
# Total loss:  -1.2712 | PDE Loss:  -1.7504 | Function Loss:  -2.4463
# Total loss:  -1.2778 | PDE Loss:  -1.7203 | Function Loss:  -2.4723
# Total loss:  -1.2843 | PDE Loss:  -1.7463 | Function Loss:  -2.4681
# Total loss:  -1.2889 | PDE Loss:  -1.7496 | Function Loss:  -2.4734
# Total loss:  -1.2941 | PDE Loss:  -1.7423 | Function Loss:  -2.4853
# Total loss:  -1.2995 | PDE Loss:  -1.7286 | Function Loss:  -2.5017
# Total loss:  -1.3033 | PDE Loss:  -1.7166 | Function Loss:  -2.5152
# Total loss:  -1.3066 | PDE Loss:  -1.7105 | Function Loss:  -2.5246
# Total loss:  -1.3114 | PDE Loss:  -1.7027 | Function Loss:  -2.5378
# Total loss:  -1.318 | PDE Loss:  -1.6983 | Function Loss:  -2.552
# Total loss:  -1.3258 | PDE Loss:  -1.6892 | Function Loss:  -2.5723
# Total loss:  -1.3355 | PDE Loss:  -1.686 | Function Loss:  -2.592
# Total loss:  -1.3528 | PDE Loss:  -1.6892 | Function Loss:  -2.6211
# Total loss:  -1.3771 | PDE Loss:  -1.6947 | Function Loss:  -2.6621
# Total loss:  -1.3985 | PDE Loss:  -1.7138 | Function Loss:  -2.6858
# Total loss:  -1.4184 | PDE Loss:  -1.7238 | Function Loss:  -2.7152
# Total loss:  -1.4354 | PDE Loss:  -1.7431 | Function Loss:  -2.73
# Total loss:  -1.4462 | PDE Loss:  -1.7745 | Function Loss:  -2.7216
# Total loss:  -1.4688 | PDE Loss:  -1.8023 | Function Loss:  -2.7396
# Total loss:  -1.4821 | PDE Loss:  -1.8127 | Function Loss:  -2.7554
# Total loss:  -1.4881 | PDE Loss:  -1.8121 | Function Loss:  -2.7673
# Total loss:  -1.4947 | PDE Loss:  -1.8195 | Function Loss:  -2.7732
# Total loss:  -1.4991 | PDE Loss:  -1.8285 | Function Loss:  -2.7736
# Total loss:  -1.5029 | PDE Loss:  -1.8201 | Function Loss:  -2.7883
# Total loss:  -1.5085 | PDE Loss:  -1.8292 | Function Loss:  -2.7907
# Total loss:  -1.5122 | PDE Loss:  -1.8323 | Function Loss:  -2.795
# Total loss:  -1.5177 | PDE Loss:  -1.8355 | Function Loss:  -2.8025
# Total loss:  -1.5233 | PDE Loss:  -1.8369 | Function Loss:  -2.8122
# Total loss:  -1.5288 | PDE Loss:  -1.8425 | Function Loss:  -2.8175
# Total loss:  -1.5341 | PDE Loss:  -1.8456 | Function Loss:  -2.8248
# Total loss:  -1.5415 | PDE Loss:  -1.8526 | Function Loss:  -2.8328
# Total loss:  -1.5536 | PDE Loss:  -1.8648 | Function Loss:  -2.8447
# Total loss:  -1.5701 | PDE Loss:  -1.8886 | Function Loss:  -2.8544
# Total loss:  -1.5886 | PDE Loss:  -1.9211 | Function Loss:  -2.8603
# Total loss:  -1.6181 | PDE Loss:  -1.9598 | Function Loss:  -2.882
# Total loss:  -1.5376 | PDE Loss:  -1.7824 | Function Loss:  -2.9033
# Total loss:  -1.6337 | PDE Loss:  -1.9769 | Function Loss:  -2.8964
# Total loss:  -1.6598 | PDE Loss:  -2.0365 | Function Loss:  -2.8964
# Total loss:  -1.6855 | PDE Loss:  -2.0665 | Function Loss:  -2.919
# Total loss:  -1.7027 | PDE Loss:  -2.0557 | Function Loss:  -2.9573
# Total loss:  -1.7093 | PDE Loss:  -2.0902 | Function Loss:  -2.9429
# Total loss:  -1.7142 | PDE Loss:  -2.1079 | Function Loss:  -2.9389
# Total loss:  -1.7185 | PDE Loss:  -2.1046 | Function Loss:  -2.9484
# Total loss:  -1.7218 | PDE Loss:  -2.1054 | Function Loss:  -2.9535
# Total loss:  -1.7266 | PDE Loss:  -2.1164 | Function Loss:  -2.954
# Total loss:  -1.7311 | PDE Loss:  -2.1236 | Function Loss:  -2.9567
# Total loss:  -1.7354 | PDE Loss:  -2.1277 | Function Loss:  -2.961
# Total loss:  -1.7388 | PDE Loss:  -2.133 | Function Loss:  -2.9632
# Total loss:  -1.7454 | PDE Loss:  -2.1335 | Function Loss:  -2.974
# Total loss:  -1.7523 | PDE Loss:  -2.1249 | Function Loss:  -2.9918
# Total loss:  -1.7553 | PDE Loss:  -2.109 | Function Loss:  -3.0094
# Total loss:  -1.7608 | PDE Loss:  -2.1188 | Function Loss:  -3.0114
# Total loss:  -1.7649 | PDE Loss:  -2.1102 | Function Loss:  -3.0258
# Total loss:  -1.7695 | PDE Loss:  -2.1003 | Function Loss:  -3.0427
# Total loss:  -1.7751 | PDE Loss:  -2.0836 | Function Loss:  -3.0688
# Total loss:  -1.7808 | PDE Loss:  -2.0746 | Function Loss:  -3.0891
# Total loss:  -1.7864 | PDE Loss:  -2.0625 | Function Loss:  -3.1139
# Total loss:  -1.7911 | PDE Loss:  -2.0578 | Function Loss:  -3.1295
# Total loss:  -1.7952 | PDE Loss:  -2.0626 | Function Loss:  -3.1327
# Total loss:  -1.802 | PDE Loss:  -2.0694 | Function Loss:  -3.1395
# Total loss:  -1.8062 | PDE Loss:  -2.0576 | Function Loss:  -3.1634
# Total loss:  -1.8165 | PDE Loss:  -2.0817 | Function Loss:  -3.1566
# Total loss:  -1.828 | PDE Loss:  -2.0973 | Function Loss:  -3.1633
# Total loss:  -1.8356 | PDE Loss:  -2.1033 | Function Loss:  -3.1726
# Total loss:  -1.8406 | PDE Loss:  -2.1022 | Function Loss:  -3.1851
# Total loss:  -1.8441 | PDE Loss:  -2.0998 | Function Loss:  -3.1957
# Total loss:  -1.8472 | PDE Loss:  -2.097 | Function Loss:  -3.2063
# Total loss:  -1.8491 | PDE Loss:  -2.0972 | Function Loss:  -3.2105
# Total loss:  -1.851 | PDE Loss:  -2.0982 | Function Loss:  -3.2134
# Total loss:  -1.8552 | PDE Loss:  -2.1024 | Function Loss:  -3.2177
# Total loss:  -1.8619 | PDE Loss:  -2.1117 | Function Loss:  -3.2209
# Total loss:  -1.8699 | PDE Loss:  -2.123 | Function Loss:  -3.2248
# Total loss:  -1.8775 | PDE Loss:  -2.1367 | Function Loss:  -3.2249
# Total loss:  -1.8844 | PDE Loss:  -2.1494 | Function Loss:  -3.2246
# Total loss:  -1.8918 | PDE Loss:  -2.1664 | Function Loss:  -3.2209
# Total loss:  -1.8996 | PDE Loss:  -2.1887 | Function Loss:  -3.2129
# Total loss:  -1.9079 | PDE Loss:  -2.2161 | Function Loss:  -3.2019
# Total loss:  -1.9162 | PDE Loss:  -2.256 | Function Loss:  -3.1817
# Total loss:  -1.9222 | PDE Loss:  -2.2806 | Function Loss:  -3.1726
# Total loss:  -1.9321 | PDE Loss:  -2.3158 | Function Loss:  -3.1636
# Total loss:  -1.942 | PDE Loss:  -2.3481 | Function Loss:  -3.1585
# Total loss:  -1.9495 | PDE Loss:  -2.3728 | Function Loss:  -3.1553
# Total loss:  -1.9579 | PDE Loss:  -2.3842 | Function Loss:  -3.1619
# Total loss:  -1.9665 | PDE Loss:  -2.3885 | Function Loss:  -3.173
# Total loss:  -1.9755 | PDE Loss:  -2.3974 | Function Loss:  -3.182
# Total loss:  -1.9838 | PDE Loss:  -2.3956 | Function Loss:  -3.1966
# Total loss:  -1.9888 | PDE Loss:  -2.3926 | Function Loss:  -3.2068
# Total loss:  -1.9938 | PDE Loss:  -2.3922 | Function Loss:  -3.2153
# Total loss:  -2.0002 | PDE Loss:  -2.3856 | Function Loss:  -3.2306
# Total loss:  -2.0051 | PDE Loss:  -2.3791 | Function Loss:  -3.2438
# Total loss:  -2.0083 | PDE Loss:  -2.3842 | Function Loss:  -3.2455
# Total loss:  -2.011 | PDE Loss:  -2.3899 | Function Loss:  -3.246
# Total loss:  -2.0128 | PDE Loss:  -2.3925 | Function Loss:  -3.2472
# Total loss:  -2.0139 | PDE Loss:  -2.3947 | Function Loss:  -3.2475
# Total loss:  -2.0148 | PDE Loss:  -2.397 | Function Loss:  -3.2474
# Total loss:  -2.016 | PDE Loss:  -2.3999 | Function Loss:  -3.2475
# Total loss:  -2.0178 | PDE Loss:  -2.4049 | Function Loss:  -3.2471
# Total loss:  -2.0207 | PDE Loss:  -2.4107 | Function Loss:  -3.2479
# Total loss:  -2.0249 | PDE Loss:  -2.4241 | Function Loss:  -3.246
# Total loss:  -2.031 | PDE Loss:  -2.438 | Function Loss:  -3.2468
# Total loss:  -2.039 | PDE Loss:  -2.4626 | Function Loss:  -3.2446
# Total loss:  -2.0474 | PDE Loss:  -2.4837 | Function Loss:  -3.2455
# Total loss:  -2.054 | PDE Loss:  -2.498 | Function Loss:  -3.2476
# Total loss:  -2.0582 | PDE Loss:  -2.5033 | Function Loss:  -3.2512
# Total loss:  -2.0613 | PDE Loss:  -2.5049 | Function Loss:  -3.2551
# Total loss:  -2.0643 | PDE Loss:  -2.5033 | Function Loss:  -3.2608
# Total loss:  -2.0677 | PDE Loss:  -2.5035 | Function Loss:  -3.266
# Total loss:  -2.0716 | PDE Loss:  -2.5015 | Function Loss:  -3.2734
# Total loss:  -2.0765 | PDE Loss:  -2.5021 | Function Loss:  -3.2809
# Total loss:  -2.0837 | PDE Loss:  -2.5105 | Function Loss:  -3.2873
# Total loss:  -2.0928 | PDE Loss:  -2.5239 | Function Loss:  -3.2938
# Total loss:  -2.1008 | PDE Loss:  -2.5379 | Function Loss:  -3.2983
# Total loss:  -2.1045 | PDE Loss:  -2.5457 | Function Loss:  -3.2998
# Total loss:  -2.1069 | PDE Loss:  -2.5468 | Function Loss:  -3.3028
# Total loss:  -2.1079 | PDE Loss:  -2.547 | Function Loss:  -3.3044
# Total loss:  -2.1088 | PDE Loss:  -2.5476 | Function Loss:  -3.3054
# Total loss:  -2.1096 | PDE Loss:  -2.5487 | Function Loss:  -3.306
# Total loss:  -2.1118 | PDE Loss:  -2.55 | Function Loss:  -3.3088
# Total loss:  -2.1133 | PDE Loss:  -2.5513 | Function Loss:  -3.3104
# Total loss:  -2.1145 | PDE Loss:  -2.5529 | Function Loss:  -3.3114
# Total loss:  -2.1157 | PDE Loss:  -2.554 | Function Loss:  -3.3126
# Total loss:  -2.1173 | PDE Loss:  -2.5571 | Function Loss:  -3.3133
# Total loss:  -2.1194 | PDE Loss:  -2.5607 | Function Loss:  -3.3145
# Total loss:  -2.1216 | PDE Loss:  -2.5662 | Function Loss:  -3.3148
# Total loss:  -2.1244 | PDE Loss:  -2.5738 | Function Loss:  -3.315
# Total loss:  -2.1281 | PDE Loss:  -2.5847 | Function Loss:  -3.3148
# Total loss:  -2.133 | PDE Loss:  -2.5982 | Function Loss:  -3.3152
# Total loss:  -2.1403 | PDE Loss:  -2.6201 | Function Loss:  -3.3151
# Total loss:  -2.148 | PDE Loss:  -2.6355 | Function Loss:  -3.319
# Total loss:  -2.1572 | PDE Loss:  -2.6541 | Function Loss:  -3.3238
# Total loss:  -2.166 | PDE Loss:  -2.6655 | Function Loss:  -3.3314
# Total loss:  -2.1787 | PDE Loss:  -2.6715 | Function Loss:  -3.3471
# Total loss:  -2.1601 | PDE Loss:  -2.5995 | Function Loss:  -3.3563
# Total loss:  -2.1863 | PDE Loss:  -2.6774 | Function Loss:  -3.3556
# Total loss:  -2.2019 | PDE Loss:  -2.6933 | Function Loss:  -3.3711
# Total loss:  -2.2188 | PDE Loss:  -2.7004 | Function Loss:  -3.3927
# Total loss:  -2.2402 | PDE Loss:  -2.7347 | Function Loss:  -3.4078
# Total loss:  -2.2552 | PDE Loss:  -2.7363 | Function Loss:  -3.4293
# Total loss:  -2.2668 | PDE Loss:  -2.7647 | Function Loss:  -3.4328
# Total loss:  -2.2799 | PDE Loss:  -2.8043 | Function Loss:  -3.4342
# Total loss:  -2.2872 | PDE Loss:  -2.8086 | Function Loss:  -3.4427
# Total loss:  -2.2994 | PDE Loss:  -2.817 | Function Loss:  -3.4565
# Total loss:  -2.3084 | PDE Loss:  -2.8139 | Function Loss:  -3.471
# Total loss:  -2.3144 | PDE Loss:  -2.8153 | Function Loss:  -3.4791
# Total loss:  -2.3142 | PDE Loss:  -2.788 | Function Loss:  -3.4919
# Total loss:  -2.3175 | PDE Loss:  -2.8098 | Function Loss:  -3.4862
# Total loss:  -2.3204 | PDE Loss:  -2.8146 | Function Loss:  -3.4882
# Total loss:  -2.3237 | PDE Loss:  -2.8157 | Function Loss:  -3.4925
# Total loss:  -2.3256 | PDE Loss:  -2.8164 | Function Loss:  -3.495
# Total loss:  -2.3266 | PDE Loss:  -2.817 | Function Loss:  -3.4962
# Total loss:  -2.3283 | PDE Loss:  -2.8211 | Function Loss:  -3.4968
# Total loss:  -2.33 | PDE Loss:  -2.8267 | Function Loss:  -3.4966
# Total loss:  -2.3314 | PDE Loss:  -2.8336 | Function Loss:  -3.4954
# Total loss:  -2.3326 | PDE Loss:  -2.8409 | Function Loss:  -3.4939
# Total loss:  -2.3341 | PDE Loss:  -2.8486 | Function Loss:  -3.4927
# Total loss:  -2.3367 | PDE Loss:  -2.8594 | Function Loss:  -3.4917
# Total loss:  -2.3406 | PDE Loss:  -2.8723 | Function Loss:  -3.4917
# Total loss:  -2.3451 | PDE Loss:  -2.885 | Function Loss:  -3.4929
# Total loss:  -2.3496 | PDE Loss:  -2.8928 | Function Loss:  -3.4961
# Total loss:  -2.3541 | PDE Loss:  -2.8999 | Function Loss:  -3.4995
# Total loss:  -2.3585 | PDE Loss:  -2.9052 | Function Loss:  -3.5036
# Total loss:  -2.3622 | PDE Loss:  -2.9064 | Function Loss:  -3.5083
# Total loss:  -2.3651 | PDE Loss:  -2.9132 | Function Loss:  -3.5096
# Total loss:  -2.3675 | PDE Loss:  -2.9118 | Function Loss:  -3.5136
# Total loss:  -2.3699 | PDE Loss:  -2.917 | Function Loss:  -3.5149
# Total loss:  -2.3725 | PDE Loss:  -2.9205 | Function Loss:  -3.517
# Total loss:  -2.3745 | PDE Loss:  -2.9185 | Function Loss:  -3.5207
# Total loss:  -2.3761 | PDE Loss:  -2.9198 | Function Loss:  -3.5224
# Total loss:  -2.3781 | PDE Loss:  -2.9217 | Function Loss:  -3.5244
# Total loss:  -2.3803 | PDE Loss:  -2.9249 | Function Loss:  -3.5262
# Total loss:  -2.382 | PDE Loss:  -2.9265 | Function Loss:  -3.5279
# Total loss:  -2.383 | PDE Loss:  -2.9279 | Function Loss:  -3.5289
# Total loss:  -2.3838 | PDE Loss:  -2.9267 | Function Loss:  -3.5304
# Total loss:  -2.3844 | PDE Loss:  -2.9259 | Function Loss:  -3.5315
# Total loss:  -2.385 | PDE Loss:  -2.9249 | Function Loss:  -3.5328
# Total loss:  -2.3858 | PDE Loss:  -2.9229 | Function Loss:  -3.5348
# Total loss:  -2.3866 | PDE Loss:  -2.9226 | Function Loss:  -3.5361
# Total loss:  -2.3873 | PDE Loss:  -2.9224 | Function Loss:  -3.5371
# Total loss:  -2.3883 | PDE Loss:  -2.9245 | Function Loss:  -3.5376
# Total loss:  -2.3897 | PDE Loss:  -2.93 | Function Loss:  -3.5373
# Total loss:  -2.3916 | PDE Loss:  -2.9387 | Function Loss:  -3.5365
# Total loss:  -2.3939 | PDE Loss:  -2.953 | Function Loss:  -3.5342
# Total loss:  -2.3961 | PDE Loss:  -2.9666 | Function Loss:  -3.5321
# Total loss:  -2.3981 | PDE Loss:  -2.9805 | Function Loss:  -3.5298
# Total loss:  -2.4003 | PDE Loss:  -2.9945 | Function Loss:  -3.5278
# Total loss:  -2.4024 | PDE Loss:  -3.0089 | Function Loss:  -3.5258
# Total loss:  -2.4041 | PDE Loss:  -3.0198 | Function Loss:  -3.5246
# Total loss:  -2.406 | PDE Loss:  -3.0301 | Function Loss:  -3.5238
# Total loss:  -2.4082 | PDE Loss:  -3.0378 | Function Loss:  -3.5243
# Total loss:  -2.411 | PDE Loss:  -3.0475 | Function Loss:  -3.525
# Total loss:  -2.4146 | PDE Loss:  -3.0521 | Function Loss:  -3.5283
# Total loss:  -2.4192 | PDE Loss:  -3.0615 | Function Loss:  -3.5315
# Total loss:  -2.4249 | PDE Loss:  -3.0694 | Function Loss:  -3.5366
# Total loss:  -2.4312 | PDE Loss:  -3.0934 | Function Loss:  -3.5379
# Total loss:  -2.4372 | PDE Loss:  -3.1097 | Function Loss:  -3.5409
# Total loss:  -2.4417 | PDE Loss:  -3.1322 | Function Loss:  -3.5408
# Total loss:  -2.445 | PDE Loss:  -3.1449 | Function Loss:  -3.5416
# Total loss:  -2.4473 | PDE Loss:  -3.1601 | Function Loss:  -3.5408
# Total loss:  -2.4485 | PDE Loss:  -3.1674 | Function Loss:  -3.5406
# Total loss:  -2.4492 | PDE Loss:  -3.1731 | Function Loss:  -3.5402
# Total loss:  -2.4504 | PDE Loss:  -3.177 | Function Loss:  -3.5406
# Total loss:  -2.4516 | PDE Loss:  -3.1868 | Function Loss:  -3.5398
# Total loss:  -2.4529 | PDE Loss:  -3.1922 | Function Loss:  -3.5403
# Total loss:  -2.4551 | PDE Loss:  -3.1993 | Function Loss:  -3.5414
# Total loss:  -2.4578 | PDE Loss:  -3.2033 | Function Loss:  -3.5438
# Total loss:  -2.4605 | PDE Loss:  -3.2048 | Function Loss:  -3.5467
# Total loss:  -2.463 | PDE Loss:  -3.2051 | Function Loss:  -3.5498
# Total loss:  -2.4653 | PDE Loss:  -3.1978 | Function Loss:  -3.5543
# Total loss:  -2.4672 | PDE Loss:  -3.1946 | Function Loss:  -3.5573
# Total loss:  -2.4686 | PDE Loss:  -3.1941 | Function Loss:  -3.5591
# Total loss:  -2.4707 | PDE Loss:  -3.1904 | Function Loss:  -3.5626
# Total loss:  -2.4731 | PDE Loss:  -3.1913 | Function Loss:  -3.5653
# Total loss:  -2.4751 | PDE Loss:  -3.1873 | Function Loss:  -3.5688
# Total loss:  -2.476 | PDE Loss:  -3.1862 | Function Loss:  -3.5702
# Total loss:  -2.4765 | PDE Loss:  -3.1831 | Function Loss:  -3.5716
# Total loss:  -2.477 | PDE Loss:  -3.1807 | Function Loss:  -3.5727
# Total loss:  -2.4777 | PDE Loss:  -3.1799 | Function Loss:  -3.5737
# Total loss:  -2.4785 | PDE Loss:  -3.1784 | Function Loss:  -3.5751
# Total loss:  -2.4792 | PDE Loss:  -3.1785 | Function Loss:  -3.5761
# Total loss:  -2.4799 | PDE Loss:  -3.1804 | Function Loss:  -3.5764
# Total loss:  -2.4809 | PDE Loss:  -3.182 | Function Loss:  -3.5772
# Total loss:  -2.4822 | PDE Loss:  -3.1845 | Function Loss:  -3.5783
# Total loss:  -2.484 | PDE Loss:  -3.1841 | Function Loss:  -3.5807
# Total loss:  -2.4866 | PDE Loss:  -3.1818 | Function Loss:  -3.5844
# Total loss:  -2.4898 | PDE Loss:  -3.172 | Function Loss:  -3.591
# Total loss:  -2.4937 | PDE Loss:  -3.1617 | Function Loss:  -3.5988
# Total loss:  -2.4969 | PDE Loss:  -3.1494 | Function Loss:  -3.6062
# Total loss:  -2.501 | PDE Loss:  -3.1377 | Function Loss:  -3.615
# Total loss:  -2.5035 | PDE Loss:  -3.126 | Function Loss:  -3.6218
# Total loss:  -2.5059 | PDE Loss:  -3.1237 | Function Loss:  -3.6257
# Total loss:  -2.5073 | PDE Loss:  -3.1209 | Function Loss:  -3.6285
# Total loss:  -2.5085 | PDE Loss:  -3.1218 | Function Loss:  -3.6297
# Total loss:  -2.51 | PDE Loss:  -3.1297 | Function Loss:  -3.6292
# Total loss:  -2.5115 | PDE Loss:  -3.1338 | Function Loss:  -3.6299
# Total loss:  -2.5131 | PDE Loss:  -3.1448 | Function Loss:  -3.6286
# Total loss:  -2.5149 | PDE Loss:  -3.153 | Function Loss:  -3.6284
# Total loss:  -2.5171 | PDE Loss:  -3.1654 | Function Loss:  -3.6277
# Total loss:  -2.5196 | PDE Loss:  -3.1741 | Function Loss:  -3.6284
# Total loss:  -2.5215 | PDE Loss:  -3.1809 | Function Loss:  -3.6288
# Total loss:  -2.523 | PDE Loss:  -3.1874 | Function Loss:  -3.629
# Total loss:  -2.5242 | PDE Loss:  -3.1878 | Function Loss:  -3.6304
# Total loss:  -2.5257 | PDE Loss:  -3.1914 | Function Loss:  -3.6313
# Total loss:  -2.5272 | PDE Loss:  -3.1988 | Function Loss:  -3.6313
# Total loss:  -2.5288 | PDE Loss:  -3.2043 | Function Loss:  -3.6318
# Total loss:  -2.53 | PDE Loss:  -3.2142 | Function Loss:  -3.6307
# Total loss:  -2.5308 | PDE Loss:  -3.2203 | Function Loss:  -3.6301
# Total loss:  -2.5313 | PDE Loss:  -3.225 | Function Loss:  -3.6296
# Total loss:  -2.5317 | PDE Loss:  -3.2283 | Function Loss:  -3.6292
# Total loss:  -2.5321 | PDE Loss:  -3.2305 | Function Loss:  -3.6291
# Total loss:  -2.5325 | PDE Loss:  -3.2327 | Function Loss:  -3.6292
# Total loss:  -2.5332 | PDE Loss:  -3.2343 | Function Loss:  -3.6295
# Total loss:  -2.5341 | PDE Loss:  -3.2363 | Function Loss:  -3.6302
# Total loss:  -2.5352 | PDE Loss:  -3.237 | Function Loss:  -3.6314
# Total loss:  -2.5369 | PDE Loss:  -3.2401 | Function Loss:  -3.6328
# Total loss:  -2.5387 | PDE Loss:  -3.237 | Function Loss:  -3.6358
# Total loss:  -2.5412 | PDE Loss:  -3.24 | Function Loss:  -3.6381
# Total loss:  -2.5442 | PDE Loss:  -3.2457 | Function Loss:  -3.6405
# Total loss:  -2.5475 | PDE Loss:  -3.2582 | Function Loss:  -3.6415
# Total loss:  -2.5498 | PDE Loss:  -3.2656 | Function Loss:  -3.6426
# Total loss:  -2.5514 | PDE Loss:  -3.2761 | Function Loss:  -3.6421
# Total loss:  -2.5526 | PDE Loss:  -3.2774 | Function Loss:  -3.6433
# Total loss:  -2.5538 | PDE Loss:  -3.2781 | Function Loss:  -3.6446
# Total loss:  -2.5556 | PDE Loss:  -3.2895 | Function Loss:  -3.6442
# Total loss:  -2.5578 | PDE Loss:  -3.2924 | Function Loss:  -3.6462
# Total loss:  -2.5618 | PDE Loss:  -3.2951 | Function Loss:  -3.6505
# Total loss:  -2.5635 | PDE Loss:  -3.2942 | Function Loss:  -3.6528
# Total loss:  -2.5646 | PDE Loss:  -3.2967 | Function Loss:  -3.6537
# Total loss:  -2.5659 | PDE Loss:  -3.2996 | Function Loss:  -3.6545
# Total loss:  -2.5671 | PDE Loss:  -3.3076 | Function Loss:  -3.6542
# Total loss:  -2.5681 | PDE Loss:  -3.3089 | Function Loss:  -3.6552
# Total loss:  -2.5687 | PDE Loss:  -3.3141 | Function Loss:  -3.6547
# Total loss:  -2.569 | PDE Loss:  -3.316 | Function Loss:  -3.6547
# Total loss:  -2.5693 | PDE Loss:  -3.316 | Function Loss:  -3.6551
# Total loss:  -2.5696 | PDE Loss:  -3.3176 | Function Loss:  -3.655
# Total loss:  -2.5698 | PDE Loss:  -3.3157 | Function Loss:  -3.6557
# Total loss:  -2.5699 | PDE Loss:  -3.3153 | Function Loss:  -3.6559
# Total loss:  -2.5701 | PDE Loss:  -3.3151 | Function Loss:  -3.6562
# Total loss:  -2.5704 | PDE Loss:  -3.3151 | Function Loss:  -3.6566
# Total loss:  -2.5709 | PDE Loss:  -3.3157 | Function Loss:  -3.6571
# Total loss:  -2.5716 | PDE Loss:  -3.3173 | Function Loss:  -3.6576
# Total loss:  -2.5727 | PDE Loss:  -3.32 | Function Loss:  -3.6584
# Total loss:  -2.5744 | PDE Loss:  -3.3249 | Function Loss:  -3.6593
# Total loss:  -2.5766 | PDE Loss:  -3.3308 | Function Loss:  -3.6607
# Total loss:  -2.5795 | PDE Loss:  -3.3413 | Function Loss:  -3.662
# Total loss:  -2.5828 | PDE Loss:  -3.348 | Function Loss:  -3.6646
# Total loss:  -2.586 | PDE Loss:  -3.3622 | Function Loss:  -3.6655
# Total loss:  -2.5887 | PDE Loss:  -3.3715 | Function Loss:  -3.667
# Total loss:  -2.5909 | PDE Loss:  -3.3728 | Function Loss:  -3.6693
# Total loss:  -2.5936 | PDE Loss:  -3.3777 | Function Loss:  -3.6716
# Total loss:  -2.596 | PDE Loss:  -3.3755 | Function Loss:  -3.675
# Total loss:  -2.5982 | PDE Loss:  -3.3726 | Function Loss:  -3.6781
# Total loss:  -2.6001 | PDE Loss:  -3.3678 | Function Loss:  -3.6814
# Total loss:  -2.6016 | PDE Loss:  -3.3619 | Function Loss:  -3.6844
# Total loss:  -2.6025 | PDE Loss:  -3.3589 | Function Loss:  -3.6862
# Total loss:  -2.6038 | PDE Loss:  -3.3516 | Function Loss:  -3.6893
# Total loss:  -2.6052 | PDE Loss:  -3.3489 | Function Loss:  -3.6916
# Total loss:  -2.6065 | PDE Loss:  -3.3421 | Function Loss:  -3.6947
# Total loss:  -2.6072 | PDE Loss:  -3.3337 | Function Loss:  -3.6975
# Total loss:  -2.6082 | PDE Loss:  -3.3364 | Function Loss:  -3.6981
# Total loss:  -2.6089 | PDE Loss:  -3.337 | Function Loss:  -3.6989
# Total loss:  -2.6096 | PDE Loss:  -3.3336 | Function Loss:  -3.7004
# Total loss:  -2.6101 | PDE Loss:  -3.3323 | Function Loss:  -3.7014
# Total loss:  -2.6105 | PDE Loss:  -3.3291 | Function Loss:  -3.7026
# Total loss:  -2.6108 | PDE Loss:  -3.3274 | Function Loss:  -3.7034
# Total loss:  -2.6114 | PDE Loss:  -3.3259 | Function Loss:  -3.7045
# Total loss:  -2.612 | PDE Loss:  -3.3249 | Function Loss:  -3.7055
# Total loss:  -2.6126 | PDE Loss:  -3.3237 | Function Loss:  -3.7065
# Total loss:  -2.6133 | PDE Loss:  -3.3227 | Function Loss:  -3.7076
# Total loss:  -2.614 | PDE Loss:  -3.3187 | Function Loss:  -3.7095
# Total loss:  -2.6148 | PDE Loss:  -3.3173 | Function Loss:  -3.7108
# Total loss:  -2.6155 | PDE Loss:  -3.3072 | Function Loss:  -3.7143
# Total loss:  -2.6164 | PDE Loss:  -3.3059 | Function Loss:  -3.7157
# Total loss:  -2.6174 | PDE Loss:  -3.3031 | Function Loss:  -3.7177
# Total loss:  -2.6189 | PDE Loss:  -3.2965 | Function Loss:  -3.7213
# Total loss:  -2.6202 | PDE Loss:  -3.2818 | Function Loss:  -3.727
# Total loss:  -2.6215 | PDE Loss:  -3.2825 | Function Loss:  -3.7284
# Total loss:  -2.623 | PDE Loss:  -3.277 | Function Loss:  -3.7319
# Total loss:  -2.6248 | PDE Loss:  -3.2708 | Function Loss:  -3.736
# Total loss:  -2.6282 | PDE Loss:  -3.2657 | Function Loss:  -3.742
# Total loss:  -2.6315 | PDE Loss:  -3.2649 | Function Loss:  -3.7464
# Total loss:  -2.6315 | PDE Loss:  -3.2462 | Function Loss:  -3.7522
# Total loss:  -2.6333 | PDE Loss:  -3.2602 | Function Loss:  -3.7503
# Total loss:  -2.635 | PDE Loss:  -3.2664 | Function Loss:  -3.7506
# Total loss:  -2.6363 | PDE Loss:  -3.2684 | Function Loss:  -3.7517
# Total loss:  -2.6371 | PDE Loss:  -3.2691 | Function Loss:  -3.7525
# Total loss:  -2.638 | PDE Loss:  -3.2727 | Function Loss:  -3.7526
# Total loss:  -2.6391 | PDE Loss:  -3.2768 | Function Loss:  -3.7527
# Total loss:  -2.6399 | PDE Loss:  -3.2807 | Function Loss:  -3.7526
# Total loss:  -2.6405 | PDE Loss:  -3.2801 | Function Loss:  -3.7536
# Total loss:  -2.6411 | PDE Loss:  -3.2825 | Function Loss:  -3.7537
# Total loss:  -2.6417 | PDE Loss:  -3.2822 | Function Loss:  -3.7545
# Total loss:  -2.6426 | PDE Loss:  -3.2797 | Function Loss:  -3.7565
# Total loss:  -2.6444 | PDE Loss:  -3.278 | Function Loss:  -3.7593
# Total loss:  -2.6467 | PDE Loss:  -3.2722 | Function Loss:  -3.7641
# Total loss:  -2.6498 | PDE Loss:  -3.2678 | Function Loss:  -3.7695
# Total loss:  -2.6523 | PDE Loss:  -3.2621 | Function Loss:  -3.7746
# Total loss:  -2.6551 | PDE Loss:  -3.2664 | Function Loss:  -3.7771
# Total loss:  -2.6579 | PDE Loss:  -3.2692 | Function Loss:  -3.7798
# Total loss:  -2.6611 | PDE Loss:  -3.2786 | Function Loss:  -3.781
# Total loss:  -2.6632 | PDE Loss:  -3.2846 | Function Loss:  -3.7819
# Total loss:  -2.6645 | PDE Loss:  -3.2908 | Function Loss:  -3.7816
# Total loss:  -2.6653 | PDE Loss:  -3.2941 | Function Loss:  -3.7817
# Total loss:  -2.666 | PDE Loss:  -3.301 | Function Loss:  -3.7805
# Total loss:  -2.6662 | PDE Loss:  -3.3016 | Function Loss:  -3.7806
# Total loss:  -2.6665 | PDE Loss:  -3.3025 | Function Loss:  -3.7807
# Total loss:  -2.6667 | PDE Loss:  -3.3022 | Function Loss:  -3.7811
# Total loss:  -2.667 | PDE Loss:  -3.3013 | Function Loss:  -3.7816
# Total loss:  -2.6672 | PDE Loss:  -3.3007 | Function Loss:  -3.7822
# Total loss:  -2.6677 | PDE Loss:  -3.2993 | Function Loss:  -3.7832
# Total loss:  -2.6687 | PDE Loss:  -3.2997 | Function Loss:  -3.7844
# Total loss:  -2.67 | PDE Loss:  -3.2993 | Function Loss:  -3.7862
# Total loss:  -2.6714 | PDE Loss:  -3.3015 | Function Loss:  -3.7874
# Total loss:  -2.6732 | PDE Loss:  -3.3059 | Function Loss:  -3.7884
# Total loss:  -2.6752 | PDE Loss:  -3.3134 | Function Loss:  -3.7887
# Total loss:  -2.6775 | PDE Loss:  -3.324 | Function Loss:  -3.7886
# Total loss:  -2.6799 | PDE Loss:  -3.337 | Function Loss:  -3.7879
# Total loss:  -2.6821 | PDE Loss:  -3.3482 | Function Loss:  -3.7877
# Total loss:  -2.6836 | PDE Loss:  -3.3576 | Function Loss:  -3.787
# Total loss:  -2.6846 | PDE Loss:  -3.3598 | Function Loss:  -3.7877
# Total loss:  -2.6858 | PDE Loss:  -3.3651 | Function Loss:  -3.7878
# Total loss:  -2.6868 | PDE Loss:  -3.3669 | Function Loss:  -3.7885
# Total loss:  -2.6878 | PDE Loss:  -3.3681 | Function Loss:  -3.7895
# Total loss:  -2.6887 | PDE Loss:  -3.3673 | Function Loss:  -3.7908
# Total loss:  -2.6897 | PDE Loss:  -3.3678 | Function Loss:  -3.792
# Total loss:  -2.691 | PDE Loss:  -3.3684 | Function Loss:  -3.7934
# Total loss:  -2.6924 | PDE Loss:  -3.3724 | Function Loss:  -3.7942
# Total loss:  -2.6938 | PDE Loss:  -3.3768 | Function Loss:  -3.7948
# Total loss:  -2.695 | PDE Loss:  -3.384 | Function Loss:  -3.7944
# Total loss:  -2.6958 | PDE Loss:  -3.3908 | Function Loss:  -3.7937
# Total loss:  -2.6964 | PDE Loss:  -3.3971 | Function Loss:  -3.7929
# Total loss:  -2.6968 | PDE Loss:  -3.4031 | Function Loss:  -3.7919
# Total loss:  -2.6972 | PDE Loss:  -3.4088 | Function Loss:  -3.791
# Total loss:  -2.6977 | PDE Loss:  -3.4144 | Function Loss:  -3.7902
# Total loss:  -2.6983 | PDE Loss:  -3.4215 | Function Loss:  -3.7893
# Total loss:  -2.6989 | PDE Loss:  -3.4262 | Function Loss:  -3.789
# Total loss:  -2.6995 | PDE Loss:  -3.4303 | Function Loss:  -3.7889
# Total loss:  -2.7002 | PDE Loss:  -3.4326 | Function Loss:  -3.7891
# Total loss:  -2.7008 | PDE Loss:  -3.4333 | Function Loss:  -3.7897
# Total loss:  -2.7016 | PDE Loss:  -3.4334 | Function Loss:  -3.7907
# Total loss:  -2.7027 | PDE Loss:  -3.4319 | Function Loss:  -3.7924
# Total loss:  -2.704 | PDE Loss:  -3.4301 | Function Loss:  -3.7944
# Total loss:  -2.7052 | PDE Loss:  -3.4282 | Function Loss:  -3.7964
# Total loss:  -2.7063 | PDE Loss:  -3.4273 | Function Loss:  -3.7979
# Total loss:  -2.7073 | PDE Loss:  -3.4271 | Function Loss:  -3.7992
# Total loss:  -2.7081 | PDE Loss:  -3.4275 | Function Loss:  -3.8001
# Total loss:  -2.7089 | PDE Loss:  -3.4273 | Function Loss:  -3.8011
# Total loss:  -2.7095 | PDE Loss:  -3.428 | Function Loss:  -3.8016
# Total loss:  -2.71 | PDE Loss:  -3.4272 | Function Loss:  -3.8025
# Total loss:  -2.7107 | PDE Loss:  -3.4286 | Function Loss:  -3.8031
# Total loss:  -2.7117 | PDE Loss:  -3.4295 | Function Loss:  -3.804
# Total loss:  -2.713 | PDE Loss:  -3.4328 | Function Loss:  -3.8049
# Total loss:  -2.7148 | PDE Loss:  -3.4383 | Function Loss:  -3.8058
# Total loss:  -2.7175 | PDE Loss:  -3.4448 | Function Loss:  -3.8076
# Total loss:  -2.7209 | PDE Loss:  -3.4551 | Function Loss:  -3.8094
# Total loss:  -2.7246 | PDE Loss:  -3.4623 | Function Loss:  -3.8123
# Total loss:  -2.7291 | PDE Loss:  -3.4747 | Function Loss:  -3.8151
# Total loss:  -2.732 | PDE Loss:  -3.4794 | Function Loss:  -3.8176
# Total loss:  -2.7348 | PDE Loss:  -3.4837 | Function Loss:  -3.8201
# Total loss:  -2.7367 | PDE Loss:  -3.4826 | Function Loss:  -3.8227
# Total loss:  -2.7377 | PDE Loss:  -3.4786 | Function Loss:  -3.8247
# Total loss:  -2.7387 | PDE Loss:  -3.4753 | Function Loss:  -3.8267
# Total loss:  -2.7392 | PDE Loss:  -3.4745 | Function Loss:  -3.8275
# Total loss:  -2.7394 | PDE Loss:  -3.4752 | Function Loss:  -3.8276
# Total loss:  -2.7399 | PDE Loss:  -3.4759 | Function Loss:  -3.8281
# Total loss:  -2.7403 | PDE Loss:  -3.4762 | Function Loss:  -3.8284
# Total loss:  -2.7405 | PDE Loss:  -3.4749 | Function Loss:  -3.829
# Total loss:  -2.7408 | PDE Loss:  -3.4747 | Function Loss:  -3.8294
# Total loss:  -2.7409 | PDE Loss:  -3.4727 | Function Loss:  -3.83
# Total loss:  -2.7411 | PDE Loss:  -3.4717 | Function Loss:  -3.8304
# Total loss:  -2.7413 | PDE Loss:  -3.4698 | Function Loss:  -3.8311
# Total loss:  -2.7415 | PDE Loss:  -3.4681 | Function Loss:  -3.8318
# Total loss:  -2.7419 | PDE Loss:  -3.4661 | Function Loss:  -3.8327
# Total loss:  -2.7424 | PDE Loss:  -3.4626 | Function Loss:  -3.8342
# Total loss:  -2.7431 | PDE Loss:  -3.459 | Function Loss:  -3.8359
# Total loss:  -2.7439 | PDE Loss:  -3.4524 | Function Loss:  -3.8384
# Total loss:  -2.7444 | PDE Loss:  -3.4503 | Function Loss:  -3.8396
# Total loss:  -2.7451 | PDE Loss:  -3.4476 | Function Loss:  -3.8412
# Total loss:  -2.7458 | PDE Loss:  -3.4456 | Function Loss:  -3.8425
# Total loss:  -2.7464 | PDE Loss:  -3.4431 | Function Loss:  -3.8439
# Total loss:  -2.7469 | PDE Loss:  -3.4409 | Function Loss:  -3.8451
# Total loss:  -2.7474 | PDE Loss:  -3.4419 | Function Loss:  -3.8454
# Total loss:  -2.7479 | PDE Loss:  -3.4388 | Function Loss:  -3.8468
# Total loss:  -2.7483 | PDE Loss:  -3.4383 | Function Loss:  -3.8475
# Total loss:  -2.749 | PDE Loss:  -3.4371 | Function Loss:  -3.8487
# Total loss:  -2.7496 | PDE Loss:  -3.4365 | Function Loss:  -3.8496
# Total loss:  -2.7503 | PDE Loss:  -3.4357 | Function Loss:  -3.8507
# Total loss:  -2.7511 | PDE Loss:  -3.4329 | Function Loss:  -3.8524
# Total loss:  -2.7521 | PDE Loss:  -3.4305 | Function Loss:  -3.8543
# Total loss:  -2.753 | PDE Loss:  -3.4252 | Function Loss:  -3.8568
# Total loss:  -2.7541 | PDE Loss:  -3.4201 | Function Loss:  -3.8597
# Total loss:  -2.7555 | PDE Loss:  -3.4137 | Function Loss:  -3.8632
# Total loss:  -2.7573 | PDE Loss:  -3.4068 | Function Loss:  -3.8675
# Total loss:  -2.7586 | PDE Loss:  -3.3933 | Function Loss:  -3.8732
# Total loss:  -2.7603 | PDE Loss:  -3.3972 | Function Loss:  -3.8742
# Total loss:  -2.7621 | PDE Loss:  -3.3948 | Function Loss:  -3.8773
# Total loss:  -2.7638 | PDE Loss:  -3.3965 | Function Loss:  -3.8789
# Total loss:  -2.7659 | PDE Loss:  -3.3994 | Function Loss:  -3.8808
# Total loss:  -2.7678 | PDE Loss:  -3.4106 | Function Loss:  -3.8799
# Total loss:  -2.769 | PDE Loss:  -3.4151 | Function Loss:  -3.8803
# Total loss:  -2.7701 | PDE Loss:  -3.4193 | Function Loss:  -3.8804
# Total loss:  -2.7715 | PDE Loss:  -3.4245 | Function Loss:  -3.8807
# Total loss:  -2.7725 | PDE Loss:  -3.4353 | Function Loss:  -3.879
# Total loss:  -2.7736 | PDE Loss:  -3.4371 | Function Loss:  -3.8798
# Total loss:  -2.7744 | PDE Loss:  -3.4391 | Function Loss:  -3.8803
# Total loss:  -2.7753 | PDE Loss:  -3.4406 | Function Loss:  -3.881
# Total loss:  -2.7759 | PDE Loss:  -3.4432 | Function Loss:  -3.8811
# Total loss:  -2.7763 | PDE Loss:  -3.4438 | Function Loss:  -3.8814
# Total loss:  -2.7766 | PDE Loss:  -3.4448 | Function Loss:  -3.8816
# Total loss:  -2.7771 | PDE Loss:  -3.4454 | Function Loss:  -3.882
# Total loss:  -2.7776 | PDE Loss:  -3.4462 | Function Loss:  -3.8824
# Total loss:  -2.7781 | PDE Loss:  -3.4464 | Function Loss:  -3.883
# Total loss:  -2.7786 | PDE Loss:  -3.4459 | Function Loss:  -3.8838
# Total loss:  -2.7793 | PDE Loss:  -3.4452 | Function Loss:  -3.8849
# Total loss:  -2.7807 | PDE Loss:  -3.4424 | Function Loss:  -3.8875
# Total loss:  -2.7825 | PDE Loss:  -3.4394 | Function Loss:  -3.8906
# Total loss:  -2.7845 | PDE Loss:  -3.4312 | Function Loss:  -3.8956
# Total loss:  -2.7868 | PDE Loss:  -3.428 | Function Loss:  -3.8994
# Total loss:  -2.7888 | PDE Loss:  -3.4226 | Function Loss:  -3.9036
# Total loss:  -2.7911 | PDE Loss:  -3.4176 | Function Loss:  -3.9082
# Total loss:  -2.7935 | PDE Loss:  -3.4198 | Function Loss:  -3.9106
# Total loss:  -2.7951 | PDE Loss:  -3.4219 | Function Loss:  -3.9121
# Total loss:  -2.797 | PDE Loss:  -3.422 | Function Loss:  -3.9146
# Total loss:  -2.7994 | PDE Loss:  -3.4284 | Function Loss:  -3.9157
# Total loss:  -2.8006 | PDE Loss:  -3.4309 | Function Loss:  -3.9165
# Total loss:  -2.8026 | PDE Loss:  -3.4378 | Function Loss:  -3.917
# Total loss:  -2.8056 | PDE Loss:  -3.4477 | Function Loss:  -3.9179
# Total loss:  -2.8091 | PDE Loss:  -3.4612 | Function Loss:  -3.9185
# Total loss:  -2.8123 | PDE Loss:  -3.4695 | Function Loss:  -3.9203
# Total loss:  -2.8151 | PDE Loss:  -3.4809 | Function Loss:  -3.9207
# Total loss:  -2.8175 | PDE Loss:  -3.4873 | Function Loss:  -3.922
# Total loss:  -2.8196 | PDE Loss:  -3.4912 | Function Loss:  -3.9237
# Total loss:  -2.822 | PDE Loss:  -3.4977 | Function Loss:  -3.9249
# Total loss:  -2.8239 | PDE Loss:  -3.5036 | Function Loss:  -3.9257
# Total loss:  -2.8255 | PDE Loss:  -3.5077 | Function Loss:  -3.9267
# Total loss:  -2.827 | PDE Loss:  -3.5128 | Function Loss:  -3.9273
# Total loss:  -2.8282 | PDE Loss:  -3.5155 | Function Loss:  -3.928
# Total loss:  -2.8292 | PDE Loss:  -3.5188 | Function Loss:  -3.9285
# Total loss:  -2.8301 | PDE Loss:  -3.5184 | Function Loss:  -3.9298
# Total loss:  -2.831 | PDE Loss:  -3.5203 | Function Loss:  -3.9303
# Total loss:  -2.832 | PDE Loss:  -3.521 | Function Loss:  -3.9315
# Total loss:  -2.8334 | PDE Loss:  -3.5231 | Function Loss:  -3.9327
# Total loss:  -2.835 | PDE Loss:  -3.5256 | Function Loss:  -3.934
# Total loss:  -2.8369 | PDE Loss:  -3.5301 | Function Loss:  -3.9353
# Total loss:  -2.8385 | PDE Loss:  -3.5323 | Function Loss:  -3.9367
# Total loss:  -2.8403 | PDE Loss:  -3.5388 | Function Loss:  -3.9373
# Total loss:  -2.8413 | PDE Loss:  -3.5419 | Function Loss:  -3.9378
# Total loss:  -2.842 | PDE Loss:  -3.5447 | Function Loss:  -3.938
# Total loss:  -2.8427 | PDE Loss:  -3.5485 | Function Loss:  -3.9379
# Total loss:  -2.843 | PDE Loss:  -3.5507 | Function Loss:  -3.9378
# Total loss:  -2.8432 | PDE Loss:  -3.5523 | Function Loss:  -3.9377
# Total loss:  -2.8434 | PDE Loss:  -3.5534 | Function Loss:  -3.9376
# Total loss:  -2.8436 | PDE Loss:  -3.5539 | Function Loss:  -3.9377
# Total loss:  -2.8437 | PDE Loss:  -3.5548 | Function Loss:  -3.9377
# Total loss:  -2.8439 | PDE Loss:  -3.5551 | Function Loss:  -3.9378
# Total loss:  -2.844 | PDE Loss:  -3.5555 | Function Loss:  -3.9378
# Total loss:  -2.8441 | PDE Loss:  -3.5559 | Function Loss:  -3.9379
# Total loss:  -2.8443 | PDE Loss:  -3.5565 | Function Loss:  -3.9379
# Total loss:  -2.8444 | PDE Loss:  -3.557 | Function Loss:  -3.938
# Total loss:  -2.8446 | PDE Loss:  -3.5582 | Function Loss:  -3.9379
# Total loss:  -2.8449 | PDE Loss:  -3.56 | Function Loss:  -3.9379
# Total loss:  -2.8454 | PDE Loss:  -3.5634 | Function Loss:  -3.9377
# Total loss:  -2.846 | PDE Loss:  -3.5671 | Function Loss:  -3.9375
# Total loss:  -2.8465 | PDE Loss:  -3.5712 | Function Loss:  -3.9372
# Total loss:  -2.8469 | PDE Loss:  -3.5741 | Function Loss:  -3.937
# Total loss:  -2.8473 | PDE Loss:  -3.5771 | Function Loss:  -3.9368
# Total loss:  -2.8476 | PDE Loss:  -3.5789 | Function Loss:  -3.9367
# Total loss:  -2.8478 | PDE Loss:  -3.5802 | Function Loss:  -3.9368
# Total loss:  -2.8481 | PDE Loss:  -3.5809 | Function Loss:  -3.937
# Total loss:  -2.8484 | PDE Loss:  -3.5821 | Function Loss:  -3.9371
# Total loss:  -2.8487 | PDE Loss:  -3.5823 | Function Loss:  -3.9373
# Total loss:  -2.849 | PDE Loss:  -3.585 | Function Loss:  -3.9372
# Total loss:  -2.8494 | PDE Loss:  -3.5856 | Function Loss:  -3.9375
# Total loss:  -2.8499 | PDE Loss:  -3.5868 | Function Loss:  -3.9378
# Total loss:  -2.8505 | PDE Loss:  -3.5885 | Function Loss:  -3.9382
# Total loss:  -2.8511 | PDE Loss:  -3.5896 | Function Loss:  -3.9387
# Total loss:  -2.8516 | PDE Loss:  -3.5903 | Function Loss:  -3.9392
# Total loss:  -2.8521 | PDE Loss:  -3.5901 | Function Loss:  -3.9398
# Total loss:  -2.8524 | PDE Loss:  -3.5895 | Function Loss:  -3.9403
# Total loss:  -2.8527 | PDE Loss:  -3.5891 | Function Loss:  -3.9408
# Total loss:  -2.8532 | PDE Loss:  -3.5879 | Function Loss:  -3.9416
# Total loss:  -2.8538 | PDE Loss:  -3.5871 | Function Loss:  -3.9425
# Total loss:  -2.8545 | PDE Loss:  -3.5849 | Function Loss:  -3.9438
# Total loss:  -2.8551 | PDE Loss:  -3.5837 | Function Loss:  -3.9449
# Total loss:  -2.8557 | PDE Loss:  -3.583 | Function Loss:  -3.9458
# Total loss:  -2.8564 | PDE Loss:  -3.5833 | Function Loss:  -3.9466
# Total loss:  -2.8571 | PDE Loss:  -3.5844 | Function Loss:  -3.9472
# Total loss:  -2.858 | PDE Loss:  -3.5877 | Function Loss:  -3.9476
# Total loss:  -2.8589 | PDE Loss:  -3.5903 | Function Loss:  -3.948
# Total loss:  -2.8597 | PDE Loss:  -3.5963 | Function Loss:  -3.9477
# Total loss:  -2.8606 | PDE Loss:  -3.6018 | Function Loss:  -3.9476
# Total loss:  -2.8615 | PDE Loss:  -3.6078 | Function Loss:  -3.9474
# Total loss:  -2.8628 | PDE Loss:  -3.6161 | Function Loss:  -3.9471
# Total loss:  -2.8643 | PDE Loss:  -3.6256 | Function Loss:  -3.9469
# Total loss:  -2.8655 | PDE Loss:  -3.632 | Function Loss:  -3.9471
# Total loss:  -2.867 | PDE Loss:  -3.6423 | Function Loss:  -3.9467
# Total loss:  -2.8678 | PDE Loss:  -3.6446 | Function Loss:  -3.9473
# Total loss:  -2.8691 | PDE Loss:  -3.6458 | Function Loss:  -3.9486
# Total loss:  -2.8702 | PDE Loss:  -3.6444 | Function Loss:  -3.9501
# Total loss:  -2.871 | PDE Loss:  -3.6432 | Function Loss:  -3.9514
# Total loss:  -2.8715 | PDE Loss:  -3.6399 | Function Loss:  -3.9526
# Total loss:  -2.8718 | PDE Loss:  -3.6376 | Function Loss:  -3.9535
# Total loss:  -2.8722 | PDE Loss:  -3.6387 | Function Loss:  -3.9537
# Total loss:  -2.8725 | PDE Loss:  -3.6399 | Function Loss:  -3.9539
# Total loss:  -2.873 | PDE Loss:  -3.6447 | Function Loss:  -3.9535
# Total loss:  -2.8736 | PDE Loss:  -3.6496 | Function Loss:  -3.9532
# Total loss:  -2.8741 | PDE Loss:  -3.6547 | Function Loss:  -3.9528
# Total loss:  -2.8748 | PDE Loss:  -3.6606 | Function Loss:  -3.9525
# ...
# Total loss:  -2.8998 | PDE Loss:  -3.7814 | Function Loss:  -3.9609
# Total loss:  -2.9001 | PDE Loss:  -3.7826 | Function Loss:  -3.9612
# Total loss:  -2.9004 | PDE Loss:  -3.7832 | Function Loss:  -3.9613
# Total loss:  -2.9005 | PDE Loss:  -3.7837 | Function Loss:  -3.9614
# Total loss:  -2.9006 | PDE Loss:  -3.7838 | Function Loss:  -3.9615
# Total loss:  -2.9007 | PDE Loss:  -3.7839 | Function Loss:  -3.9616
# Total loss:  -2.9008 | PDE Loss:  -3.784 | Function Loss:  -3.9617
# Total loss:  -2.9009 | PDE Loss:  -3.7836 | Function Loss:  -3.9619
# Total loss:  -2.9012 | PDE Loss:  -3.7808 | Function Loss:  -3.9626
# Total loss:  -2.9014 | PDE Loss:  -3.7809 | Function Loss:  -3.9628
# Total loss:  -2.9018 | PDE Loss:  -3.7803 | Function Loss:  -3.9634
# Total loss:  -2.9022 | PDE Loss:  -3.7795 | Function Loss:  -3.964
# Total loss:  -2.9027 | PDE Loss:  -3.7783 | Function Loss:  -3.9647
# Total loss:  -2.9031 | PDE Loss:  -3.7777 | Function Loss:  -3.9653
# Total loss:  -2.9036 | PDE Loss:  -3.7764 | Function Loss:  -3.9662
# Total loss:  -2.9043 | PDE Loss:  -3.777 | Function Loss:  -3.9668
# Total loss:  -2.9052 | PDE Loss:  -3.7779 | Function Loss:  -3.9677
# Total loss:  -2.9067 | PDE Loss:  -3.7809 | Function Loss:  -3.969
# Total loss:  -2.9081 | PDE Loss:  -3.7829 | Function Loss:  -3.9703
# Total loss:  -2.9093 | PDE Loss:  -3.7866 | Function Loss:  -3.9711
# Total loss:  -2.91 | PDE Loss:  -3.7874 | Function Loss:  -3.9718
# Total loss:  -2.9107 | PDE Loss:  -3.7922 | Function Loss:  -3.9719
# Total loss:  -2.9116 | PDE Loss:  -3.7987 | Function Loss:  -3.9719
# Total loss:  -2.9123 | PDE Loss:  -3.8037 | Function Loss:  -3.972
# Total loss:  -2.913 | PDE Loss:  -3.8086 | Function Loss:  -3.9721
# Total loss:  -2.9138 | PDE Loss:  -3.8103 | Function Loss:  -3.9727
# Total loss:  -2.9145 | PDE Loss:  -3.8121 | Function Loss:  -3.9733
# Total loss:  -2.9152 | PDE Loss:  -3.8113 | Function Loss:  -3.9742
# Total loss:  -2.9161 | PDE Loss:  -3.8107 | Function Loss:  -3.9753
# Total loss:  -2.9169 | PDE Loss:  -3.8085 | Function Loss:  -3.9766
# Total loss:  -2.9177 | PDE Loss:  -3.807 | Function Loss:  -3.9778
# Total loss:  -2.9183 | PDE Loss:  -3.805 | Function Loss:  -3.9787
# Total loss:  -2.9189 | PDE Loss:  -3.8064 | Function Loss:  -3.9791
# Total loss:  -2.9195 | PDE Loss:  -3.8077 | Function Loss:  -3.9796
# Total loss:  -2.9202 | PDE Loss:  -3.8118 | Function Loss:  -3.9798
# Total loss:  -2.9207 | PDE Loss:  -3.815 | Function Loss:  -3.98
# Total loss:  -2.9213 | PDE Loss:  -3.8187 | Function Loss:  -3.9801
# Total loss:  -2.922 | PDE Loss:  -3.8251 | Function Loss:  -3.98
# Total loss:  -2.9227 | PDE Loss:  -3.8299 | Function Loss:  -3.9802
# Total loss:  -2.9234 | PDE Loss:  -3.8353 | Function Loss:  -3.9802
# Total loss:  -2.9244 | PDE Loss:  -3.8432 | Function Loss:  -3.9802
# Total loss:  -2.9254 | PDE Loss:  -3.8504 | Function Loss:  -3.9803
# Total loss:  -2.9263 | PDE Loss:  -3.8561 | Function Loss:  -3.9806
# Total loss:  -2.9275 | PDE Loss:  -3.8637 | Function Loss:  -3.981
# Total loss:  -2.9277 | PDE Loss:  -3.86 | Function Loss:  -3.9816
# Total loss:  -2.9282 | PDE Loss:  -3.8656 | Function Loss:  -3.9815
# Total loss:  -2.9291 | PDE Loss:  -3.8707 | Function Loss:  -3.9818
# Total loss:  -2.9297 | PDE Loss:  -3.8753 | Function Loss:  -3.9819
# Total loss:  -2.9303 | PDE Loss:  -3.8792 | Function Loss:  -3.9821
# Total loss:  -2.9309 | PDE Loss:  -3.8858 | Function Loss:  -3.982
# Total loss:  -2.9315 | PDE Loss:  -3.8882 | Function Loss:  -3.9823
# Total loss:  -2.9318 | PDE Loss:  -3.8913 | Function Loss:  -3.9823
# Total loss:  -2.9324 | PDE Loss:  -3.8945 | Function Loss:  -3.9826
# Total loss:  -2.933 | PDE Loss:  -3.8978 | Function Loss:  -3.9828
# Total loss:  -2.9335 | PDE Loss:  -3.9001 | Function Loss:  -3.9831
# Total loss:  -2.9341 | PDE Loss:  -3.9024 | Function Loss:  -3.9836
# Total loss:  -2.9346 | PDE Loss:  -3.9036 | Function Loss:  -3.9839
# Total loss:  -2.935 | PDE Loss:  -3.9052 | Function Loss:  -3.9842
# Total loss:  -2.9355 | PDE Loss:  -3.908 | Function Loss:  -3.9844
# Total loss:  -2.9361 | PDE Loss:  -3.912 | Function Loss:  -3.9847
# Total loss:  -2.9368 | PDE Loss:  -3.9168 | Function Loss:  -3.9848
# Total loss:  -2.9374 | PDE Loss:  -3.9218 | Function Loss:  -3.9849
# Total loss:  -2.9381 | PDE Loss:  -3.9278 | Function Loss:  -3.985
# Total loss:  -2.9388 | PDE Loss:  -3.9332 | Function Loss:  -3.9851
# Total loss:  -2.9391 | PDE Loss:  -3.9336 | Function Loss:  -3.9854
# Total loss:  -2.9397 | PDE Loss:  -3.9394 | Function Loss:  -3.9855
# Total loss:  -2.9401 | PDE Loss:  -3.9421 | Function Loss:  -3.9856
# Total loss:  -2.9405 | PDE Loss:  -3.9445 | Function Loss:  -3.9858
# Total loss:  -2.941 | PDE Loss:  -3.9479 | Function Loss:  -3.986
# Total loss:  -2.9414 | PDE Loss:  -3.9499 | Function Loss:  -3.9862
# Total loss:  -2.9417 | PDE Loss:  -3.9523 | Function Loss:  -3.9863
# Total loss:  -2.942 | PDE Loss:  -3.9528 | Function Loss:  -3.9866
# Total loss:  -2.9422 | PDE Loss:  -3.954 | Function Loss:  -3.9867
# Total loss:  -2.9424 | PDE Loss:  -3.9557 | Function Loss:  -3.9867
# Total loss:  -2.9426 | PDE Loss:  -3.9564 | Function Loss:  -3.9869
# Total loss:  -2.9428 | PDE Loss:  -3.9567 | Function Loss:  -3.987
# Total loss:  -2.9429 | PDE Loss:  -3.9565 | Function Loss:  -3.9871
# Total loss:  -2.9429 | PDE Loss:  -3.9559 | Function Loss:  -3.9872
# Total loss:  -2.943 | PDE Loss:  -3.9555 | Function Loss:  -3.9873
# Total loss:  -2.943 | PDE Loss:  -3.9551 | Function Loss:  -3.9874
# Total loss:  -2.943 | PDE Loss:  -3.9547 | Function Loss:  -3.9875
# Total loss:  -2.9431 | PDE Loss:  -3.9547 | Function Loss:  -3.9876
# Total loss:  -2.9432 | PDE Loss:  -3.9547 | Function Loss:  -3.9876
# Total loss:  -2.9432 | PDE Loss:  -3.9552 | Function Loss:  -3.9877
# Total loss:  -2.9433 | PDE Loss:  -3.9563 | Function Loss:  -3.9877
# Total loss:  -2.9434 | PDE Loss:  -3.9578 | Function Loss:  -3.9876
# Total loss:  -2.9436 | PDE Loss:  -3.9601 | Function Loss:  -3.9875
# Total loss:  -2.9437 | PDE Loss:  -3.9626 | Function Loss:  -3.9874
# Total loss:  -2.9439 | PDE Loss:  -3.9657 | Function Loss:  -3.9873
# Total loss:  -2.9441 | PDE Loss:  -3.9687 | Function Loss:  -3.9872
# Total loss:  -2.9444 | PDE Loss:  -3.9724 | Function Loss:  -3.9871
# Total loss:  -2.9447 | PDE Loss:  -3.9762 | Function Loss:  -3.9871
# Total loss:  -2.9451 | PDE Loss:  -3.9806 | Function Loss:  -3.9871
# Total loss:  -2.9455 | PDE Loss:  -3.9852 | Function Loss:  -3.987
# Total loss:  -2.9458 | PDE Loss:  -3.9901 | Function Loss:  -3.987
# Total loss:  -2.9462 | PDE Loss:  -3.9953 | Function Loss:  -3.9868
# Total loss:  -2.9465 | PDE Loss:  -4.0003 | Function Loss:  -3.9867
# Total loss:  -2.9469 | PDE Loss:  -4.0056 | Function Loss:  -3.9866
# Total loss:  -2.9471 | PDE Loss:  -4.0085 | Function Loss:  -3.9865
# Total loss:  -2.9473 | PDE Loss:  -4.0108 | Function Loss:  -3.9865
# Total loss:  -2.9475 | PDE Loss:  -4.0125 | Function Loss:  -3.9866
# Total loss:  -2.9477 | PDE Loss:  -4.0158 | Function Loss:  -3.9865
# Total loss:  -2.9478 | PDE Loss:  -4.0165 | Function Loss:  -3.9866
# Total loss:  -2.948 | PDE Loss:  -4.0178 | Function Loss:  -3.9866
# Total loss:  -2.9482 | PDE Loss:  -4.0194 | Function Loss:  -3.9867
# Total loss:  -2.9484 | PDE Loss:  -4.0209 | Function Loss:  -3.9868
# Total loss:  -2.9486 | PDE Loss:  -4.0222 | Function Loss:  -3.9869
# Total loss:  -2.9488 | PDE Loss:  -4.0237 | Function Loss:  -3.987
# Total loss:  -2.9491 | PDE Loss:  -4.0258 | Function Loss:  -3.9871
# Total loss:  -2.9493 | PDE Loss:  -4.0284 | Function Loss:  -3.9871
# Total loss:  -2.9495 | PDE Loss:  -4.0305 | Function Loss:  -3.9872
# Total loss:  -2.9497 | PDE Loss:  -4.0323 | Function Loss:  -3.9872
# Total loss:  -2.9498 | PDE Loss:  -4.0345 | Function Loss:  -3.9871
# Total loss:  -2.95 | PDE Loss:  -4.0357 | Function Loss:  -3.9872
# Total loss:  -2.95 | PDE Loss:  -4.0371 | Function Loss:  -3.9871
# Total loss:  -2.9501 | PDE Loss:  -4.0372 | Function Loss:  -3.9872
# Total loss:  -2.9502 | PDE Loss:  -4.0374 | Function Loss:  -3.9872
# Total loss:  -2.9502 | PDE Loss:  -4.0371 | Function Loss:  -3.9873
# Total loss:  -2.9502 | PDE Loss:  -4.0365 | Function Loss:  -3.9874
# Total loss:  -2.9503 | PDE Loss:  -4.0358 | Function Loss:  -3.9875
# Total loss:  -2.9504 | PDE Loss:  -4.0351 | Function Loss:  -3.9877
# Total loss:  -2.9505 | PDE Loss:  -4.0343 | Function Loss:  -3.9879
# Total loss:  -2.9507 | PDE Loss:  -4.0344 | Function Loss:  -3.9881
# Total loss:  -2.9511 | PDE Loss:  -4.0364 | Function Loss:  -3.9883
# Total loss:  -2.9515 | PDE Loss:  -4.0396 | Function Loss:  -3.9885
# Total loss:  -2.9519 | PDE Loss:  -4.044 | Function Loss:  -3.9885
# Total loss:  -2.9524 | PDE Loss:  -4.0499 | Function Loss:  -3.9886
# Total loss:  -2.9529 | PDE Loss:  -4.0556 | Function Loss:  -3.9886
# Total loss:  -2.9532 | PDE Loss:  -4.0602 | Function Loss:  -3.9885
# Total loss:  -2.9533 | PDE Loss:  -4.062 | Function Loss:  -3.9885
# Total loss:  -2.9534 | PDE Loss:  -4.0635 | Function Loss:  -3.9885
# Total loss:  -2.9535 | PDE Loss:  -4.0648 | Function Loss:  -3.9885
# Total loss:  -2.9536 | PDE Loss:  -4.066 | Function Loss:  -3.9885
# Total loss:  -2.9537 | PDE Loss:  -4.067 | Function Loss:  -3.9885
# Total loss:  -2.9538 | PDE Loss:  -4.0683 | Function Loss:  -3.9885
# Total loss:  -2.9538 | PDE Loss:  -4.0688 | Function Loss:  -3.9885
# Total loss:  -2.9539 | PDE Loss:  -4.0697 | Function Loss:  -3.9885
# Total loss:  -2.9539 | PDE Loss:  -4.0704 | Function Loss:  -3.9885
# Total loss:  -2.9539 | PDE Loss:  -4.0711 | Function Loss:  -3.9884
# Total loss:  -2.954 | PDE Loss:  -4.0719 | Function Loss:  -3.9884
# Total loss:  -2.954 | PDE Loss:  -4.0728 | Function Loss:  -3.9884
# Total loss:  -2.9541 | PDE Loss:  -4.0737 | Function Loss:  -3.9884
# Total loss:  -2.9541 | PDE Loss:  -4.0749 | Function Loss:  -3.9883
# Total loss:  -2.9542 | PDE Loss:  -4.0758 | Function Loss:  -3.9883
# Total loss:  -2.9543 | PDE Loss:  -4.077 | Function Loss:  -3.9883
# Total loss:  -2.9544 | PDE Loss:  -4.078 | Function Loss:  -3.9883
# Total loss:  -2.9545 | PDE Loss:  -4.0794 | Function Loss:  -3.9883
# Total loss:  -2.9546 | PDE Loss:  -4.0803 | Function Loss:  -3.9884
# Total loss:  -2.9547 | PDE Loss:  -4.0816 | Function Loss:  -3.9884
# Total loss:  -2.9548 | PDE Loss:  -4.0821 | Function Loss:  -3.9885
# Total loss:  -2.9549 | PDE Loss:  -4.0825 | Function Loss:  -3.9885
# Total loss:  -2.9549 | PDE Loss:  -4.0827 | Function Loss:  -3.9886
# Total loss:  -2.955 | PDE Loss:  -4.0825 | Function Loss:  -3.9886
# Total loss:  -2.955 | PDE Loss:  -4.0828 | Function Loss:  -3.9886
# Total loss:  -2.955 | PDE Loss:  -4.0834 | Function Loss:  -3.9886
# Total loss:  -2.9551 | PDE Loss:  -4.0839 | Function Loss:  -3.9886
# Total loss:  -2.9551 | PDE Loss:  -4.0853 | Function Loss:  -3.9886
# Total loss:  -2.9552 | PDE Loss:  -4.0863 | Function Loss:  -3.9885
# Total loss:  -2.9553 | PDE Loss:  -4.0876 | Function Loss:  -3.9885
# Total loss:  -2.9553 | PDE Loss:  -4.0885 | Function Loss:  -3.9885
# Total loss:  -2.9554 | PDE Loss:  -4.0893 | Function Loss:  -3.9886
# Total loss:  -2.9555 | PDE Loss:  -4.0895 | Function Loss:  -3.9886
# Total loss:  -2.9556 | PDE Loss:  -4.0892 | Function Loss:  -3.9887
# Total loss:  -2.9556 | PDE Loss:  -4.0889 | Function Loss:  -3.9888
# Total loss:  -2.9557 | PDE Loss:  -4.0884 | Function Loss:  -3.9889
# Total loss:  -2.9558 | PDE Loss:  -4.0878 | Function Loss:  -3.9891
# Total loss:  -2.9559 | PDE Loss:  -4.0868 | Function Loss:  -3.9893
# Total loss:  -2.9559 | PDE Loss:  -4.0864 | Function Loss:  -3.9894
# Total loss:  -2.956 | PDE Loss:  -4.0854 | Function Loss:  -3.9895
# Total loss:  -2.956 | PDE Loss:  -4.0853 | Function Loss:  -3.9895
# Total loss:  -2.956 | PDE Loss:  -4.0849 | Function Loss:  -3.9896
# Total loss:  -2.9561 | PDE Loss:  -4.0847 | Function Loss:  -3.9896
# Total loss:  -2.9562 | PDE Loss:  -4.0851 | Function Loss:  -3.9897
# Total loss:  -2.9562 | PDE Loss:  -4.0855 | Function Loss:  -3.9897
# Total loss:  -2.9563 | PDE Loss:  -4.0861 | Function Loss:  -3.9897
# Total loss:  -2.9563 | PDE Loss:  -4.0866 | Function Loss:  -3.9898
# Total loss:  -2.9564 | PDE Loss:  -4.0876 | Function Loss:  -3.9898
# Total loss:  -2.9566 | PDE Loss:  -4.0888 | Function Loss:  -3.9898
# Total loss:  -2.9568 | PDE Loss:  -4.0915 | Function Loss:  -3.9899
# Total loss:  -2.957 | PDE Loss:  -4.0938 | Function Loss:  -3.99
# Total loss:  -2.9573 | PDE Loss:  -4.097 | Function Loss:  -3.99
# Total loss:  -2.9577 | PDE Loss:  -4.1018 | Function Loss:  -3.99
# Total loss:  -2.9579 | PDE Loss:  -4.105 | Function Loss:  -3.99
# Total loss:  -2.9582 | PDE Loss:  -4.11 | Function Loss:  -3.99
# Total loss:  -2.9584 | PDE Loss:  -4.1125 | Function Loss:  -3.99
# Total loss:  -2.9587 | PDE Loss:  -4.1184 | Function Loss:  -3.9898
# Total loss:  -2.9588 | PDE Loss:  -4.1208 | Function Loss:  -3.9898
# Total loss:  -2.9591 | PDE Loss:  -4.1247 | Function Loss:  -3.9898
# Total loss:  -2.9593 | PDE Loss:  -4.1283 | Function Loss:  -3.9897
# Total loss:  -2.9594 | PDE Loss:  -4.1307 | Function Loss:  -3.9897
# Total loss:  -2.9595 | PDE Loss:  -4.1337 | Function Loss:  -3.9896
# Total loss:  -2.9597 | PDE Loss:  -4.1374 | Function Loss:  -3.9895
# Total loss:  -2.9598 | PDE Loss:  -4.139 | Function Loss:  -3.9895
# Total loss:  -2.9599 | PDE Loss:  -4.1416 | Function Loss:  -3.9894
# Total loss:  -2.96 | PDE Loss:  -4.1434 | Function Loss:  -3.9894
# Total loss:  -2.9601 | PDE Loss:  -4.1456 | Function Loss:  -3.9894
# Total loss:  -2.9602 | PDE Loss:  -4.1488 | Function Loss:  -3.9893
# Total loss:  -2.9603 | PDE Loss:  -4.1519 | Function Loss:  -3.9892
# Total loss:  -2.9604 | PDE Loss:  -4.1551 | Function Loss:  -3.9891
# Total loss:  -2.9605 | PDE Loss:  -4.1581 | Function Loss:  -3.9889
# Total loss:  -2.9606 | PDE Loss:  -4.1612 | Function Loss:  -3.9888
# Total loss:  -2.9606 | PDE Loss:  -4.1636 | Function Loss:  -3.9887
# Total loss:  -2.9607 | PDE Loss:  -4.1663 | Function Loss:  -3.9886
# Total loss:  -2.9608 | PDE Loss:  -4.1675 | Function Loss:  -3.9886
# Total loss:  -2.9608 | PDE Loss:  -4.1683 | Function Loss:  -3.9886
# Total loss:  -2.9609 | PDE Loss:  -4.1702 | Function Loss:  -3.9886
# Total loss:  -2.961 | PDE Loss:  -4.1697 | Function Loss:  -3.9887
# Total loss:  -2.9611 | PDE Loss:  -4.1688 | Function Loss:  -3.9889
# Total loss:  -2.9612 | PDE Loss:  -4.1672 | Function Loss:  -3.9892
# Total loss:  -2.9614 | PDE Loss:  -4.1646 | Function Loss:  -3.9895
# Total loss:  -2.9615 | PDE Loss:  -4.1626 | Function Loss:  -3.9897
# Total loss:  -2.9616 | PDE Loss:  -4.1616 | Function Loss:  -3.9899
# Total loss:  -2.9617 | PDE Loss:  -4.1604 | Function Loss:  -3.9901
# Total loss:  -2.9619 | PDE Loss:  -4.1605 | Function Loss:  -3.9902
# Total loss:  -2.962 | PDE Loss:  -4.16 | Function Loss:  -3.9904
# Total loss:  -2.9622 | PDE Loss:  -4.1614 | Function Loss:  -3.9905
# Total loss:  -2.9623 | PDE Loss:  -4.1633 | Function Loss:  -3.9906
# Total loss:  -2.9625 | PDE Loss:  -4.1662 | Function Loss:  -3.9906
# Total loss:  -2.9626 | PDE Loss:  -4.1686 | Function Loss:  -3.9905
# Total loss:  -2.9627 | PDE Loss:  -4.1716 | Function Loss:  -3.9905
# Total loss:  -2.9629 | PDE Loss:  -4.1733 | Function Loss:  -3.9905
# Total loss:  -2.9629 | PDE Loss:  -4.1742 | Function Loss:  -3.9905
# Total loss:  -2.9631 | PDE Loss:  -4.1771 | Function Loss:  -3.9905
# Total loss:  -2.9633 | PDE Loss:  -4.18 | Function Loss:  -3.9905
# Total loss:  -2.9635 | PDE Loss:  -4.1838 | Function Loss:  -3.9905
# Total loss:  -2.9637 | PDE Loss:  -4.187 | Function Loss:  -3.9905
# Total loss:  -2.9639 | PDE Loss:  -4.1902 | Function Loss:  -3.9905
# Total loss:  -2.9641 | PDE Loss:  -4.1929 | Function Loss:  -3.9906
# Total loss:  -2.9643 | PDE Loss:  -4.1952 | Function Loss:  -3.9906
# Total loss:  -2.9644 | PDE Loss:  -4.196 | Function Loss:  -3.9907
# Total loss:  -2.9646 | PDE Loss:  -4.1986 | Function Loss:  -3.9907
# Total loss:  -2.9647 | PDE Loss:  -4.1997 | Function Loss:  -3.9907
# Total loss:  -2.9648 | PDE Loss:  -4.2017 | Function Loss:  -3.9908
# Total loss:  -2.9651 | PDE Loss:  -4.2043 | Function Loss:  -3.9908
# Total loss:  -2.9653 | PDE Loss:  -4.2067 | Function Loss:  -3.9909
# Total loss:  -2.9654 | PDE Loss:  -4.2083 | Function Loss:  -3.991
# Final Loss:  -2.9653913974761963

# %%
pinn.plotting()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
